# %% [markdown]
# ## Imports

# %%
import os
import subprocess
from Bio import AlignIO
import sys
import PyQt5
from ete3 import Tree, TreeStyle, TextFace, NodeStyle, AttrFace
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# my functions
sys.path.append(os.path.join('..', 'scripts', 'python'))
from create_phyl_tree import run_mafft, alignment_stats, run_raxmlng_check, run_raxmlng_tree, filter_fasta_file, shorten_sequence_names, num_seqs, run_gblocks_grid_search, move_search_grid_files

# %% [markdown]
# ## Variables

# %%
project = 'Suthaus_2022'
marker = 'Full18S'
sim = 'sim_90'
denoise_method = 'RAD'
raw_data = os.path.join('..', 'raw_data')
results_path = os.path.join('..', 'results')
reference_align_dir = os.path.join(raw_data, 'reference_alignments', 'vamp')
new_seq_dir = os.path.join(results_path, 'tax_assignment_vsearch', project, marker, sim, denoise_method, 'vamp_specific')

# %% [markdown]
# # Preparing input fasta file for the sequence alignment

# %% [markdown]
# ### Create a fasta file with all the new sequences assigned to the vampyrellids

# %%
# Path to the output file
merged_fasta_file = os.path.join(new_seq_dir, 'all_samples.fasta')

# Create a list of fasta files, excluding those starting with 'Mock'
files = [file for file in os.listdir(new_seq_dir) if not file.startswith('Mock')]

# List to store the modified lines
merged_lines = []

for file in files:
    path = os.path.join(new_seq_dir, file)
    sample = file.split('_')[0]
    with open(path, 'r') as infile:
        for line in infile:
            if line.startswith('>'):
                # Replace ';' with '_' in the line as the RAxML-ng does not support the semicolon
                modified_line = line.strip().replace(';', '_')
                # Add the sample name to the line
                merged_lines.append(modified_line + '_' + sample + '\n')
            else:
                merged_lines.append(line)

# Write the contents to the output file: results -> tax_assignment_vsearch -> vamp_specific -> all_samples.fasta
with open(merged_fasta_file, 'w') as outfile:
    outfile.writelines(merged_lines)

# %% [markdown]
# ### Prepare vampyrella reference sequence database

# %%
# We have to exclude the unpublished sequences
# All the unpublished sequences started with 'XXXXXXXX' in the sequence ID

# Vampyrella reference sequences path
vamp_ref_seqs = os.path.join(reference_align_dir, '2023_VAMPYRELLIDA_SSU_annotated_PR2_AM_AS_not_aligned_version.fasta')
# Vampyrella filtered fasta file
output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim)
filtered_fasta_file = os.path.join(output_dir, 'vamp_ref_seqs.fasta')

# Create path to the save directory if not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Filter out sequences with headers starting with "XXXXXXXX", and return the filtered lines.
filtered_lines = filter_fasta_file(file_path = vamp_ref_seqs, exclude_pattern = 'XXXXXXXX')
shorten_seq_names = shorten_sequence_names(filtered_lines)

# Write the contents to the output fasta file file: results -> phyl_trees -> vamp_ref_seqs.fasta
with open(filtered_fasta_file, 'w') as outfile:
    outfile.writelines(shorten_seq_names)

# %% [markdown]
# ### Combine the new sequences with our vampyrella reference sequence database

# %%
# Reference alignment path
vamp_ref_seqs = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'vamp_ref_seqs.fasta')
# Path to the new sequences
new_vamp_seqs = os.path.join(new_seq_dir, 'all_samples.fasta')
# Path to the output directory and name of the output file
output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim)
combined_alignment = os.path.join(output_dir, 'vamp_ref_and_new_seqs_comb.fasta')

# Combine ref. sequences fasta file and new vamp sequences

# Read the contents of the reference sequences file
with open(vamp_ref_seqs, 'r') as file1:
    content1 = file1.read()

# Read the contents of the denoised sequences file
with open(new_vamp_seqs, 'r') as file2:
    content2 = file2.read()

# Write the combined contents to the new file: results -> phyl_trees -> vamp_ref_and_new_seqs_comb.fasta
with open(combined_alignment, 'w') as infile:
    infile.write(content1 + '\n' + content2)

print(f"Combined files {new_vamp_seqs} and {vamp_ref_seqs} into {combined_alignment}")

# %% [markdown]
# # Create alignment

# %%
# Creating alignment
input_sequences = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'vamp_ref_and_new_seqs_comb.fasta')
output_sequences = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
log_file = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.log')

run_mafft(input_file = input_sequences, 
          output_file = output_sequences, 
          log_file = log_file, 
          method = 'localpair', 
          maxiterate_num = 1000)

# %%
# Alignment stats
alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')


num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment)

print(f'''
Number of sequences: {num_sequences}
Alignment length: {alignment_length} base pairs
Average number of gaps per sequence: {round(average_gaps, 2)}
Percentage gaps: {round(percentage_gaps, 2)}%
Percentage identity: {round(percentage_identity, 2)}%
''')

# %%
# Alignment stats
# alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')

alignment = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', 'vamp_mafft.fasta')


num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment)

print(f'''
Number of sequences: {num_sequences}
Alignment length: {alignment_length} base pairs
Average number of gaps per sequence: {round(average_gaps, 2)}
Percentage gaps: {round(percentage_gaps, 2)}%
Percentage identity: {round(percentage_identity, 2)}%
''')

# %% [markdown]
# # Check alignment

# %%
# Check the alignment manually to see how does it look like

# %% [markdown]
# # Gblocks: masking poorly aligned positions

# %%
# Define the Parameter Range
Defining the range of values we want to explore for each parameter
mafft_alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')

# Number of sequences and half of the sequences in the alignemnt as a baseline for Gblocks parameters
num_seqs_ = num_seqs(mafft_alignment)
print(f'Total number of sequences in the alignment: {num_seqs_}')
half_num_seqs = math.floor(num_seqs_ / 2) + 1 # half of the sequences, rounded down
print(f'Half of the sequences in the alignment (rounded down): {half_num_seqs}')

# b1
# Description: Minimum Number of Sequences for a Conserved Position
# Minimum is half of the sequences in the alignment.
step_size_b1 = 20
start_b1 = 0
stop_b1 = step_size_b1 * 10
b1_values = [half_num_seqs + i for i in range(start_b1, stop_b1, step_size_b1)]

# b2
# Description: Minimum Number Of Sequences For A Flank Position.
# The lower limit for b2 is the value you set for b1.
step_size_b2 = 20
start_b2 = 0
stop_b2 = step_size_b2 * 10
b2_values = [half_num_seqs + i for i in range(start_b2, stop_b2, step_size_b2)]

# b3:
# Description: Maximum Number Of Contiguous Nonconserved Positions.
# Setting this value too high can include regions of the alignment that are too variable, 
# whereas setting it too low can exclude potentially informative parts of the alignment.
# Default = 8.
step_size_b3 = 5
start_b3 = 8
stop_b3 = (step_size_b3 * 10) + start_b3
b3_values = list(range(start_b3, stop_b3, step_size_b3))

# b4:
# Description: Minimum Length Of A Block.
# Any block that's shorter than the number set will be excluded from the final alignment.
# Default = 10.
step_size_b4 = 5
start_b4 = 10
stop_b4 =  (step_size_b4 * 10) + start_b4
b4_values = list(range(start_b4, stop_b4, step_size_b4))

# v5
# Description: Allowed Gap Positions.
# a: all gaps allowed (the most relaxed setting)
# h: half (a balanced approach)
# n: no gaps allowed (the most strict setting)
b5_values = ['a', 'h', 'n']

print(f'''
b1: {b1_values}
b2: {b2_values}
b3: {b3_values}
b4: {b4_values}
b5: {b5_values}
''')

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
alignment = os.path.join(alignments_path, 'vamp_mafft.fasta')
gblocks_path = os.path.join('..', 'raw_data', 'packages', 'Gblocks_0.91b', 'Gblocks')


run_gblocks_grid_search(mafft_alignment = alignment,
                        b1_values = b1_values,
                        b2_values = b2_values,
                        b3_values = b3_values,
                        b4_values = b4_values,
                        b5_values = b5_values,
                        gblocks_path = gblocks_path)

# Move all the output files to the separate 'grid_search' directory
move_search_grid_files(directory_path = alignments_path, 
                       grid_search_path = os.path.join(alignments_path, 'grid_search'))

# %%
# Checking some basic statistics about our MAFFT alignment
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')

fasta_files = [fasta for fasta in os.listdir(grid_search_path) if '.fasta' in fasta and '_h_' in fasta]

for fasta_file in fasta_files:
    alignment_path = os.path.join(grid_search_path, fasta_file)
    parameters = fasta_file.split('grid_')[1].strip('.fasta')
    print(f'Paramters: {parameters}')
    num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment_path)
    print(f"Number of sequences: {num_sequences}")
    print(f"Alignment length: {alignment_length}")
    print(f"Average number of gaps per sequence: {average_gaps:.2f}")
    print(f"Percentage of gaps across the sequences: {percentage_gaps:.2f}%")
    print(f"Average percentage identity: {percentage_identity:.2f}%")
    print('\n')

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')
fasta_files = [fasta for fasta in os.listdir(grid_search_path) if '.fasta' in fasta and '_h_' in fasta]
results = []

for fasta_file in fasta_files:
    metrics = alignment_stats(os.path.join(grid_search_path, fasta_file))
    b5_value = fasta_file.split("_grid_")[1].split("_")[0]
    iteration_num = fasta_file.split("_grid_")[1].split("_")[1].strip('.fasta')
    results.append((b5_value, iteration_num) + metrics)

# %%
# Create a dataframe from the grid results
grid_df = pd.DataFrame(results, columns=['b5_value', 
                                         'iteration_num', 
                                         'num_sequences', 
                                         'alignment_length', 
                                         'avg_num_gaps', 
                                         'percentage_gaps', 
                                         'avg_percentage_identity'])
# Sort the dataframe based on the iteration number
grid_df = grid_df.sort_values(by='iteration_num').reset_index(drop=True)

# Add the values from the Gblocks parameters
grid_df['b1_value'] = b1_values
grid_df['b2_value'] = b2_values
grid_df['b3_value'] = b3_values
grid_df['b4_value'] = b4_values

# %%
grid_df

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')

# Visualization

# Set style of seaborn plot
sns.set(style="white")

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Define the metrics and their respective labels
metrics = ['alignment_length', 'avg_num_gaps', 'percentage_gaps', 'avg_percentage_identity']
labels = ['Alignment Length', 'Average Number of Gaps', 'Percentage of Gaps', 'Average Percentage Identity']

# Iterate over each metric and plot it in its subplot
for ax, metric, label in zip(axes.ravel(), metrics, labels):
    sns.lineplot(x='iteration_num', y=metric, data=grid_df, color='lightcoral', ax=ax)
    ax.set_title(label + ' vs Iteration Number', fontweight='bold')
    ax.set_xlabel('')
    ax.set_ylabel(label)
    # Set visibility for spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(True)
    ax.spines['left'].set_visible(True)

# # Adjust layout for better spacing
# plt.tight_layout()
# plt.show()

# save path
save_path = os.path.join(grid_search_path, 'pr2_ref_align_gblocks_grid_search_h.png')
# Save the figure
# plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# # Create Maximum Likelihood tree

# %%
# Variables:
# alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
model = 'GTR+G'

alignment = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', 'vamp_mafft_cut_gblocks.fasta')

# %%
# # Run raxml-ng to check the alignment and save the output in the specified directory.
# prefix = 'T1'
# output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, prefix)

prefix = 'T1_gblocks'
output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

run_raxmlng_check(alignment = alignment, 
                  output_dir = output_dir, 
                  model = model, 
                  prefix = prefix)

# %%
# # Run raxml-ng to compute the maximum likelihood tree and save the output in the specified directory
# prefix = 'T2'
# output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, prefix)


prefix = 'T2_gblocks'
output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

run_raxmlng_tree(alignment = alignment, 
                 output_dir = output_dir, 
                 model = model, 
                 prefix= prefix)

 # raxml-ng --msa prim.phy --model GTR+G --prefix T4 --threads 2 --seed 2 --tree pars{25},rand{25}
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 07-Dec-2023 19:35:51 as follows:
#
# raxml-ng --msa ../results/phyl_trees/refrence_alignment_tree/vamp_mafft_cut_gblocks.fasta --model GTR+G --prefix T2_gblocks --threads 3 --seed 2 --tree pars{25},rand{25}
#
# Analysis options:
#   run mode: ML tree search
#   start tree(s): random (25) + parsimony (25)
#   random seed: 2
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (3 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: ../results/phyl_trees/refrence_alignment_tree/vamp_mafft_cut_gblocks.fasta
# [00:00:00] Loaded alignment with 103 taxa and 1204 sites
#
# WARNING: Sequences Thalassomyxa_strain_KibAr_KC779519 and Thalassomyxa_strain_V1ld4_KC779520 are exactly identical!
# WARNING: Sequences Theratromyxa_strain_BaikalA155_EU567294 and Theratromyxa_weberi_GQ377666 are exactly identical!
# WARNING: Sequences Theratromyxa_strain_BaikalA155_EU567294 and Theratromyxa_strain_Wara_KC779513 are exactly identical!
# WARNING: Sequences Placopus_X_GU385615 and Placopus_XX_GU385647 are exactly identical!
# WARNING: Duplicate sequences found: 4
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 818 patterns
#
# Partition 0: noname
# Model: GTR+FO+G4m
# Alignment sites / patterns: 1204 / 818
# Gaps: 18.04 %
# Invariant sites: 44.02 %
#
#
# NOTE: Binary MSA file created: T2_gblocks.raxml.rba
#
# Parallelization scheme autoconfig: 3 worker(s) x 1 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Generating 25 random starting tree(s) with 103 taxa
# [00:00:00] Generating 25 parsimony starting tree(s) with 103 taxa
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 818 / 13088
# [00:00:00] Data distribution: max. searches per worker: 17
#
# Starting ML tree search with 50 distinct starting trees
#
# [00:00:24] [worker #1] ML tree search #2, logLikelihood: -17965.011914
# [00:00:26] [worker #2] ML tree search #3, logLikelihood: -17965.098167
# [00:00:31] [worker #0] ML tree search #1, logLikelihood: -17965.081059
# [00:00:48] [worker #2] ML tree search #6, logLikelihood: -17965.139601
# [00:00:50] [worker #1] ML tree search #5, logLikelihood: -17965.170126
# [00:00:58] [worker #0] ML tree search #4, logLikelihood: -17964.653039
# [00:01:13] [worker #2] ML tree search #9, logLikelihood: -17965.005999
# [00:01:15] [worker #1] ML tree search #8, logLikelihood: -17964.655675
# [00:01:21] [worker #0] ML tree search #7, logLikelihood: -17965.154638
# [00:01:39] [worker #2] ML tree search #12, logLikelihood: -17965.141087
# [00:01:40] [worker #1] ML tree search #11, logLikelihood: -17964.677603
# [00:01:52] [worker #0] ML tree search #10, logLikelihood: -17965.002615
# [00:02:08] [worker #1] ML tree search #14, logLikelihood: -17965.097439
# [00:02:12] [worker #2] ML tree search #15, logLikelihood: -17964.755069
# [00:02:20] [worker #0] ML tree search #13, logLikelihood: -17965.018795
# [00:02:36] [worker #1] ML tree search #17, logLikelihood: -17964.676276
# [00:02:37] [worker #2] ML tree search #18, logLikelihood: -17965.051742
# [00:02:52] [worker #0] ML tree search #16, logLikelihood: -17965.043416
# [00:03:04] [worker #2] ML tree search #21, logLikelihood: -17965.066012
# [00:03:05] [worker #1] ML tree search #20, logLikelihood: -17965.004951
# [00:03:23] [worker #0] ML tree search #19, logLikelihood: -17965.110944
# [00:03:33] [worker #1] ML tree search #23, logLikelihood: -17965.034777
# [00:03:37] [worker #2] ML tree search #24, logLikelihood: -17965.097051
# [00:03:48] [worker #0] ML tree search #22, logLikelihood: -17965.003907
# [00:03:54] [worker #1] ML tree search #26, logLikelihood: -17965.178716
# [00:03:58] [worker #2] ML tree search #27, logLikelihood: -17966.807612
# [00:04:13] [worker #0] ML tree search #25, logLikelihood: -17965.004845
# [00:04:25] [worker #1] ML tree search #29, logLikelihood: -17965.105667
# [00:04:31] [worker #2] ML tree search #30, logLikelihood: -17965.117075
# [00:04:39] [worker #0] ML tree search #28, logLikelihood: -17964.699839
# [00:04:51] [worker #1] ML tree search #32, logLikelihood: -17964.809238
# [00:04:54] [worker #2] ML tree search #33, logLikelihood: -17965.124878
# [00:04:59] [worker #0] ML tree search #31, logLikelihood: -17964.693451
# [00:05:17] [worker #1] ML tree search #35, logLikelihood: -17965.166750
# [00:05:26] [worker #2] ML tree search #36, logLikelihood: -17965.117799
# [00:05:32] [worker #0] ML tree search #34, logLikelihood: -17965.102822
# [00:05:37] [worker #1] ML tree search #38, logLikelihood: -17965.178568
# [00:05:56] [worker #0] ML tree search #37, logLikelihood: -17965.200967
# [00:06:00] [worker #2] ML tree search #39, logLikelihood: -17965.125084
# [00:06:05] [worker #1] ML tree search #41, logLikelihood: -17965.121230
# [00:06:23] [worker #0] ML tree search #40, logLikelihood: -17966.791268
# [00:06:26] [worker #1] ML tree search #44, logLikelihood: -17964.692017
# [00:06:39] [worker #2] ML tree search #42, logLikelihood: -17967.891806
# [00:06:44] [worker #0] ML tree search #43, logLikelihood: -17967.062311
# [00:06:56] [worker #1] ML tree search #47, logLikelihood: -17967.421420
# [00:07:01] [worker #2] ML tree search #45, logLikelihood: -17965.202065
# [00:07:05] [worker #0] ML tree search #46, logLikelihood: -17964.707710
# [00:07:26] [worker #2] ML tree search #48, logLikelihood: -17964.809106
# [00:07:28] [worker #1] ML tree search #50, logLikelihood: -17965.082057
# [00:07:30] [worker #0] ML tree search #49, logLikelihood: -17964.785704
#
# Optimized model parameters:
#
#    Partition 0: noname
#    Rate heterogeneity: GAMMA (4 cats, mean),  alpha: 0.349245 (ML),  weights&rates: (0.250000,0.010124) (0.250000,0.142968) (0.250000,0.669954) (0.250000,3.176954)
#    Base frequencies (ML): 0.295599 0.154829 0.243500 0.306073
#    Substitution rates (ML): 1.666749 3.346045 1.606839 0.905504 7.248101 1.000000
#
#
# Final LogLikelihood: -17964.653039
#
# AIC score: 36353.306077 / AICc score: 36444.438267 / BIC score: 37433.107858
# Free parameters (model + branch lengths): 212
#
# WARNING: Best ML tree contains 7 near-zero branches!
#
# Best ML tree with collapsed near-zero branches saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.bestTreeCollapsed
# Best ML tree saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.bestTree
# All ML trees saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.mlTrees
# Optimized model saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.bestModel
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_gblocks.raxml.log
#
# Analysis started: 07-Dec-2023 19:35:51 / finished: 07-Dec-2023 19:43:21
#
# Elapsed time: 450.064 seconds
#
#
# Output files were moved to: ../results/phyl_trees/refrence_alignment_tree/T2_gblocks
# 0

# %% [markdown]
# ## Inferring bootstrap trees

# %%
def run_raxmlng_bootstrap(alignment, output_dir, num_threads=3, model='GTR+G', prefix='T3'):

    # Specify command for raxm-ng
    cmd = [
        'raxml-ng',
        '--bootstrap',
        '--msa', alignment,
        '--model', model,
        '--prefix', prefix,
        '--threads', str(num_threads),
        '--seed', '2'
    ]

    # Run the command via the subrocess module
    results = subprocess.run(cmd,
                             stdout=subprocess.PIPE,
                             stderr=subprocess.PIPE,
                             text=True,
                             check=True)

    # Print output and error messages (if any)
    print(results.stdout)
    if results.stderr:
        print(results.stderr)

    # Move files to the output directory
    for file in os.listdir():
        if file.startswith(prefix):
            os.rename(file, os.path.join(output_dir, file))
    if results.returncode == 0:
        print(f'Output files were moved to: {output_dir}')

    return results.returncode

# %%
prefix = 'T3_gblocks'
model = 'GTR+G'
output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)


run_raxmlng_bootstrap(alignment = alignment,
                      output_dir = output_dir, 
                      model = model, 
                      prefix = prefix)
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 07-Dec-2023 19:50:15 as follows:
#
# raxml-ng --bootstrap --msa ../results/phyl_trees/refrence_alignment_tree/vamp_mafft_cut_gblocks.fasta --model GTR+G --prefix T3_gblocks --threads 3 --seed 2
#
# Analysis options:
#   run mode: Bootstrapping
#   start tree(s):
#   bootstrap replicates: max: 1000 + bootstopping (autoMRE, cutoff: 0.030000)
#   random seed: 2
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (3 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: ../results/phyl_trees/refrence_alignment_tree/vamp_mafft_cut_gblocks.fasta
# [00:00:00] Loaded alignment with 103 taxa and 1204 sites
#
# WARNING: Sequences Thalassomyxa_strain_KibAr_KC779519 and Thalassomyxa_strain_V1ld4_KC779520 are exactly identical!
# WARNING: Sequences Theratromyxa_strain_BaikalA155_EU567294 and Theratromyxa_weberi_GQ377666 are exactly identical!
# WARNING: Sequences Theratromyxa_strain_BaikalA155_EU567294 and Theratromyxa_strain_Wara_KC779513 are exactly identical!
# WARNING: Sequences Placopus_X_GU385615 and Placopus_XX_GU385647 are exactly identical!
# WARNING: Duplicate sequences found: 4
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_gblocks.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 818 patterns
#
# Partition 0: noname
# Model: GTR+FO+G4m
# Alignment sites / patterns: 1204 / 818
# Gaps: 18.04 %
# Invariant sites: 44.02 %
#
#
# NOTE: Binary MSA file created: T3_gblocks.raxml.rba
#
# Parallelization scheme autoconfig: 3 worker(s) x 1 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 818 / 13088
# [00:00:00] Data distribution: max. searches per worker: 334
# [00:00:00] Starting bootstrapping analysis with 1000 replicates.
#
# [00:00:14] [worker #1] Bootstrap tree #2, logLikelihood: -17635.295149
# [00:00:18] [worker #0] Bootstrap tree #1, logLikelihood: -16758.061763
# [00:00:19] [worker #2] Bootstrap tree #3, logLikelihood: -18028.012037
# [00:00:33] [worker #1] Bootstrap tree #5, logLikelihood: -16597.374112
# [00:00:35] [worker #0] Bootstrap tree #4, logLikelihood: -18234.398591
# [00:00:42] [worker #2] Bootstrap tree #6, logLikelihood: -17520.717977
# [00:00:50] [worker #1] Bootstrap tree #8, logLikelihood: -17901.177412
# [00:00:54] [worker #0] Bootstrap tree #7, logLikelihood: -18360.753621
# [00:01:07] [worker #2] Bootstrap tree #9, logLikelihood: -17554.385606
# [00:01:12] [worker #0] Bootstrap tree #10, logLikelihood: -18362.574567
# [00:01:12] [worker #1] Bootstrap tree #11, logLikelihood: -17943.568910
# [00:01:31] [worker #2] Bootstrap tree #12, logLikelihood: -17066.680647
# [00:01:39] [worker #0] Bootstrap tree #13, logLikelihood: -18000.886642
# [00:01:39] [worker #1] Bootstrap tree #14, logLikelihood: -16696.908649
# [00:01:47] [worker #2] Bootstrap tree #15, logLikelihood: -17682.111980
# [00:02:00] [worker #0] Bootstrap tree #16, logLikelihood: -16759.929299
# [00:02:05] [worker #1] Bootstrap tree #17, logLikelihood: -18910.239173
# [00:02:09] [worker #2] Bootstrap tree #18, logLikelihood: -18320.937566
# [00:02:24] [worker #1] Bootstrap tree #20, logLikelihood: -16347.855982
# [00:02:25] [worker #0] Bootstrap tree #19, logLikelihood: -16890.958140
# [00:02:25] [worker #2] Bootstrap tree #21, logLikelihood: -17795.564249
# [00:02:41] [worker #0] Bootstrap tree #22, logLikelihood: -18148.178591
# [00:02:43] [worker #1] Bootstrap tree #23, logLikelihood: -18288.418772
# [00:02:44] [worker #2] Bootstrap tree #24, logLikelihood: -18290.110915
# [00:02:58] [worker #0] Bootstrap tree #25, logLikelihood: -17473.757996
# [00:03:01] [worker #2] Bootstrap tree #27, logLikelihood: -17867.531066
# [00:03:02] [worker #1] Bootstrap tree #26, logLikelihood: -18100.776253
# [00:03:16] [worker #0] Bootstrap tree #28, logLikelihood: -19265.438457
# [00:03:19] [worker #2] Bootstrap tree #30, logLikelihood: -18027.739797
# [00:03:22] [worker #1] Bootstrap tree #29, logLikelihood: -18359.965916
# [00:03:33] [worker #0] Bootstrap tree #31, logLikelihood: -17202.562905
# [00:03:40] [worker #1] Bootstrap tree #32, logLikelihood: -18689.340238
# [00:03:43] [worker #2] Bootstrap tree #33, logLikelihood: -18362.811600
# [00:03:52] [worker #0] Bootstrap tree #34, logLikelihood: -17818.189575
# [00:04:06] [worker #1] Bootstrap tree #35, logLikelihood: -18424.884044
# [00:04:09] [worker #0] Bootstrap tree #37, logLikelihood: -17300.954397
# [00:04:10] [worker #2] Bootstrap tree #36, logLikelihood: -17876.599839
# [00:04:25] [worker #1] Bootstrap tree #38, logLikelihood: -17174.883745
# [00:04:31] [worker #0] Bootstrap tree #40, logLikelihood: -18594.682076
# [00:04:31] [worker #2] Bootstrap tree #39, logLikelihood: -17604.884954
# [00:04:43] [worker #1] Bootstrap tree #41, logLikelihood: -17684.023684
# [00:04:49] [worker #2] Bootstrap tree #42, logLikelihood: -18063.090892
# [00:04:51] [worker #0] Bootstrap tree #43, logLikelihood: -17549.024954
# [00:05:01] [worker #1] Bootstrap tree #44, logLikelihood: -17407.518192
# [00:05:11] [worker #2] Bootstrap tree #45, logLikelihood: -17447.074354
# [00:05:15] [worker #0] Bootstrap tree #46, logLikelihood: -18399.387950
# [00:05:19] [worker #1] Bootstrap tree #47, logLikelihood: -17727.231048
# [00:05:34] [worker #0] Bootstrap tree #49, logLikelihood: -18440.150380
# [00:05:35] [worker #2] Bootstrap tree #48, logLikelihood: -17864.072258
# [00:05:47] [worker #1] Bootstrap tree #50, logLikelihood: -17582.382793
# [00:06:05] [worker #2] Bootstrap tree #51, logLikelihood: -16862.092758
# [00:06:06] [worker #0] Bootstrap tree #52, logLikelihood: -17662.338368
# [00:06:14] [worker #1] Bootstrap tree #53, logLikelihood: -17781.578885
# [00:06:29] [worker #0] Bootstrap tree #55, logLikelihood: -18483.908140
# [00:06:31] [worker #1] Bootstrap tree #56, logLikelihood: -16408.363370
# [00:06:35] [worker #2] Bootstrap tree #54, logLikelihood: -17004.334033
# [00:06:43] [worker #0] Bootstrap tree #58, logLikelihood: -19238.803068
# [00:06:52] [worker #2] Bootstrap tree #57, logLikelihood: -16662.272526
# [00:06:57] [worker #1] Bootstrap tree #59, logLikelihood: -18041.758190
# [00:07:02] [worker #0] Bootstrap tree #61, logLikelihood: -18047.193588
# [00:07:06] [worker #2] Bootstrap tree #60, logLikelihood: -16714.564285
# [00:07:16] [worker #1] Bootstrap tree #62, logLikelihood: -17957.577649
# [00:07:23] [worker #0] Bootstrap tree #64, logLikelihood: -18733.823923
# [00:07:25] [worker #2] Bootstrap tree #63, logLikelihood: -17393.722646
# [00:07:34] [worker #1] Bootstrap tree #65, logLikelihood: -18235.748356
# [00:07:43] [worker #0] Bootstrap tree #67, logLikelihood: -18912.881302
# [00:07:44] [worker #2] Bootstrap tree #66, logLikelihood: -17598.246630
# [00:07:53] [worker #1] Bootstrap tree #68, logLikelihood: -17311.588317
# [00:08:00] [worker #2] Bootstrap tree #69, logLikelihood: -17618.409256
# [00:08:02] [worker #0] Bootstrap tree #70, logLikelihood: -17131.356408
# [00:08:15] [worker #1] Bootstrap tree #71, logLikelihood: -18092.990735
# [00:08:18] [worker #0] Bootstrap tree #73, logLikelihood: -17513.583625
# [00:08:31] [worker #2] Bootstrap tree #72, logLikelihood: -18350.266221
# [00:08:35] [worker #0] Bootstrap tree #76, logLikelihood: -18306.370040
# [00:08:37] [worker #1] Bootstrap tree #74, logLikelihood: -18177.758278
# [00:08:56] [worker #2] Bootstrap tree #75, logLikelihood: -17242.363909
# [00:08:59] [worker #1] Bootstrap tree #77, logLikelihood: -18351.054858
# [00:09:02] [worker #0] Bootstrap tree #79, logLikelihood: -17880.676390
# [00:09:13] [worker #2] Bootstrap tree #78, logLikelihood: -18183.433136
# [00:09:17] [worker #1] Bootstrap tree #80, logLikelihood: -17137.433699
# [00:09:19] [worker #0] Bootstrap tree #82, logLikelihood: -17855.284562
# [00:09:35] [worker #0] Bootstrap tree #85, logLikelihood: -16690.274312
# [00:09:36] [worker #2] Bootstrap tree #81, logLikelihood: -17913.566711
# [00:09:41] [worker #1] Bootstrap tree #83, logLikelihood: -19113.938264
# [00:09:53] [worker #0] Bootstrap tree #88, logLikelihood: -17267.474124
# [00:10:00] [worker #1] Bootstrap tree #86, logLikelihood: -17779.160434
# [00:10:06] [worker #2] Bootstrap tree #84, logLikelihood: -18479.577980
# [00:10:17] [worker #0] Bootstrap tree #91, logLikelihood: -18021.249133
# [00:10:21] [worker #2] Bootstrap tree #87, logLikelihood: -17631.907531
# [00:10:23] [worker #1] Bootstrap tree #89, logLikelihood: -18084.859657
# [00:10:33] [worker #0] Bootstrap tree #94, logLikelihood: -17819.004675
# [00:10:42] [worker #1] Bootstrap tree #92, logLikelihood: -17829.399342
# [00:10:45] [worker #2] Bootstrap tree #90, logLikelihood: -17081.525797
# [00:11:01] [worker #1] Bootstrap tree #95, logLikelihood: -17281.631153
# [00:11:01] [worker #0] Bootstrap tree #97, logLikelihood: -17863.901931
# [00:11:02] [worker #2] Bootstrap tree #93, logLikelihood: -16680.268326
# [00:11:18] [worker #0] Bootstrap tree #100, logLikelihood: -17918.934077
# [00:11:24] [worker #1] Bootstrap tree #98, logLikelihood: -17886.508866
# [00:11:28] [worker #2] Bootstrap tree #96, logLikelihood: -17735.210529
# [00:11:52] [worker #2] Bootstrap tree #99, logLikelihood: -18707.584762
# [00:12:10] [worker #0] Bootstrap tree #103, logLikelihood: -17820.666515
# [00:12:17] [worker #2] Bootstrap tree #102, logLikelihood: -18165.814836
# [00:12:18] [worker #1] Bootstrap tree #101, logLikelihood: -18955.286039
# [00:12:31] [worker #0] Bootstrap tree #106, logLikelihood: -18180.252404
# [00:12:33] [worker #2] Bootstrap tree #105, logLikelihood: -17047.592563
# [00:12:42] [worker #1] Bootstrap tree #104, logLikelihood: -17219.528348
# [00:12:51] [worker #0] Bootstrap tree #109, logLikelihood: -17240.895046
# [00:12:56] [worker #2] Bootstrap tree #108, logLikelihood: -16814.111082
# [00:13:00] [worker #1] Bootstrap tree #107, logLikelihood: -17770.564579
# [00:13:11] [worker #0] Bootstrap tree #112, logLikelihood: -17006.626403
# [00:13:14] [worker #2] Bootstrap tree #111, logLikelihood: -18115.799494
# [00:13:17] [worker #1] Bootstrap tree #110, logLikelihood: -18150.606175
# [00:13:34] [worker #2] Bootstrap tree #114, logLikelihood: -17803.446565
# [00:13:35] [worker #0] Bootstrap tree #115, logLikelihood: -17822.791946
# [00:13:47] [worker #1] Bootstrap tree #113, logLikelihood: -17139.195107
# [00:13:53] [worker #0] Bootstrap tree #118, logLikelihood: -18268.703256
# [00:14:07] [worker #2] Bootstrap tree #117, logLikelihood: -18200.262228
# [00:14:15] [worker #1] Bootstrap tree #116, logLikelihood: -17965.482959
# [00:14:16] [worker #0] Bootstrap tree #121, logLikelihood: -19043.953334
# [00:14:25] [worker #2] Bootstrap tree #120, logLikelihood: -19344.708466
# [00:14:37] [worker #0] Bootstrap tree #124, logLikelihood: -18537.673447
# [00:14:37] [worker #1] Bootstrap tree #119, logLikelihood: -18053.579525
# [00:14:43] [worker #2] Bootstrap tree #123, logLikelihood: -19081.364999
# [00:14:56] [worker #0] Bootstrap tree #127, logLikelihood: -18400.528668
# [00:14:59] [worker #2] Bootstrap tree #126, logLikelihood: -16705.346670
# [00:15:00] [worker #1] Bootstrap tree #122, logLikelihood: -15453.291408
# [00:15:16] [worker #0] Bootstrap tree #130, logLikelihood: -17807.701739
# [00:15:20] [worker #1] Bootstrap tree #125, logLikelihood: -17185.820638
# [00:15:22] [worker #2] Bootstrap tree #129, logLikelihood: -17655.754353
# [00:15:33] [worker #0] Bootstrap tree #133, logLikelihood: -16535.160691
# [00:15:39] [worker #2] Bootstrap tree #132, logLikelihood: -17595.158318
# [00:15:55] [worker #1] Bootstrap tree #128, logLikelihood: -17818.626903
# [00:15:59] [worker #2] Bootstrap tree #135, logLikelihood: -17325.103189
# [00:16:02] [worker #0] Bootstrap tree #136, logLikelihood: -18307.543156
# [00:16:14] [worker #1] Bootstrap tree #131, logLikelihood: -17449.755593
# [00:16:20] [worker #2] Bootstrap tree #138, logLikelihood: -17498.772829
# [00:16:28] [worker #0] Bootstrap tree #139, logLikelihood: -17090.809093
# [00:16:45] [worker #1] Bootstrap tree #134, logLikelihood: -16118.792628
# [00:16:51] [worker #2] Bootstrap tree #141, logLikelihood: -18454.727080
# [00:16:52] [worker #0] Bootstrap tree #142, logLikelihood: -17688.370614
# [00:17:09] [worker #2] Bootstrap tree #144, logLikelihood: -18243.283597
# [00:17:09] [worker #0] Bootstrap tree #145, logLikelihood: -17562.121281
# [00:17:17] [worker #1] Bootstrap tree #137, logLikelihood: -16906.010938
# [00:17:27] [worker #0] Bootstrap tree #148, logLikelihood: -18113.101868
# [00:17:28] [worker #2] Bootstrap tree #147, logLikelihood: -18075.574121
# [00:17:43] [worker #1] Bootstrap tree #140, logLikelihood: -18216.867493
# [00:17:48] [worker #2] Bootstrap tree #150, logLikelihood: -17081.733203
# [00:18:02] [worker #1] Bootstrap tree #143, logLikelihood: -17816.165975
# [00:18:17] [worker #1] Bootstrap tree #146, logLikelihood: -16411.385570
# [00:18:32] [worker #1] Bootstrap tree #149, logLikelihood: -17224.404607
# [00:18:48] [worker #1] Bootstrap tree #152, logLikelihood: -18078.842667
# [00:18:49] [worker #0] Bootstrap tree #151, logLikelihood: -17456.006978
# [00:18:49] [worker #2] Bootstrap tree #153, logLikelihood: -17703.695476
# [00:19:05] [worker #0] Bootstrap tree #154, logLikelihood: -17528.227816
# [00:19:14] [worker #1] Bootstrap tree #155, logLikelihood: -17456.825955
# [00:19:14] [worker #2] Bootstrap tree #156, logLikelihood: -17890.262950
# [00:19:32] [worker #0] Bootstrap tree #157, logLikelihood: -17875.775099
# [00:19:33] [worker #1] Bootstrap tree #158, logLikelihood: -17459.342346
# [00:19:33] [worker #2] Bootstrap tree #159, logLikelihood: -17800.081805
# [00:19:51] [worker #0] Bootstrap tree #160, logLikelihood: -18348.085876
# [00:19:52] [worker #2] Bootstrap tree #162, logLikelihood: -18997.297072
# [00:20:04] [worker #1] Bootstrap tree #161, logLikelihood: -17364.901115
# [00:20:09] [worker #2] Bootstrap tree #165, logLikelihood: -17241.204030
# [00:20:09] [worker #0] Bootstrap tree #163, logLikelihood: -16977.911498
# [00:20:24] [worker #1] Bootstrap tree #164, logLikelihood: -17905.409841
# [00:20:25] [worker #0] Bootstrap tree #166, logLikelihood: -17053.849610
# [00:20:28] [worker #2] Bootstrap tree #168, logLikelihood: -17906.037772
# [00:20:41] [worker #1] Bootstrap tree #167, logLikelihood: -17930.031345
# [00:20:43] [worker #0] Bootstrap tree #169, logLikelihood: -18177.542930
# [00:20:45] [worker #2] Bootstrap tree #171, logLikelihood: -17911.072221
# [00:21:01] [worker #0] Bootstrap tree #172, logLikelihood: -18324.639143
# [00:21:04] [worker #2] Bootstrap tree #174, logLikelihood: -18129.129500
# [00:21:07] [worker #1] Bootstrap tree #170, logLikelihood: -17956.674711
# [00:21:19] [worker #0] Bootstrap tree #175, logLikelihood: -17755.810212
# [00:21:20] [worker #2] Bootstrap tree #177, logLikelihood: -17959.719829
# [00:21:31] [worker #1] Bootstrap tree #173, logLikelihood: -18486.851050
# [00:21:37] [worker #0] Bootstrap tree #178, logLikelihood: -18112.690830
# [00:21:37] [worker #2] Bootstrap tree #180, logLikelihood: -17773.983972
# [00:21:59] [worker #2] Bootstrap tree #183, logLikelihood: -18143.920591
# [00:22:01] [worker #1] Bootstrap tree #176, logLikelihood: -17901.355120
# [00:22:03] [worker #0] Bootstrap tree #181, logLikelihood: -18344.243891
# [00:22:20] [worker #0] Bootstrap tree #184, logLikelihood: -17723.513589
# [00:22:20] [worker #1] Bootstrap tree #179, logLikelihood: -16445.300432
# [00:22:24] [worker #2] Bootstrap tree #186, logLikelihood: -17684.563003
# [00:22:42] [worker #2] Bootstrap tree #189, logLikelihood: -17392.025423
# [00:22:42] [worker #0] Bootstrap tree #187, logLikelihood: -18134.804936
# [00:22:54] [worker #1] Bootstrap tree #182, logLikelihood: -17854.094564
# [00:22:58] [worker #0] Bootstrap tree #190, logLikelihood: -17991.034752
# [00:23:06] [worker #2] Bootstrap tree #192, logLikelihood: -16452.530123
# [00:23:11] [worker #1] Bootstrap tree #185, logLikelihood: -16988.568549
# [00:23:15] [worker #0] Bootstrap tree #193, logLikelihood: -17895.213011
# [00:23:29] [worker #1] Bootstrap tree #188, logLikelihood: -18581.459936
# [00:23:29] [worker #2] Bootstrap tree #195, logLikelihood: -17537.263962
# [00:23:34] [worker #0] Bootstrap tree #196, logLikelihood: -17674.064850
# [00:23:47] [worker #2] Bootstrap tree #198, logLikelihood: -18339.757511
# [00:23:52] [worker #1] Bootstrap tree #191, logLikelihood: -18018.734733
# [00:23:54] [worker #0] Bootstrap tree #199, logLikelihood: -17325.214100
# [00:24:11] [worker #1] Bootstrap tree #194, logLikelihood: -18096.400861
# [00:24:28] [worker #1] Bootstrap tree #197, logLikelihood: -18398.805320
# [00:24:45] [worker #1] Bootstrap tree #200, logLikelihood: -16717.838753
# [00:25:02] [worker #0] Bootstrap tree #202, logLikelihood: -17091.994197
# [00:25:03] [worker #2] Bootstrap tree #201, logLikelihood: -18516.997911
# [00:25:06] [worker #1] Bootstrap tree #203, logLikelihood: -17786.269226
# [00:25:24] [worker #0] Bootstrap tree #205, logLikelihood: -18737.620695
# [00:25:31] [worker #1] Bootstrap tree #206, logLikelihood: -17386.043458
# [00:25:34] [worker #2] Bootstrap tree #204, logLikelihood: -17076.883065
# [00:25:42] [worker #0] Bootstrap tree #208, logLikelihood: -18540.232014
# [00:25:58] [worker #2] Bootstrap tree #207, logLikelihood: -17616.982419
# [00:25:58] [worker #1] Bootstrap tree #209, logLikelihood: -18334.042249
# [00:26:06] [worker #0] Bootstrap tree #211, logLikelihood: -17536.795399
# [00:26:16] [worker #2] Bootstrap tree #210, logLikelihood: -18117.231032
# [00:26:18] [worker #1] Bootstrap tree #212, logLikelihood: -17708.820946
# [00:26:32] [worker #0] Bootstrap tree #214, logLikelihood: -17984.003587
# [00:26:37] [worker #2] Bootstrap tree #213, logLikelihood: -17385.893583
# [00:26:39] [worker #1] Bootstrap tree #215, logLikelihood: -17369.587635
# [00:26:48] [worker #0] Bootstrap tree #217, logLikelihood: -17579.743632
# [00:26:56] [worker #2] Bootstrap tree #216, logLikelihood: -17872.919982
# [00:26:58] [worker #1] Bootstrap tree #218, logLikelihood: -17998.335976
# [00:27:09] [worker #0] Bootstrap tree #220, logLikelihood: -17838.574338
# [00:27:12] [worker #1] Bootstrap tree #221, logLikelihood: -17210.210034
# [00:27:13] [worker #2] Bootstrap tree #219, logLikelihood: -18070.468021
# [00:27:26] [worker #0] Bootstrap tree #223, logLikelihood: -16978.575750
# [00:27:32] [worker #2] Bootstrap tree #222, logLikelihood: -17253.621253
# [00:27:34] [worker #1] Bootstrap tree #224, logLikelihood: -17881.451417
# [00:27:49] [worker #0] Bootstrap tree #226, logLikelihood: -17772.129207
# [00:27:51] [worker #1] Bootstrap tree #227, logLikelihood: -17183.868483
# [00:28:06] [worker #2] Bootstrap tree #225, logLikelihood: -17921.128567
# [00:28:13] [worker #1] Bootstrap tree #230, logLikelihood: -17251.116417
# [00:28:13] [worker #0] Bootstrap tree #229, logLikelihood: -17511.761753
# [00:28:24] [worker #2] Bootstrap tree #228, logLikelihood: -17911.448612
# [00:28:31] [worker #1] Bootstrap tree #233, logLikelihood: -17607.863614
# [00:28:32] [worker #0] Bootstrap tree #232, logLikelihood: -18747.016555
# [00:28:46] [worker #2] Bootstrap tree #231, logLikelihood: -17209.449051
# [00:28:50] [worker #1] Bootstrap tree #236, logLikelihood: -19272.334595
# [00:29:00] [worker #0] Bootstrap tree #235, logLikelihood: -18497.375200
# [00:29:06] [worker #2] Bootstrap tree #234, logLikelihood: -17042.884316
# [00:29:22] [worker #0] Bootstrap tree #238, logLikelihood: -16994.001901
# [00:29:25] [worker #2] Bootstrap tree #237, logLikelihood: -18656.339698
# [00:29:27] [worker #1] Bootstrap tree #239, logLikelihood: -17835.841259
# [00:29:37] [worker #0] Bootstrap tree #241, logLikelihood: -17721.578489
# [00:29:43] [worker #2] Bootstrap tree #240, logLikelihood: -18065.569492
# [00:29:49] [worker #1] Bootstrap tree #242, logLikelihood: -17565.765982
# [00:29:55] [worker #0] Bootstrap tree #244, logLikelihood: -18413.663866
# [00:30:09] [worker #2] Bootstrap tree #243, logLikelihood: -16523.888489
# [00:30:19] [worker #1] Bootstrap tree #245, logLikelihood: -17735.436848
# [00:30:20] [worker #0] Bootstrap tree #247, logLikelihood: -16769.426460
# [00:30:29] [worker #2] Bootstrap tree #246, logLikelihood: -18732.943482
# [00:30:37] [worker #1] Bootstrap tree #248, logLikelihood: -17551.141520
# [00:30:38] [worker #0] Bootstrap tree #250, logLikelihood: -17550.331287
# [00:30:46] [worker #2] Bootstrap tree #249, logLikelihood: -17626.462381
# [00:31:03] [worker #2] Bootstrap tree #252, logLikelihood: -18562.010325
# [00:31:10] [worker #1] Bootstrap tree #251, logLikelihood: -18703.689566
# [00:31:21] [worker #0] Bootstrap tree #253, logLikelihood: -17405.698328
# [00:31:25] [worker #2] Bootstrap tree #255, logLikelihood: -18154.046603
# [00:31:28] [worker #1] Bootstrap tree #254, logLikelihood: -17898.821127
# [00:31:41] [worker #0] Bootstrap tree #256, logLikelihood: -17988.082101
# [00:31:41] [worker #2] Bootstrap tree #258, logLikelihood: -17010.425587
# [00:31:52] [worker #1] Bootstrap tree #257, logLikelihood: -18258.070209
# [00:31:59] [worker #0] Bootstrap tree #259, logLikelihood: -19530.544045
# [00:32:00] [worker #2] Bootstrap tree #261, logLikelihood: -17772.897764
# [00:32:09] [worker #1] Bootstrap tree #260, logLikelihood: -18110.675811
# [00:32:18] [worker #2] Bootstrap tree #264, logLikelihood: -16996.312334
# [00:32:24] [worker #0] Bootstrap tree #262, logLikelihood: -17658.401399
# [00:32:28] [worker #1] Bootstrap tree #263, logLikelihood: -17871.173001
# [00:32:36] [worker #2] Bootstrap tree #267, logLikelihood: -18973.435463
# [00:32:43] [worker #0] Bootstrap tree #265, logLikelihood: -18410.072336
# [00:32:53] [worker #1] Bootstrap tree #266, logLikelihood: -17503.901030
# [00:33:02] [worker #0] Bootstrap tree #268, logLikelihood: -18397.151188
# [00:33:04] [worker #2] Bootstrap tree #270, logLikelihood: -18296.532241
# [00:33:18] [worker #1] Bootstrap tree #269, logLikelihood: -18054.029436
# [00:33:19] [worker #0] Bootstrap tree #271, logLikelihood: -18097.946634
# [00:33:37] [worker #2] Bootstrap tree #273, logLikelihood: -17251.684564
# [00:33:37] [worker #0] Bootstrap tree #274, logLikelihood: -18091.634378
# [00:33:38] [worker #1] Bootstrap tree #272, logLikelihood: -17951.269455
# [00:33:55] [worker #2] Bootstrap tree #276, logLikelihood: -18782.483133
# [00:33:57] [worker #0] Bootstrap tree #277, logLikelihood: -17560.373326
# [00:34:06] [worker #1] Bootstrap tree #275, logLikelihood: -18187.871565
# [00:34:17] [worker #2] Bootstrap tree #279, logLikelihood: -18167.753620
# [00:34:21] [worker #0] Bootstrap tree #280, logLikelihood: -17851.099038
# [00:34:23] [worker #1] Bootstrap tree #278, logLikelihood: -18220.269269
# [00:34:36] [worker #2] Bootstrap tree #282, logLikelihood: -17853.984982
# [00:34:43] [worker #0] Bootstrap tree #283, logLikelihood: -18387.432587
# [00:34:43] [worker #1] Bootstrap tree #281, logLikelihood: -18124.085446
# [00:34:52] [worker #2] Bootstrap tree #285, logLikelihood: -17933.522893
# [00:34:59] [worker #0] Bootstrap tree #286, logLikelihood: -18304.418423
# [00:35:11] [worker #1] Bootstrap tree #284, logLikelihood: -18644.177128
# [00:35:11] [worker #2] Bootstrap tree #288, logLikelihood: -17594.964550
# [00:35:18] [worker #0] Bootstrap tree #289, logLikelihood: -18958.315704
# [00:35:28] [worker #2] Bootstrap tree #291, logLikelihood: -18225.161300
# [00:35:35] [worker #0] Bootstrap tree #292, logLikelihood: -17729.096709
# [00:35:38] [worker #1] Bootstrap tree #287, logLikelihood: -17372.186380
# [00:35:46] [worker #2] Bootstrap tree #294, logLikelihood: -18131.337620
# [00:35:57] [worker #1] Bootstrap tree #290, logLikelihood: -18143.915412
# [00:35:57] [worker #0] Bootstrap tree #295, logLikelihood: -17890.524148
# [00:36:05] [worker #2] Bootstrap tree #297, logLikelihood: -16375.106536
# [00:36:14] [worker #1] Bootstrap tree #293, logLikelihood: -17358.087961
# [00:36:23] [worker #0] Bootstrap tree #298, logLikelihood: -17981.580410
# [00:36:25] [worker #2] Bootstrap tree #300, logLikelihood: -18043.090710
# [00:36:40] [worker #1] Bootstrap tree #296, logLikelihood: -17796.954025
# [00:37:11] [worker #1] Bootstrap tree #299, logLikelihood: -18074.745057
# [00:37:28] [worker #2] Bootstrap tree #303, logLikelihood: -16978.171536
# [00:37:30] [worker #0] Bootstrap tree #301, logLikelihood: -15580.511061
# [00:37:31] [worker #1] Bootstrap tree #302, logLikelihood: -17311.123521
# [00:37:47] [worker #2] Bootstrap tree #306, logLikelihood: -16815.292577
# [00:37:48] [worker #1] Bootstrap tree #305, logLikelihood: -18186.986738
# [00:37:50] [worker #0] Bootstrap tree #304, logLikelihood: -18138.974805
# [00:38:02] [worker #2] Bootstrap tree #309, logLikelihood: -17996.815119
# [00:38:04] [worker #1] Bootstrap tree #308, logLikelihood: -17287.329040
# [00:38:09] [worker #0] Bootstrap tree #307, logLikelihood: -17686.330886
# [00:38:21] [worker #1] Bootstrap tree #311, logLikelihood: -18401.113918
# [00:38:23] [worker #2] Bootstrap tree #312, logLikelihood: -17764.180942
# [00:38:30] [worker #0] Bootstrap tree #310, logLikelihood: -18636.580202
# [00:38:40] [worker #1] Bootstrap tree #314, logLikelihood: -17658.361929
# [00:38:48] [worker #0] Bootstrap tree #313, logLikelihood: -17922.551064
# [00:38:49] [worker #2] Bootstrap tree #315, logLikelihood: -18254.983732
# [00:39:06] [worker #2] Bootstrap tree #318, logLikelihood: -17827.132768
# [00:39:12] [worker #1] Bootstrap tree #317, logLikelihood: -17735.874866
# [00:39:14] [worker #0] Bootstrap tree #316, logLikelihood: -18273.327088
# [00:39:30] [worker #1] Bootstrap tree #320, logLikelihood: -18497.626600
# [00:39:31] [worker #2] Bootstrap tree #321, logLikelihood: -17065.459940
# [00:39:34] [worker #0] Bootstrap tree #319, logLikelihood: -17279.466066
# [00:39:49] [worker #1] Bootstrap tree #323, logLikelihood: -17088.822380
# [00:39:51] [worker #2] Bootstrap tree #324, logLikelihood: -17643.832220
# [00:39:53] [worker #0] Bootstrap tree #322, logLikelihood: -17922.751053
# [00:40:14] [worker #1] Bootstrap tree #326, logLikelihood: -17008.945560
# [00:40:18] [worker #0] Bootstrap tree #325, logLikelihood: -17323.263739
# [00:40:26] [worker #2] Bootstrap tree #327, logLikelihood: -17329.322540
# [00:40:30] [worker #1] Bootstrap tree #329, logLikelihood: -17520.144686
# [00:40:38] [worker #0] Bootstrap tree #328, logLikelihood: -16614.518656
# [00:40:48] [worker #2] Bootstrap tree #330, logLikelihood: -18737.588947
# [00:40:55] [worker #1] Bootstrap tree #332, logLikelihood: -17624.676554
# [00:41:08] [worker #0] Bootstrap tree #331, logLikelihood: -19203.743241
# [00:41:10] [worker #2] Bootstrap tree #333, logLikelihood: -17641.064381
# [00:41:19] [worker #1] Bootstrap tree #335, logLikelihood: -16154.328363
# [00:41:24] [worker #0] Bootstrap tree #334, logLikelihood: -16989.312432
# [00:41:28] [worker #2] Bootstrap tree #336, logLikelihood: -18184.369446
# [00:41:44] [worker #0] Bootstrap tree #337, logLikelihood: -17303.496454
# [00:41:45] [worker #1] Bootstrap tree #338, logLikelihood: -18481.718557
# [00:42:01] [worker #0] Bootstrap tree #340, logLikelihood: -16696.758906
# [00:42:02] [worker #1] Bootstrap tree #341, logLikelihood: -17021.039018
# [00:42:15] [worker #2] Bootstrap tree #339, logLikelihood: -17594.106845
# [00:42:19] [worker #0] Bootstrap tree #343, logLikelihood: -17622.558806
# [00:42:21] [worker #1] Bootstrap tree #344, logLikelihood: -18328.774726
# [00:42:37] [worker #2] Bootstrap tree #342, logLikelihood: -17647.261631
# [00:42:37] [worker #0] Bootstrap tree #346, logLikelihood: -17497.874234
# [00:42:41] [worker #1] Bootstrap tree #347, logLikelihood: -17286.942576
# [00:42:55] [worker #2] Bootstrap tree #345, logLikelihood: -16994.873726
# [00:42:59] [worker #0] Bootstrap tree #349, logLikelihood: -17612.181940
# [00:42:59] [worker #1] Bootstrap tree #350, logLikelihood: -18212.486362
# [00:43:12] [worker #2] Bootstrap tree #348, logLikelihood: -17670.479569
# [00:43:31] [worker #0] Bootstrap tree #352, logLikelihood: -17737.125384
# [00:43:37] [worker #1] Bootstrap tree #353, logLikelihood: -16956.557953
# [00:43:42] [worker #2] Bootstrap tree #351, logLikelihood: -18255.865653
# [00:43:49] [worker #0] Bootstrap tree #355, logLikelihood: -17577.503933
# [00:43:57] [worker #1] Bootstrap tree #356, logLikelihood: -16363.470519
# [00:44:09] [worker #2] Bootstrap tree #354, logLikelihood: -17891.890602
# [00:44:16] [worker #0] Bootstrap tree #358, logLikelihood: -18471.217524
# [00:44:17] [worker #1] Bootstrap tree #359, logLikelihood: -17921.830666
# [00:44:34] [worker #1] Bootstrap tree #362, logLikelihood: -17060.235815
# [00:44:37] [worker #0] Bootstrap tree #361, logLikelihood: -18576.387849
# [00:44:42] [worker #2] Bootstrap tree #357, logLikelihood: -18414.996903
# [00:44:54] [worker #0] Bootstrap tree #364, logLikelihood: -17853.837940
# [00:44:56] [worker #1] Bootstrap tree #365, logLikelihood: -17869.033144
# [00:44:59] [worker #2] Bootstrap tree #360, logLikelihood: -17759.974818
# [00:45:14] [worker #0] Bootstrap tree #367, logLikelihood: -18554.298961
# [00:45:22] [worker #2] Bootstrap tree #363, logLikelihood: -18299.154861
# [00:45:24] [worker #1] Bootstrap tree #368, logLikelihood: -18193.573113
# [00:45:35] [worker #0] Bootstrap tree #370, logLikelihood: -16832.196023
# [00:45:40] [worker #1] Bootstrap tree #371, logLikelihood: -18348.452419
# [00:45:42] [worker #2] Bootstrap tree #366, logLikelihood: -17731.481685
# [00:45:54] [worker #0] Bootstrap tree #373, logLikelihood: -18409.249509
# [00:45:59] [worker #1] Bootstrap tree #374, logLikelihood: -17483.578695
# [00:46:02] [worker #2] Bootstrap tree #369, logLikelihood: -16909.778786
# [00:46:13] [worker #0] Bootstrap tree #376, logLikelihood: -17702.952189
# [00:46:22] [worker #2] Bootstrap tree #372, logLikelihood: -18476.557623
# [00:46:26] [worker #1] Bootstrap tree #377, logLikelihood: -16904.469487
# [00:46:31] [worker #0] Bootstrap tree #379, logLikelihood: -17346.809899
# [00:46:43] [worker #2] Bootstrap tree #375, logLikelihood: -18603.702848
# [00:46:49] [worker #0] Bootstrap tree #382, logLikelihood: -18023.981273
# [00:46:50] [worker #1] Bootstrap tree #380, logLikelihood: -17855.079041
# [00:47:06] [worker #0] Bootstrap tree #385, logLikelihood: -18139.141587
# [00:47:07] [worker #1] Bootstrap tree #383, logLikelihood: -18012.629806
# [00:47:07] [worker #2] Bootstrap tree #378, logLikelihood: -17703.469546
# [00:47:25] [worker #2] Bootstrap tree #381, logLikelihood: -18551.385650
# [00:47:26] [worker #1] Bootstrap tree #386, logLikelihood: -17904.759731
# [00:47:37] [worker #0] Bootstrap tree #388, logLikelihood: -18204.014562
# [00:47:44] [worker #2] Bootstrap tree #384, logLikelihood: -18055.148830
# [00:47:45] [worker #1] Bootstrap tree #389, logLikelihood: -17674.703984
# [00:48:01] [worker #0] Bootstrap tree #391, logLikelihood: -18229.329342
# [00:48:03] [worker #2] Bootstrap tree #387, logLikelihood: -17535.752938
# [00:48:09] [worker #1] Bootstrap tree #392, logLikelihood: -17309.574629
# [00:48:19] [worker #0] Bootstrap tree #394, logLikelihood: -17758.818517
# [00:48:20] [worker #2] Bootstrap tree #390, logLikelihood: -17662.671739
# [00:48:36] [worker #0] Bootstrap tree #397, logLikelihood: -18580.542540
# [00:48:37] [worker #1] Bootstrap tree #395, logLikelihood: -17764.250181
# [00:48:37] [worker #2] Bootstrap tree #393, logLikelihood: -18563.497416
# [00:48:55] [worker #1] Bootstrap tree #398, logLikelihood: -17807.516529
# [00:48:57] [worker #0] Bootstrap tree #400, logLikelihood: -17665.201137
# [00:49:06] [worker #2] Bootstrap tree #396, logLikelihood: -17385.476569
# [00:49:28] [worker #2] Bootstrap tree #399, logLikelihood: -17882.660588
# [00:49:48] [worker #1] Bootstrap tree #401, logLikelihood: -17169.819993
# [00:49:49] [worker #0] Bootstrap tree #403, logLikelihood: -17805.855293
# [00:50:02] [worker #2] Bootstrap tree #402, logLikelihood: -18602.341050
# [00:50:06] [worker #1] Bootstrap tree #404, logLikelihood: -17670.854263
# [00:50:14] [worker #0] Bootstrap tree #406, logLikelihood: -17713.305487
# [00:50:21] [worker #2] Bootstrap tree #405, logLikelihood: -18020.245495
# [00:50:25] [worker #1] Bootstrap tree #407, logLikelihood: -17906.495098
# [00:50:32] [worker #0] Bootstrap tree #409, logLikelihood: -18200.735659
# [00:50:40] [worker #2] Bootstrap tree #408, logLikelihood: -18213.409514
# [00:50:50] [worker #1] Bootstrap tree #410, logLikelihood: -17763.465875
# [00:50:55] [worker #0] Bootstrap tree #412, logLikelihood: -17518.553160
# [00:50:58] [worker #2] Bootstrap tree #411, logLikelihood: -17187.085906
# [00:51:11] [worker #1] Bootstrap tree #413, logLikelihood: -17732.605845
# [00:51:15] [worker #0] Bootstrap tree #415, logLikelihood: -18301.395188
# [00:51:16] [worker #2] Bootstrap tree #414, logLikelihood: -18548.990956
# [00:51:35] [worker #0] Bootstrap tree #418, logLikelihood: -17154.309897
# [00:51:37] [worker #1] Bootstrap tree #416, logLikelihood: -17814.982553
# [00:51:43] [worker #2] Bootstrap tree #417, logLikelihood: -18413.025074
# [00:52:01] [worker #1] Bootstrap tree #419, logLikelihood: -18287.758764
# [00:52:01] [worker #2] Bootstrap tree #420, logLikelihood: -17009.715928
# [00:52:02] [worker #0] Bootstrap tree #421, logLikelihood: -17232.823575
# [00:52:19] [worker #0] Bootstrap tree #424, logLikelihood: -17474.587614
# [00:52:20] [worker #1] Bootstrap tree #422, logLikelihood: -17439.038558
# [00:52:20] [worker #2] Bootstrap tree #423, logLikelihood: -17136.818378
# [00:52:34] [worker #0] Bootstrap tree #427, logLikelihood: -16619.345059
# [00:52:37] [worker #1] Bootstrap tree #425, logLikelihood: -16970.218082
# [00:52:47] [worker #2] Bootstrap tree #426, logLikelihood: -18991.497100
# [00:52:55] [worker #1] Bootstrap tree #428, logLikelihood: -16930.386075
# [00:52:57] [worker #0] Bootstrap tree #430, logLikelihood: -18040.385884
# [00:53:06] [worker #2] Bootstrap tree #429, logLikelihood: -17733.188095
# [00:53:15] [worker #0] Bootstrap tree #433, logLikelihood: -18313.027342
# [00:53:16] [worker #1] Bootstrap tree #431, logLikelihood: -17959.088282
# [00:53:25] [worker #2] Bootstrap tree #432, logLikelihood: -18185.946379
# [00:53:35] [worker #1] Bootstrap tree #434, logLikelihood: -16896.623675
# [00:53:36] [worker #0] Bootstrap tree #436, logLikelihood: -18670.736347
# [00:53:41] [worker #2] Bootstrap tree #435, logLikelihood: -17503.071729
# [00:53:53] [worker #0] Bootstrap tree #439, logLikelihood: -16592.881887
# [00:53:53] [worker #1] Bootstrap tree #437, logLikelihood: -17769.839990
# [00:53:58] [worker #2] Bootstrap tree #438, logLikelihood: -18349.889978
# [00:54:12] [worker #1] Bootstrap tree #440, logLikelihood: -18159.577178
# [00:54:12] [worker #0] Bootstrap tree #442, logLikelihood: -17745.186558
# [00:54:18] [worker #2] Bootstrap tree #441, logLikelihood: -16582.493300
# [00:54:30] [worker #0] Bootstrap tree #445, logLikelihood: -18736.003442
# [00:54:35] [worker #1] Bootstrap tree #443, logLikelihood: -17370.403539
# [00:54:44] [worker #2] Bootstrap tree #444, logLikelihood: -17941.569560
# [00:54:49] [worker #0] Bootstrap tree #448, logLikelihood: -17548.139335
# [00:55:01] [worker #2] Bootstrap tree #447, logLikelihood: -18128.508542
# [00:55:06] [worker #1] Bootstrap tree #446, logLikelihood: -17981.170188
# [00:55:20] [worker #2] Bootstrap tree #450, logLikelihood: -17529.621837
# [00:55:29] [worker #1] Bootstrap tree #449, logLikelihood: -18857.380626
# [00:55:46] [worker #0] Bootstrap tree #451, logLikelihood: -17074.233968
# [00:55:46] [worker #1] Bootstrap tree #452, logLikelihood: -18060.655924
# [00:55:49] [worker #2] Bootstrap tree #453, logLikelihood: -18141.801353
# [00:56:05] [worker #1] Bootstrap tree #455, logLikelihood: -17595.346283
# [00:56:09] [worker #0] Bootstrap tree #454, logLikelihood: -17136.242216
# [00:56:11] [worker #2] Bootstrap tree #456, logLikelihood: -17889.761682
# [00:56:23] [worker #1] Bootstrap tree #458, logLikelihood: -17723.938446
# [00:56:28] [worker #0] Bootstrap tree #457, logLikelihood: -18180.862300
# [00:56:29] [worker #2] Bootstrap tree #459, logLikelihood: -19240.534626
# [00:56:40] [worker #1] Bootstrap tree #461, logLikelihood: -16951.061653
# [00:56:46] [worker #0] Bootstrap tree #460, logLikelihood: -16588.594518
# [00:56:48] [worker #2] Bootstrap tree #462, logLikelihood: -17031.500749
# [00:57:03] [worker #1] Bootstrap tree #464, logLikelihood: -17346.196780
# [00:57:06] [worker #2] Bootstrap tree #465, logLikelihood: -17320.195562
# [00:57:11] [worker #0] Bootstrap tree #463, logLikelihood: -17646.692521
# [00:57:22] [worker #1] Bootstrap tree #467, logLikelihood: -18048.326759
# [00:57:24] [worker #2] Bootstrap tree #468, logLikelihood: -17416.723150
# [00:57:35] [worker #0] Bootstrap tree #466, logLikelihood: -17640.762449
# [00:57:42] [worker #1] Bootstrap tree #470, logLikelihood: -18304.527519
# [00:57:44] [worker #2] Bootstrap tree #471, logLikelihood: -17855.114431
# [00:57:54] [worker #0] Bootstrap tree #469, logLikelihood: -16689.184598
# [00:58:01] [worker #1] Bootstrap tree #473, logLikelihood: -16730.186563
# [00:58:02] [worker #2] Bootstrap tree #474, logLikelihood: -16662.993993
# [00:58:17] [worker #1] Bootstrap tree #476, logLikelihood: -18288.758041
# [00:58:20] [worker #2] Bootstrap tree #477, logLikelihood: -17452.632595
# [00:58:23] [worker #0] Bootstrap tree #472, logLikelihood: -17406.071826
# [00:58:44] [worker #2] Bootstrap tree #480, logLikelihood: -17717.441647
# [00:58:45] [worker #1] Bootstrap tree #479, logLikelihood: -18051.737647
# [00:58:52] [worker #0] Bootstrap tree #475, logLikelihood: -17673.786773
# [00:59:00] [worker #2] Bootstrap tree #483, logLikelihood: -18430.935698
# [00:59:07] [worker #1] Bootstrap tree #482, logLikelihood: -17738.979967
# [00:59:09] [worker #0] Bootstrap tree #478, logLikelihood: -18952.239077
# [00:59:16] [worker #2] Bootstrap tree #486, logLikelihood: -17417.066898
# [00:59:27] [worker #1] Bootstrap tree #485, logLikelihood: -17434.995667
# [00:59:28] [worker #0] Bootstrap tree #481, logLikelihood: -18072.858357
# [00:59:34] [worker #2] Bootstrap tree #489, logLikelihood: -18114.379296
# [00:59:48] [worker #0] Bootstrap tree #484, logLikelihood: -17595.624170
# [00:59:49] [worker #1] Bootstrap tree #488, logLikelihood: -17043.729994
# [00:59:55] [worker #2] Bootstrap tree #492, logLikelihood: -17462.398317
# [01:00:07] [worker #1] Bootstrap tree #491, logLikelihood: -19137.411660
# [01:00:10] [worker #0] Bootstrap tree #487, logLikelihood: -17483.001441
# [01:00:19] [worker #2] Bootstrap tree #495, logLikelihood: -17349.072895
# [01:00:23] [worker #1] Bootstrap tree #494, logLikelihood: -18399.083412
# [01:00:29] [worker #0] Bootstrap tree #490, logLikelihood: -18497.033405
# [01:00:41] [worker #2] Bootstrap tree #498, logLikelihood: -18171.862647
# [01:00:42] [worker #1] Bootstrap tree #497, logLikelihood: -17717.508371
# [01:00:46] [worker #0] Bootstrap tree #493, logLikelihood: -16817.774456
# [01:01:00] [worker #1] Bootstrap tree #500, logLikelihood: -16240.137168
# [01:01:11] [worker #0] Bootstrap tree #496, logLikelihood: -17391.588292
# [01:01:26] [worker #0] Bootstrap tree #499, logLikelihood: -18262.578227
# [01:01:45] [worker #0] Bootstrap tree #502, logLikelihood: -18301.946904
# [01:01:45] [worker #1] Bootstrap tree #503, logLikelihood: -18707.526828
# [01:01:49] [worker #2] Bootstrap tree #501, logLikelihood: -18572.928940
# [01:02:06] [worker #2] Bootstrap tree #504, logLikelihood: -17601.604378
# [01:02:06] [worker #1] Bootstrap tree #506, logLikelihood: -18443.240554
# [01:02:08] [worker #0] Bootstrap tree #505, logLikelihood: -16847.804885
# [01:02:26] [worker #0] Bootstrap tree #508, logLikelihood: -17241.720317
# [01:02:26] [worker #2] Bootstrap tree #507, logLikelihood: -17256.905466
# [01:02:30] [worker #1] Bootstrap tree #509, logLikelihood: -18856.723893
# [01:02:45] [worker #0] Bootstrap tree #511, logLikelihood: -18564.210616
# [01:02:47] [worker #1] Bootstrap tree #512, logLikelihood: -18717.857939
# [01:02:51] [worker #2] Bootstrap tree #510, logLikelihood: -17384.731108
# [01:03:07] [worker #2] Bootstrap tree #513, logLikelihood: -18310.748504
# [01:03:12] [worker #0] Bootstrap tree #514, logLikelihood: -17416.613673
# [01:03:17] [worker #1] Bootstrap tree #515, logLikelihood: -18580.758691
# [01:03:31] [worker #0] Bootstrap tree #517, logLikelihood: -17248.758336
# [01:03:36] [worker #2] Bootstrap tree #516, logLikelihood: -18511.697593
# [01:03:38] [worker #1] Bootstrap tree #518, logLikelihood: -17159.078317
# [01:03:49] [worker #0] Bootstrap tree #520, logLikelihood: -18918.918512
# [01:04:00] [worker #2] Bootstrap tree #519, logLikelihood: -18814.572208
# [01:04:06] [worker #1] Bootstrap tree #521, logLikelihood: -17158.559930
# [01:04:17] [worker #0] Bootstrap tree #523, logLikelihood: -17987.841282
# [01:04:19] [worker #2] Bootstrap tree #522, logLikelihood: -18327.509807
# [01:04:24] [worker #1] Bootstrap tree #524, logLikelihood: -17649.324154
# [01:04:36] [worker #0] Bootstrap tree #526, logLikelihood: -17249.069654
# [01:04:39] [worker #2] Bootstrap tree #525, logLikelihood: -17041.108685
# [01:04:45] [worker #1] Bootstrap tree #527, logLikelihood: -17895.687770
# [01:04:52] [worker #0] Bootstrap tree #529, logLikelihood: -17722.702893
# [01:05:04] [worker #2] Bootstrap tree #528, logLikelihood: -17807.134366
# [01:05:06] [worker #1] Bootstrap tree #530, logLikelihood: -16575.884073
# [01:05:10] [worker #0] Bootstrap tree #532, logLikelihood: -18623.988904
# [01:05:22] [worker #2] Bootstrap tree #531, logLikelihood: -17989.938896
# [01:05:22] [worker #1] Bootstrap tree #533, logLikelihood: -17789.781837
# [01:05:33] [worker #0] Bootstrap tree #535, logLikelihood: -17144.438532
# [01:05:40] [worker #1] Bootstrap tree #536, logLikelihood: -17484.064905
# [01:05:43] [worker #2] Bootstrap tree #534, logLikelihood: -17072.563485
# [01:05:51] [worker #0] Bootstrap tree #538, logLikelihood: -17710.371189
# [01:05:57] [worker #1] Bootstrap tree #539, logLikelihood: -17695.960660
# [01:06:09] [worker #2] Bootstrap tree #537, logLikelihood: -18256.716784
# [01:06:13] [worker #0] Bootstrap tree #541, logLikelihood: -17768.495208
# [01:06:14] [worker #1] Bootstrap tree #542, logLikelihood: -17248.386859
# [01:06:25] [worker #2] Bootstrap tree #540, logLikelihood: -17064.185830
# [01:06:31] [worker #1] Bootstrap tree #545, logLikelihood: -18754.443524
# [01:06:36] [worker #0] Bootstrap tree #544, logLikelihood: -16422.120350
# [01:06:45] [worker #2] Bootstrap tree #543, logLikelihood: -18136.261682
# [01:06:49] [worker #1] Bootstrap tree #548, logLikelihood: -17268.840834
# [01:06:53] [worker #0] Bootstrap tree #547, logLikelihood: -17790.702749
# [01:07:06] [worker #2] Bootstrap tree #546, logLikelihood: -17152.853263
# [01:07:15] [worker #0] Bootstrap tree #550, logLikelihood: -17754.179451
# [01:07:30] [worker #2] Bootstrap tree #549, logLikelihood: -17629.805129
# [01:07:50] [worker #2] Bootstrap tree #552, logLikelihood: -17241.007975
# [01:07:51] [worker #0] Bootstrap tree #553, logLikelihood: -17665.377225
# [01:07:57] [worker #1] Bootstrap tree #551, logLikelihood: -17685.168326
# [01:08:06] [worker #2] Bootstrap tree #555, logLikelihood: -16479.209533
# [01:08:09] [worker #0] Bootstrap tree #556, logLikelihood: -17371.088636
# [01:08:16] [worker #1] Bootstrap tree #554, logLikelihood: -18383.059765
# [01:08:22] [worker #2] Bootstrap tree #558, logLikelihood: -17496.332046
# [01:08:26] [worker #0] Bootstrap tree #559, logLikelihood: -17535.197718
# [01:08:34] [worker #1] Bootstrap tree #557, logLikelihood: -16827.781873
# [01:08:44] [worker #0] Bootstrap tree #562, logLikelihood: -17560.632545
# [01:08:45] [worker #2] Bootstrap tree #561, logLikelihood: -17168.718321
# [01:08:59] [worker #1] Bootstrap tree #560, logLikelihood: -17808.118216
# [01:09:03] [worker #0] Bootstrap tree #565, logLikelihood: -18778.628614
# [01:09:04] [worker #2] Bootstrap tree #564, logLikelihood: -17854.690890
# [01:09:16] [worker #1] Bootstrap tree #563, logLikelihood: -17152.060707
# [01:09:21] [worker #0] Bootstrap tree #568, logLikelihood: -17569.805195
# [01:09:28] [worker #2] Bootstrap tree #567, logLikelihood: -16745.280737
# [01:09:38] [worker #1] Bootstrap tree #566, logLikelihood: -18439.784305
# [01:09:40] [worker #0] Bootstrap tree #571, logLikelihood: -18038.816626
# [01:09:51] [worker #2] Bootstrap tree #570, logLikelihood: -18556.732583
# [01:09:56] [worker #1] Bootstrap tree #569, logLikelihood: -17471.632087
# [01:09:59] [worker #0] Bootstrap tree #574, logLikelihood: -18570.908891
# [01:10:08] [worker #2] Bootstrap tree #573, logLikelihood: -17574.263631
# [01:10:17] [worker #0] Bootstrap tree #577, logLikelihood: -18440.486122
# [01:10:20] [worker #1] Bootstrap tree #572, logLikelihood: -17753.597670
# [01:10:26] [worker #2] Bootstrap tree #576, logLikelihood: -18261.657700
# [01:10:36] [worker #0] Bootstrap tree #580, logLikelihood: -18304.045896
# [01:10:39] [worker #1] Bootstrap tree #575, logLikelihood: -16681.403030
# [01:10:45] [worker #2] Bootstrap tree #579, logLikelihood: -17869.782010
# [01:10:56] [worker #1] Bootstrap tree #578, logLikelihood: -16877.671694
# [01:10:58] [worker #0] Bootstrap tree #583, logLikelihood: -18461.330381
# [01:11:03] [worker #2] Bootstrap tree #582, logLikelihood: -18562.075502
# [01:11:15] [worker #1] Bootstrap tree #581, logLikelihood: -16475.662250
# [01:11:22] [worker #0] Bootstrap tree #586, logLikelihood: -17656.375013
# [01:11:25] [worker #2] Bootstrap tree #585, logLikelihood: -17497.065233
# [01:11:35] [worker #1] Bootstrap tree #584, logLikelihood: -17916.624214
# [01:11:40] [worker #0] Bootstrap tree #589, logLikelihood: -18323.290540
# [01:11:43] [worker #2] Bootstrap tree #588, logLikelihood: -17426.864541
# [01:11:55] [worker #1] Bootstrap tree #587, logLikelihood: -18556.950369
# [01:12:07] [worker #2] Bootstrap tree #591, logLikelihood: -17813.003745
# [01:12:09] [worker #0] Bootstrap tree #592, logLikelihood: -18095.133868
# [01:12:13] [worker #1] Bootstrap tree #590, logLikelihood: -17827.445956
# [01:12:25] [worker #0] Bootstrap tree #595, logLikelihood: -16834.875307
# [01:12:26] [worker #2] Bootstrap tree #594, logLikelihood: -19185.025679
# [01:12:39] [worker #1] Bootstrap tree #593, logLikelihood: -17874.498957
# [01:12:46] [worker #2] Bootstrap tree #597, logLikelihood: -17796.585021
# [01:12:50] [worker #0] Bootstrap tree #598, logLikelihood: -18495.882825
# [01:12:57] [worker #1] Bootstrap tree #596, logLikelihood: -18131.528558
# [01:13:04] [worker #2] Bootstrap tree #600, logLikelihood: -17375.821424
# [01:13:23] [worker #1] Bootstrap tree #599, logLikelihood: -19206.338930
# [01:13:40] [worker #0] Bootstrap tree #601, logLikelihood: -16882.932234
# [01:13:42] [worker #1] Bootstrap tree #602, logLikelihood: -18314.322532
# [01:13:42] [worker #2] Bootstrap tree #603, logLikelihood: -18220.156994
# [01:13:59] [worker #2] Bootstrap tree #606, logLikelihood: -16737.418877
# [01:14:03] [worker #0] Bootstrap tree #604, logLikelihood: -18972.055953
# [01:14:06] [worker #1] Bootstrap tree #605, logLikelihood: -16997.708570
# [01:14:16] [worker #2] Bootstrap tree #609, logLikelihood: -17102.051088
# [01:14:21] [worker #0] Bootstrap tree #607, logLikelihood: -17573.535332
# [01:14:26] [worker #1] Bootstrap tree #608, logLikelihood: -17903.030596
# [01:14:34] [worker #2] Bootstrap tree #612, logLikelihood: -17079.329296
# [01:14:47] [worker #0] Bootstrap tree #610, logLikelihood: -17766.033389
# [01:14:52] [worker #1] Bootstrap tree #611, logLikelihood: -18262.831805
# [01:15:03] [worker #2] Bootstrap tree #615, logLikelihood: -17280.794361
# [01:15:07] [worker #0] Bootstrap tree #613, logLikelihood: -17026.363596
# [01:15:14] [worker #1] Bootstrap tree #614, logLikelihood: -17263.112502
# [01:15:23] [worker #0] Bootstrap tree #616, logLikelihood: -17196.989035
# [01:15:26] [worker #2] Bootstrap tree #618, logLikelihood: -17169.526259
# [01:15:31] [worker #1] Bootstrap tree #617, logLikelihood: -17531.640195
# [01:15:40] [worker #0] Bootstrap tree #619, logLikelihood: -18222.515911
# [01:15:45] [worker #2] Bootstrap tree #621, logLikelihood: -17359.323120
# [01:15:52] [worker #1] Bootstrap tree #620, logLikelihood: -17002.768178
# [01:16:01] [worker #2] Bootstrap tree #624, logLikelihood: -17894.330654
# [01:16:01] [worker #0] Bootstrap tree #622, logLikelihood: -18155.276650
# [01:16:11] [worker #1] Bootstrap tree #623, logLikelihood: -17358.475962
# [01:16:20] [worker #0] Bootstrap tree #625, logLikelihood: -17157.860775
# [01:16:21] [worker #2] Bootstrap tree #627, logLikelihood: -17078.815448
# [01:16:36] [worker #1] Bootstrap tree #626, logLikelihood: -17659.333020
# [01:16:38] [worker #0] Bootstrap tree #628, logLikelihood: -18349.981742
# [01:16:42] [worker #2] Bootstrap tree #630, logLikelihood: -17405.217525
# [01:16:54] [worker #1] Bootstrap tree #629, logLikelihood: -17533.997541
# [01:17:03] [worker #0] Bootstrap tree #631, logLikelihood: -18697.493021
# [01:17:07] [worker #2] Bootstrap tree #633, logLikelihood: -18568.315988
# [01:17:14] [worker #1] Bootstrap tree #632, logLikelihood: -17732.246261
# [01:17:27] [worker #2] Bootstrap tree #636, logLikelihood: -17309.749156
# [01:17:29] [worker #0] Bootstrap tree #634, logLikelihood: -18174.772412
# [01:17:32] [worker #1] Bootstrap tree #635, logLikelihood: -17396.550497
# [01:17:43] [worker #2] Bootstrap tree #639, logLikelihood: -18382.382450
# [01:17:46] [worker #0] Bootstrap tree #637, logLikelihood: -17974.194326
# [01:17:48] [worker #1] Bootstrap tree #638, logLikelihood: -16899.021296
# [01:18:03] [worker #0] Bootstrap tree #640, logLikelihood: -17090.670500
# [01:18:03] [worker #2] Bootstrap tree #642, logLikelihood: -18137.697673
# [01:18:10] [worker #1] Bootstrap tree #641, logLikelihood: -18236.599893
# [01:18:23] [worker #0] Bootstrap tree #643, logLikelihood: -18133.785386
# [01:18:27] [worker #2] Bootstrap tree #645, logLikelihood: -17343.411186
# [01:18:27] [worker #1] Bootstrap tree #644, logLikelihood: -17881.479794
# [01:18:48] [worker #2] Bootstrap tree #648, logLikelihood: -17371.547346
# [01:18:53] [worker #0] Bootstrap tree #646, logLikelihood: -17655.639406
# [01:18:57] [worker #1] Bootstrap tree #647, logLikelihood: -17577.788637
# [01:19:10] [worker #0] Bootstrap tree #649, logLikelihood: -17568.223947
# [01:19:14] [worker #1] Bootstrap tree #650, logLikelihood: -17501.238469
# [01:19:16] Bootstrapping converged after 650 replicates.
#
# Bootstrap trees saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_gblocks.raxml.bootstraps
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_gblocks.raxml.log
#
# Analysis started: 07-Dec-2023 19:50:15 / finished: 07-Dec-2023 21:09:32
#
# Elapsed time: 4756.533 seconds
#
#
# Output files were moved to: ../results/phyl_trees/refrence_alignment_tree/T3_gblocks
# 0

# %% [markdown]
# ### Computing branch support

# %% [markdown]
# # Tree visualisation

# %%
tree_path

# %%
# Variables
tree_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'T2_gblocks_strong', 'T2.raxml.bestTree')
alignment_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
os.environ['QT_QPA_PLATFORM'] = 'offscreen'

# %%
# Creating name_mapping dictionary to rename the new sequences in the tree

name_mapping = {}

with open(alignment_path, 'r') as f:
    for line in f:
        # Reference sequences part
        if line.startswith('>') and 'Vampyrellida' in line:
            old_name = line.strip('>').strip()
            new_name = line.split('|')[-1].strip()
            id = line.split('|')[0].strip('>').strip()
            name_mapping[old_name] = new_name + '_' + id
        # New environmental sequences part
        elif line.startswith('>') and 'centroid' in line:
            old_name = line.strip('>').strip()
            seq_name = line.split('=')[1].strip('_seqs')
            sample_name = line.split('_')[-1].strip()
            new_name = 'env_otu_' + seq_name + '_' + sample_name
            name_mapping[old_name] = new_name

# %% [markdown]
# ### Create inner nodes

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()

# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree

# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = "internal_node_{}".format(i)
        i += 1

# for node in tree.traverse():
#     print(node.name)

# # Apply the renaming directly to the leaves of the tree
# for leaf in tree.iter_leaves():
#     if leaf.name in name_mapping:
#         leaf.name = name_mapping[leaf.name]

# Styling
ts.show_leaf_name = True # display leaf names

# Hides the node circles
for node in tree.traverse():
    node.img_style["size"] = 0

# Add node names/IDs
for n in tree.traverse():
    # Create a face to display node name/ID
    name_face = TextFace(n.name, fsize=10, fgcolor='black')
    n.add_face(name_face, column=0, position="branch-top")

tree.render(os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'tree_inner_nodes_gblocks_strong.png'), dpi=300, w=10000, tree_style=ts)
tree.render('%%inline', tree_style=ts)

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()
# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree

# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = 'internal_node_{}'.format(i)
        i += 1


# Find the node you want to use as the new root
node_to_reroot = tree&'internal_node_20'  # Replace 'Node_Name' with the name of your desired node

# Use the assigned name to reroot
tree.set_outgroup(node_to_reroot)

# # Identify the node whose children you want to swap
node_to_swap_1 = tree&'internal_node_0'  
node_to_swap_2 = tree&'internal_node_12'
# node_to_swap_3 = tree&'internal_node_68'
# node_to_swap_4 = tree&'internal_node_64'
# node_to_swap_5 = tree&'internal_node_72'

# # Swap the children of the target node
node_to_swap_1.swap_children()
node_to_swap_2.swap_children()
# node_to_swap_3.swap_children()
# node_to_swap_4.swap_children()
# node_to_swap_5.swap_children()



# Apply the renaming directly to the leaves of the tree
for leaf in tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]


# Add node names/IDs
for n in tree.traverse():
    # Create a face to display node name/ID
    name_face = TextFace(n.name, fsize=10, fgcolor='black')
    n.add_face(name_face, column=0, position="branch-top")


# Hides the node circles
for node in tree.traverse():
    node.img_style['size'] = 0

tree.render('%%inline', tree_style=ts)
# tree.show()
# tree.render(os.path.join(results_path, 'tree_test.png'), tree_style=ts)

# %% [markdown]
# ### Topology

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()
# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree
line_width = 2


# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = 'internal_node_{}'.format(i)
        i += 1


# Find the node you want to use as the new root
node_to_reroot = tree&'internal_node_6'  # Replace 'Node_Name' with the name of your desired node

# Use the assigned name to reroot
tree.set_outgroup(node_to_reroot)

# Identify the node whose children you want to swap
node_to_swap_1 = tree&'internal_node_0'  
node_to_swap_2 = tree&'internal_node_2'
# node_to_swap_3 = tree&'internal_node_11'
# node_to_swap_4 = tree&'internal_node_64'
# node_to_swap_5 = tree&'internal_node_72'

# Swap the children of the target node
node_to_swap_1.swap_children()
node_to_swap_2.swap_children()
node_to_swap_3.swap_children()
# node_to_swap_4.swap_children()
# node_to_swap_5.swap_children()




# Apply the renaming directly to the leaves of the tree
for leaf in tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]


# # Add node names/IDs
# for n in tree.traverse():
#     # Create a face to display node name/ID
#     name_face = TextFace(n.name, fsize=10, fgcolor='black')
#     n.add_face(name_face, column=0, position="branch-top")


# Hides the node circles
for node in tree.traverse():
    node.img_style['size'] = 0

# Nodestyle
for node in tree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = line_width  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = line_width  # Set the thickness of horizontal lines
    node.set_style(nstyle)

# Find the node you want to collapse
node_to_collapse_1 = tree&'internal_node_6'
node_to_collapse_2 = tree&'internal_node_7'
node_to_collapse_3 = tree&'internal_node_29'
node_to_collapse_4 = tree&'internal_node_28'
node_to_collapse_5 = tree&'internal_node_1'
node_to_collapse_6 = tree&'internal_node_8'
node_to_collapse_7 = tree&'internal_node_19'

# node_to_collapse.img_style['shape'] = 'sphere'
# node_to_collapse.img_style['size'] = 50
node_to_collapse_1.img_style['draw_descendants'] = False
node_to_collapse_2.img_style['draw_descendants'] = False
node_to_collapse_3.img_style['draw_descendants'] = False
node_to_collapse_4.img_style['draw_descendants'] = False
node_to_collapse_5.img_style['draw_descendants'] = False
node_to_collapse_6.img_style['draw_descendants'] = False
node_to_collapse_7.img_style['draw_descendants'] = False

# Rename the node
node_to_collapse_1.name = 'Sericomyxidae'
node_to_collapse_2.name = 'Thalassomyxa & Arachnula'
node_to_collapse_3.name = 'Placopodidae'
node_to_collapse_4.name = 'B4'
node_to_collapse_5.name = 'Vampyrella & Leptophrys'
node_to_collapse_6.name = 'B1'
node_to_collapse_7.name = 'B2'

tree.render('%%inline', tree_style=ts)
# tree.show()
tree.render(os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'tree_gblocks_strong.png'), dpi=600, w=1000, tree_style=ts)

# %%
import os
from ete3 import Tree, TreeStyle, NodeStyle, TextFace

os.environ['QT_QPA_PLATFORM'] = 'offscreen'
line_width = 1
tree_width = 200


# Create a Tree object from the Newick file
main_tree = Tree(f'{tree_file}/T2.raxml.bestTree')


# Apply the renaming directly to the leaves of the tree
for leaf in main_tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]
        

# Function to get color based on the label
def get_color(name):
    if 'Leptophrys_vorax_strain_LV02_' in name:
        return 'red'
    elif 'Leptophrys_vorax_strain_LV04_' in name:
        return '#990000'
    elif 'Vampyrella_lateritia_strain_VL09_' in name:
        return 'green'
    elif 'Vampyrella_lateritia_strain_NHR1' in name:
        return '#33CC33'
    elif 'Pseudovampyrella_closterii_strain_VC01_' in name:
        return 'purple'
    elif 'Placopus_flabellus_NHR1_' in name:
        return 'orange'
    elif 'Leptophrys_vorax_strain_LV01_' in name:
        return '#FF6666'
    return 'black'  # Default color if no match

for node in main_tree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = line_width  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = line_width  # Set the thickness of horizontal lines
    node.set_style(nstyle)

for leaf in main_tree.iter_leaves():
    color = get_color(leaf.name)

    # Apply the color to the text (leaf name)
    name_face = TextFace(leaf.name, fgcolor=color)
    leaf.add_face(name_face, column=0, position="branch-right")

    # Apply the color to the branch leading to the leaf
    nstyle = NodeStyle()
    nstyle["fgcolor"] = color
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_color"] = color
    nstyle["hz_line_color"] = color
    nstyle["vt_line_width"] = line_width  # Control the thickness of the vertical lines
    nstyle["hz_line_width"] = line_width  # Control the thickness of the horizontal lines
    leaf.set_style(nstyle)


ts = TreeStyle()
ts.scale = tree_width  # Increase this value to spread out the tree more
ts.show_leaf_name = False
# main_tree.render("%%inline", tree_style=ts)
# main_tree.render(f"{tree_file}/tree_mock.png", dpi=600, w=10000, tree_style=ts)

# save as Newick
# main_tree.write(outfile=f"{tree_file}/tree_mock.newick")

# %% [markdown]
# # Subtrees
