# %%
# imports
from Bio import AlignIO
from Bio.Align.Applications import ClustalwCommandline
from Bio.Align import MultipleSeqAlignment
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import subprocess
from ete3 import Tree

# %%
# variables
project = 'Suthaus_2022'
cell = 'cellCombined'
marker = 'Full18S'
sim = 'sim90'
raw_data = '../raw_data'
denoise_method = 'FAD'
vamp_spec_dir = f'{raw_data}/vamp_specific_seqs/{project}/{marker}/{cell}/{sim}/{denoise_method}'
vamp_ref_seqs = f'{raw_data}/reference_alignments/vamp/2023_VAMPYRELLIDA_SSU_annotated_PR2_AM_AS_not_aligned_version.fasta'
clustalw_path = f'{raw_data}/packages/clustalw-2.1-linux-x86_64-libcppstatic/clustalw2'
tree_file = f'{raw_data}/phylogenetic_inference/{project}/{marker}/{cell}/{sim}'
pics_dir = f'{raw_data}/OTU_results/{project}'
tax_assign_dir = f'{raw_data}/tax_assign_results/{project}/{marker}/{cell}/{sim}/{denoise_method}'

# %%
# functions

def strip(file_path, output_path='out_stripped.fasta'):
    '''
    Remove line breaks in FASTA files
    '''
    seqs = []
    # read a file and stripped it
    with open(file_path,'rt') as f:
        lines = f.readlines()
        for line in lines:
            if line.startswith('>'):
                seqs.append('\n' + line)
            else:
                line_cleaned = line.rstrip()
                seqs.append(line_cleaned)
        seqs[0] = seqs[0].lstrip()
    # write the file into fasta
    with open(output_path, 'w') as fp:
        for seq in seqs:
            fp.write(seq)

# %% [markdown]
# # Creating alignments

# %%
# format the ref. sequences fasta file if needed

strip(file_path = vamp_ref_seqs, output_path = vamp_ref_seqs)

# %%
# combine the ref. sequences fasta file and denoised sequences


# Path to the output file
file_combined_path = f'{vamp_spec_dir}/reference_and_mock_seqs.fasta'

# Path to the denoised sequences
denoised_sequences = f'{vamp_spec_dir}/Mock_18S_otu.fasta'

# Read the contents of the reference sequences file
with open(vamp_ref_seqs, 'r') as file1:
    content1 = file1.read()

# Read the contents of the denoised sequences file
with open(denoised_sequences, 'r') as file2:
    content2 = file2.read()

# Write the combined contents to the new file
with open(file_combined_path, 'w') as file_combined:
    file_combined.write(content1 + '\n' + content2)

print(f"Combined files {denoised_sequences} and {vamp_ref_seqs} into {file_combined_path}")

# %%
# Creating alignment

# paths
input_sequences = f'{vamp_spec_dir}/reference_and_mock_seqs.fasta'



#     creating an alingnment using clustalw:
#     see more here: https://manpages.ubuntu.com/manpages/impish/man1/clustalw.1.html
cmd = ClustalwCommandline(clustalw_path,
                          infile=input_sequences,
                          output='fasta',
                          outfile=f'{vamp_spec_dir}/aligned_reference_and_mock_seqs.fasta')
# print clustal command in a linux style
print(cmd)
# run clustalw alignment
stdout, stderr = cmd()

# %%
# if you want to check the resulting alignments using biopython

align = AlignIO.read(f'{vamp_spec_dir}/aligned_reference_and_mock_seqs.fasta', 'fasta')
print(align)

# %% [markdown]
# # Creating a maximum likelihood phylogenetic tree

# %%
# Path to your alignment file
alignment_path = f'{vamp_spec_dir}/aligned_reference_and_mock_seqs.fasta'

# Output prefix for the tree
output_prefix = f'{vamp_spec_dir}/raxml_tree'

# The command to run RAxML-NG
cmd = f"raxml-ng --all --msa {alignment_path} --model GTR+G --prefix {output_prefix} --threads 2"

# Run the command
process = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
stdout, stderr = process.communicate()

# Check if the command was successful
if process.returncode != 0:
    print(f"RAxML-NG encountered an error:\n{stderr.decode()}")
else:
    print(f"RAxML-NG ran successfully. Tree(s) saved to {output_prefix}.bestTree and other files.")

# %% [markdown]
# # Tree visualizing

# %%
# Creating name_mapping dictionary to rename the new sequences in the tree

name_mapping = {}

with open(f'{tax_assign_dir}/blast6_Mock_18S.tab') as f:
    content = f.read
    for line in f:
        if 'Vampyrellida' in line:
            old_name = line.strip().split('\t')[0].replace(';', '_')
            new_name_second_part = line.strip().split(';')[0].strip('centroid=')
            new_name_first_part = line.split(',s:')[1].split('\t')[0]
            name_mapping[old_name] = new_name_first_part + "_" + new_name_second_part
            
name_mapping
# Out:
# {'centroid=seq12_300_seqs=5': 'Vampyrella_lateritia_strain_VL09_seq12_300',
#  'centroid=seq173_22_seqs=10': 'Leptophrys_vorax_strain_LV02_seq173_22',
#  'centroid=seq199_18_seqs=1': 'Leptophrys_vorax_strain_LV02_seq199_18',
#  'centroid=seq179_25_seqs=3': 'Pseudovampyrella_closterii_strain_VC01_seq179_25',
#  'centroid=seq18_128_seqs=2': 'Placopus_flabellus_HR01_seq18_128',
#  'centroid=seq254_8_seqs=21': 'Leptophrys_vorax_strain_LV02_seq254_8',
#  'centroid=seq308_6_seqs=1': 'Leptophrys_vorax_strain_LV04_seq308_6'}

# %%
import os
from ete3 import Tree, TreeStyle, NodeStyle, TextFace

os.environ['QT_QPA_PLATFORM'] = 'offscreen'
line_width = 1
tree_width = 200


# Create a Tree object from the Newick file
main_tree = Tree(f'{tree_file}/T2.raxml.bestTree')


# Apply the renaming directly to the leaves of the tree
for leaf in main_tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]
        

# Function to get color based on the label
def get_color(name):
    if 'Leptophrys_vorax_strain_LV02_' in name:
        return 'red'
    elif 'Leptophrys_vorax_strain_LV04_' in name:
        return '#990000'
    elif 'Vampyrella_lateritia_strain_VL09_' in name:
        return 'green'
    elif 'Vampyrella_lateritia_strain_NHR1' in name:
        return '#33CC33'
    elif 'Pseudovampyrella_closterii_strain_VC01_' in name:
        return 'purple'
    elif 'Placopus_flabellus_NHR1_' in name:
        return 'orange'
    elif 'Leptophrys_vorax_strain_LV01_' in name:
        return '#FF6666'
    return 'black'  # Default color if no match

for node in main_tree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = line_width  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = line_width  # Set the thickness of horizontal lines
    node.set_style(nstyle)

for leaf in main_tree.iter_leaves():
    color = get_color(leaf.name)

    # Apply the color to the text (leaf name)
    name_face = TextFace(leaf.name, fgcolor=color)
    leaf.add_face(name_face, column=0, position="branch-right")

    # Apply the color to the branch leading to the leaf
    nstyle = NodeStyle()
    nstyle["fgcolor"] = color
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_color"] = color
    nstyle["hz_line_color"] = color
    nstyle["vt_line_width"] = line_width  # Control the thickness of the vertical lines
    nstyle["hz_line_width"] = line_width  # Control the thickness of the horizontal lines
    leaf.set_style(nstyle)


ts = TreeStyle()
ts.scale = tree_width  # Increase this value to spread out the tree more
ts.show_leaf_name = False
# main_tree.render("%%inline", tree_style=ts)
# main_tree.render(f"{tree_file}/tree_mock.png", dpi=600, w=10000, tree_style=ts)

# save as Newick
# main_tree.write(outfile=f"{tree_file}/tree_mock.newick")

# %% [markdown]
# ## Subtrees

# %% [markdown]
# ### Subtrees tree

# %%
# Function to get color based on the label
def get_color(name, subtaxa):
    
    # color code for Leptophrys_vorax
    if subtaxa == 'Leptophrys_vorax':
        if 'Leptophrys_vorax_strain_LV02_' in name:
            return 'red'
        elif 'Leptophrys_vorax_strain_LV04_' in name:
            return '#990000'
        elif 'Leptophrys_vorax_strain_LV01_' in name:
            return '#FF6666'
        return 'black'  # Default color if no match
    
    # color code for Vampyrella_lateritia
    elif subtaxa == 'Vampyrella_lateritia':
        if 'Vampyrella_lateritia_strain_VL09_' in name:
            return 'green'
#         elif 'Vampyrella_lateritia_strain_NHR1' in name:
#             return '#33CC33'
    
    # color code for Pseudovampyrella_closterii
    elif subtaxa == 'Pseudovampyrella_closterii':
        if 'Pseudovampyrella_closterii_strain_VC01_' in name:
            return 'purple'
    
    # color code for Placopus_flabellus
    elif subtaxa == 'Placopus_flabellus':
        if 'Placopus_flabellus' in name:
            return 'orange'
    else:
        print('Subtaxa name is probably incorrect. Choose among: Leptophrys_vorax, Vampyrella_lateritia, or Pseudovampyrella_closterii')

# %%
# Subtaxa
subtaxa = 'Placopus_flabellus'

# load the tree
main_tree = Tree(f"{tree_file}/tree_mock.newick")

# Collect leaves that match the condition for new sequences
matching_leaves = [leaf for leaf in main_tree.iter_leaves() if f'{subtaxa}_strain_' in leaf.name and 'seq' in leaf.name]




# Find the common ancestor of these leaves
common_ancestor = main_tree.get_common_ancestor(matching_leaves)

# Use this common ancestor as the root of a new subtree
subtree = common_ancestor.copy(method="newick")


for node in subtree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = 2  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = 2  # Set the thickness of horizontal lines
    node.set_style(nstyle)

for leaf in subtree.iter_leaves():
    color = get_color(name = leaf.name, subtaxa = subtaxa)

    # Apply the color to the text (leaf name)
    name_face = TextFace(leaf.name, fgcolor=color)
    leaf.add_face(name_face, column=0, position="branch-right")

    # Apply the color to the branch leading to the leaf
    nstyle = NodeStyle()
    nstyle["fgcolor"] = color
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_color"] = color
    nstyle["hz_line_color"] = color
    nstyle["vt_line_width"] = 2  # Control the thickness of the vertical lines
    nstyle["hz_line_width"] = 2  # Control the thickness of the horizontal lines
    leaf.set_style(nstyle)


ts = TreeStyle()
ts.show_leaf_name = False
# subtree.render("%%inline", tree_style=ts)
subtree.render(f"{tree_file}/subtree_mock_{subtaxa}.png", dpi=600, w=6000, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[263.4818039663431,
#    7.060753746489306,
#    3624.400587295253,
#    127.0935674368075,
#    2,
#    'JF720748|Vampyrellida|Leptophryidae|Vernalophrys|Vernalophrys_X'],
#   [259.64066389566176,
#    127.0935674368075,
#    3987.7186420420153,
#    247.1263811271257,
#    3,
#    'KF141791|Vampyrellida|Leptophryidae|Vernalophrys|Vernalophrys_algivore'],
#   [97.78572735066082,
#    247.1263811271257,
#    4708.457923808178,
#    367.1591948174439,
#    6,
#    'AY941200|Vampyrellidae|Leptophryidae|Platyreta|Platyreta_germanica_strain_Fritzlar_Werkel'],
#   [96.0503271555323,
#    367.1591948174439,
#    4614.932724908688,
#    487.1920085077621,
#    7,
#    'AY941201|Vampyrellida|Leptophryidae|Platyreta|Platyreta_germanica_strain_Gross_Gernau'],
#   [117.51188280061136,
#    487.1920085077621,
#    3831.4683534539863,
#    607.2248221980803,
#    8,
#    'AY620306|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [310.4959727507224,
#    607.2248221980803,
#    4638.738019348667,
#    727.2576358883986,
#    11,
#    'EU567294|Vampyrellida|Leptophryidae|Theratromyxa|Theratromyxa_strain_BaikalA155'],
#   [310.4959727507224,
#    727.2576358883986,
#    4109.181488361969,
#    847.2904495787167,
#    12,
#    'GQ377666|Vampyrellida|Leptophryidae|Theratromyxa|Theratromyxa_weberi'],
#   [359.9474550220811,
#    847.2904495787167,
#    4088.025433168435,
#    967.3232632690349,
#    17,
#    'EU567258|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [369.8789919752865,
#    967.3232632690349,
#    4097.956970121641,
#    1087.3560769593532,
#    22,
#    'AB769357|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [355.29552674236356,
#    1087.3560769593532,
#    4083.373504888717,
#    1207.3888906496713,
#    23,
#    'AB769365|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [389.8550648487752,
#    1207.3888906496713,
#    4435.666961587147,
#    1327.4217043399894,
#    25,
#    'MF621963|Vampyrellida|Leptophryidae|Arachnomyxa|Arachnomyxa_cryptophaga'],
#   [355.44976620837514,
#    1327.4217043399894,
#    4104.710005594196,
#    1447.4545180303078,
#    30,
#    'GQ844515|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [362.74026160986864,
#    1447.4545180303078,
#    4041.3929635307973,
#    1567.487331720626,
#    31,
#    'FJ410786|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [352.91512514391206,
#    1567.487331720626,
#    4102.175364529733,
#    1687.5201454109442,
#    32,
#    'GQ844430|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [356.854417602056,
#    1687.5201454109442,
#    4106.114656987877,
#    1807.5529591012623,
#    33,
#    'GQ844533|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [441.6605547992674,
#    1807.5529591012623,
#    5207.669333679549,
#    1927.5857727915804,
#    38,
#    'OQ591879|Vampyrellida|Leptophryidae|Pseudovampyrella|Pseudovampyrella_minor_strainVC02'],
#   [439.10199424542276,
#    1927.5857727915804,
#    3016.2771117140196,
#    2047.6185864818988,
#    40,
#    'Pseudovampyrella_closterii_strain_VC01_seq179_25'],
#   [447.04079029015367,
#    2047.6185864818988,
#    5361.32539784671,
#    2167.651400172217,
#    41,
#    'OQ591878|Vampyrellida|Leptophryidae|Pseudovampyrella|Pseudovampyrella_closterii_strain_VC01'],
#   [472.407821184251,
#    2167.651400172217,
#    4765.346099049749,
#    2287.684213862535,
#    42,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_X_strain_VI01'],
#   [414.58204319942234,
#    2287.684213862535,
#    3930.8374089510967,
#    2407.7170275528533,
#    44,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Strigomyxa|Strigomyxa_ruptor'],
#   [414.58204319942274,
#    2407.7170275528533,
#    4728.702582304389,
#    2527.7498412431714,
#    45,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Strigomyxa|Strigomyxa_ruptor_strain_Strigo01'],
#   [541.8988866974572,
#    2527.7498412431714,
#    5576.216307944333,
#    2647.7826549334895,
#    51,
#    'XXXXXXXX|Vampyrellida|Vampyrellida_clade_PurpleVamp|clade_PurpleVamp_X|clade_PurpleVamp_XX'],
#   [564.7568456364303,
#    2647.7826549334895,
#    3996.2831664302335,
#    2767.815468623808,
#    53,
#    'EU567265|Vampyrellida|Vampyrellida_clade_A|clade_A_X|clade_A_XX'],
#   [587.9323564171933,
#    2767.815468623808,
#    4005.3371697180173,
#    2887.848282314126,
#    55,
#    'AY620291|Vampyrellida|Vampyrellida_clade_A|clade_A_X|clade_A_XX'],
#   [560.1832743046867,
#    2887.848282314126,
#    3977.5880876055107,
#    3007.8810960044443,
#    56,
#    'EF024716|Vampyrellida|Vampyrellida_clade_A|clade_A_X|clade_A_XX'],
#   [566.1854165194924,
#    3007.8810960044443,
#    3778.8283711721265,
#    3127.9139096947624,
#    62,
#    'EU567262|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_X'],
#   [567.981852653043,
#    3127.9139096947624,
#    3801.8070685451453,
#    3247.9467233850805,
#    63,
#    'DQ409093|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_X'],
#   [575.228633125667,
#    3247.9467233850805,
#    3759.628572792344,
#    3367.979537075399,
#    64,
#    'JN090874|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_X'],
#   [646.2785894985648,
#    3367.979537075399,
#    3858.921544151199,
#    3488.012350765717,
#    68,
#    'EU567266|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_X'],
#   [641.4369549237525,
#    3488.012350765717,
#    4800.220911605954,
#    3608.0451644560353,
#    69,
#    'HE609040|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL01'],
#   [643.9377787790897,
#    3608.0451644560353,
#    4859.207765433205,
#    3728.0779781463534,
#    73,
#    'XXXXXXXX|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_NHR1'],
#   [645.692974413707,
#    3728.0779781463534,
#    2848.648143318371,
#    3848.110791836672,
#    78,
#    'Vampyrella_lateritia_strain_VL09_seq12_300'],
#   [644.4796789350787,
#    3848.110791836672,
#    4831.506650603237,
#    3968.14360552699,
#    79,
#    'XXXXXXXX|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL10'],
#   [644.4788541251,
#    3968.14360552699,
#    4831.505825793259,
#    4088.176419217308,
#    80,
#    'XXXXXXXX|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL06'],
#   [644.4780293151215,
#    4088.176419217308,
#    4831.50500098328,
#    4208.209232907627,
#    81,
#    'XXXXXXXX|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL09'],
#   [645.1609719774627,
#    4208.209232907627,
#    4811.005682406153,
#    4328.242046597945,
#    82,
#    'OK381872|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL08'],
#   [640.9783605756103,
#    4328.242046597945,
#    4799.762317257811,
#    4448.274860288263,
#    83,
#    'HE609034|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL02'],
#   [648.6523926171866,
#    4448.274860288263,
#    4814.497103045877,
#    4568.307673978581,
#    84,
#    'OK381871|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_lateritia_strain_VL07'],
#   [668.9674623919102,
#    4568.307673978581,
#    4446.470716763689,
#    4688.340487668899,
#    85,
#    'XXXXXXXX|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_strain_NV01'],
#   [557.2098343315699,
#    4688.340487668899,
#    4737.1760522532395,
#    4808.373301359217,
#    87,
#    'HE609035|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_pendula_strain_VP02'],
#   [554.4838373520545,
#    4808.373301359217,
#    4734.450055273724,
#    4928.406115049535,
#    88,
#    'HE609035|Vampyrellida|Vampyrellidae|Vampyrella|Vampyrella_pendula_strain_VP01'],
#   [621.9978333463796,
#    4928.406115049535,
#    4251.225259041883,
#    5048.4389287398535,
#    90,
#    'XXXXXXXX|Vampyrellida|Vampyrellida_strain_Vr|strain_Vr_X|strain_Vr_XX'],
#   [625.3267664203051,
#    5048.4389287398535,
#    4247.493438369319,
#    5168.471742430172,
#    96,
#    'EU567268|Vampyrellida|Vampyrellida_clade_B4|clade_B4_X|clade_B4_XX'],
#   [628.4321759900104,
#    5168.471742430172,
#    4222.355832953067,
#    5288.504556120491,
#    98,
#    'JQ242405|Vampyrellida|Vampyrellida_clade_B4|clade_B4_X|clade_B4_XX'],
#   [626.761110973218,
#    5288.504556120491,
#    4220.6847679362745,
#    5408.537369810809,
#    99,
#    'JQ243522|Vampyrellida|Vampyrellida_clade_B4|clade_B4_X|clade_B4_XX'],
#   [640.9255727369754,
#    5408.537369810809,
#    4213.666968460564,
#    5528.570183501127,
#    101,
#    'AB622340|Vampyrellida|Placopodidae|Placopodidae_X|Placopodidae_XX'],
#   [807.9116521593025,
#    5528.570183501127,
#    4408.896062868848,
#    5648.602997191445,
#    104,
#    'OK381883|Vampyrellida|Placopodidae|Placopus|Placopus_X_strain_HR02'],
#   [759.0094933337402,
#    5648.602997191445,
#    3886.923403028503,
#    5768.635810881763,
#    105,
#    'EU567269|Vampyrellida|Placopodidae|Placopus_X|Placopus_XX'],
#   [966.3353791930226,
#    5768.635810881763,
#    3896.5481839860845,
#    5888.668624572081,
#    108,
#    'AY179971|Vampyrellida|Placopodidae|Placopus|Placopus_X'],
#   [962.4035100246865,
#    5888.668624572081,
#    4429.233599550937,
#    6008.701438262399,
#    110,
#    'OK381882|Vampyrellida|Placopodidae|Placopus|Placopus_X_strain_HS'],
#   [949.2246961854446,
#    6008.701438262399,
#    2763.838409033196,
#    6128.734251952717,
#    113,
#    'Placopus_flabellus_HR01_seq18_128'],
#   [947.9050002195673,
#    6128.734251952717,
#    4541.828657182624,
#    6248.7670656430355,
#    114,
#    'KY124641|Vampyrellida|Placopodidae|Placopus|Placopus_flabellus_HR01'],
#   [1045.7274636902223,
#    6248.7670656430355,
#    3940.636499750838,
#    6368.799879333354,
#    115,
#    'FJ157330|Vampyrellida|Placopodidae|Placopus|Placopus_X'],
#   [826.9070259681494,
#    6368.799879333354,
#    4922.144198931946,
#    6488.832693023673,
#    117,
#    'MH2352265|Vampyrellida|Placopodidae|Placopus|Placopus_pusillus_strain_PGC2_1'],
#   [848.2737284656813,
#    6488.832693023673,
#    3990.309145653423,
#    6608.865506713991,
#    119,
#    'GU385680|Vampyrellida|Placopodidae|Placopus_X|Placopus_XX'],
#   [872.855540260082,
#    6608.865506713991,
#    3831.3113600391007,
#    6728.898320404309,
#    121,
#    'GU385615|Vamyprellida|Placopodidae|Placopus|Placopus_X'],
#   [872.855540260082,
#    6728.898320404309,
#    4014.890957447823,
#    6848.931134094627,
#    122,
#    'GU385647|Vampyrellida|Placopodidae|Placopus_X|Placopus_XX'],
#   [852.9833934439062,
#    6848.931134094627,
#    4461.028557899942,
#    6968.963947784945,
#    124,
#    'AY605211|Vampyrellida|Vampyrellida_clade_B2|clade_B2_X|clade_B2_XX'],
#   [952.5420819196686,
#    6968.963947784945,
#    4574.708753868683,
#    7088.996761475263,
#    126,
#    'AB695521|Vampyrellida|Vampyrellida_clade_B2|clade_B2_X|clade_B2_XX'],
#   [900.7398912090913,
#    7088.996761475263,
#    4508.7850556651265,
#    7209.029575165581,
#    127,
#    'AY605200|Vampyrellida|Vampyrellida_clade_B2|clade_B2_X|clade_B2_XX'],
#   [618.4321798085753,
#    7209.029575165581,
#    4233.5380980111,
#    7329.062388855899,
#    129,
#    'KC315810|Vampyrellida|Vampyrellida_clade_B1|clade_B1_X|clade_B1_XX'],
#   [670.6071846295132,
#    7329.062388855899,
#    4292.773856578528,
#    7449.0952025462175,
#    131,
#    'EU567267|Vampyrellida|Vampyrellida_clade_B1|clade_B1_X|clade_B1_XX'],
#   [635.1585013660911,
#    7449.0952025462175,
#    4257.3251733151055,
#    7569.128016236536,
#    132,
#    'AB721056|Vampyrellida|Vampyrellida_clade_B1|clade_B1_X|clade_B1_XX'],
#   [967.8423070240588,
#    7569.128016236536,
#    4738.284807649348,
#    7689.160829926855,
#    135,
#    'EU567270|Vampyrellida|Vampyrellida_X|Vampyrellida_XX|Vampyrellida_XXX'],
#   [1064.429205146661,
#    7689.160829926855,
#    5590.372356646306,
#    7809.193643617173,
#    139,
#    'MW969735|Vampyrellida|Sericomyxidae|Sericomyxa|Sericomyxa_perlucida_strain_BWH1_7'],
#   [1277.9964281145642,
#    7809.193643617173,
#    5429.719631050276,
#    7929.226457307491,
#    140,
#    'MH235264|Vampyrellida|Placopodidae|Placopus|Placopus_melkoniani_strain_MAC_1'],
#   [1064.5331312039739,
#    7929.226457307491,
#    5985.87849250702,
#    8049.259270997809,
#    142,
#    'KC779511|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_X_strain_NVam1_Penardia'],
#   [902.6889171886957,
#    8049.259270997809,
#    4673.131417813985,
#    8169.292084688127,
#    144,
#    'AF372744|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_XX'],
#   [900.5922502229084,
#    8169.292084688127,
#    4671.034750848197,
#    8289.324898378445,
#    145,
#    'AF372743|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_XX'],
#   [844.8235483248908,
#    8289.324898378445,
#    5490.799513514854,
#    8409.357712068764,
#    149,
#    'XXXXXXXX|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_X_strain_Clone2_11'],
#   [845.3242079819457,
#    8409.357712068764,
#    5427.753389453505,
#    8529.390525759081,
#    150,
#    'XXXXXXXX|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_X_strain_Clone2_5'],
#   [841.9367133995338,
#    8529.390525759081,
#    5424.365894871094,
#    8649.4233394494,
#    152,
#    'XXXXXXXX|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_X_strain_Clone2_3'],
#   [838.5079783181892,
#    8649.4233394494,
#    5484.483943508153,
#    8769.456153139718,
#    153,
#    'XXXXXXXX|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_X_strain_Clone2_12'],
#   [889.7938379821175,
#    8769.456153139718,
#    4660.236338607407,
#    8889.488966830037,
#    155,
#    'LC150164|Vampyrellida|Sericomyxdiae|Sericomyxidae_X|Sericomyxidae_XX'],
#   [839.4606338435572,
#    8889.488966830037,
#    4638.146149454804,
#    9009.521780520354,
#    156,
#    'GU479951|Vampyrellida|Sericomyxidae|Sericomyxidae_X|Sericomyxidae_XX'],
#   [656.1688859528367,
#    9009.521780520354,
#    4165.363497958022,
#    9129.554594210673,
#    160,
#    'JQ782345|Vampyrellida|Arachnulidae|Arachnulidae_X|Arachnulidae_XX'],
#   [870.7333041849556,
#    9129.554594210673,
#    4471.717714894502,
#    9249.58740790099,
#    164,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Arachnula|Arachnula_strain_AV03'],
#   [870.7333041849556,
#    9249.58740790099,
#    4471.717714894502,
#    9369.620221591309,
#    165,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Arachnula|Arachnula_strain_AV04'],
#   [870.1691341595429,
#    9369.620221591309,
#    4471.153544869088,
#    9489.653035281628,
#    166,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Arachnula|Arachnula_strain_AV02'],
#   [868.475799273327,
#    9489.653035281628,
#    3925.782171503197,
#    9609.685848971945,
#    167,
#    'EU910611|Vampyrellida|Arachnulidae|Arachnula|Arachnula_X'],
#   [761.1589481381629,
#    9609.685848971945,
#    5541.289234511423,
#    9729.718662662264,
#    172,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|lower_thalassomyxid|lower_thalassomyxid_strain_PGC2.2'],
#   [764.2049713894036,
#    9729.718662662264,
#    5360.7556603539415,
#    9849.751476352581,
#    173,
#    'OK381873|Vampyrellida|Arachnulidae|lower_thalassomyxid|lower_thalassomyxid_strain_ASB'],
#   [756.5730046567398,
#    9849.751476352581,
#    5614.371582241382,
#    9969.7842900429,
#    174,
#    'OK381874|Vampyrellida|Arachnulidae|lower_thalassomyxid|lower_thalassomyxid_strain_BWH_1_3'],
#   [801.525148494435,
#    9969.7842900429,
#    5475.744128670355,
#    10089.817103733218,
#    175,
#    'OK381875|Vampyrellida|Arachnulidae|lower_thalassomyxid|lower_thalassomyxid_strain_SCO4'],
#   [760.3135179100228,
#    10089.817103733218,
#    4912.036720845735,
#    10209.849917423537,
#    176,
#    'KC779514|Vampyrellida|Arachnulidae|Arachnulidae_X|Arachnulidae_X_strain_CAraX'],
#   [730.5890158985939,
#    10209.849917423537,
#    4190.358351678354,
#    10329.882731113854,
#    179,
#    'EF024704|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_X'],
#   [685.0776508953576,
#    10329.882731113854,
#    5401.661153550213,
#    10449.915544804173,
#    181,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Arachnulidae_X|Arachnulidae_X_strain_Limnomyxa_GV8'],
#   [739.7699757712066,
#    10449.915544804173,
#    4199.539311550966,
#    10569.948358494492,
#    185,
#    'EF539120|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_X'],
#   [676.1565061660275,
#    10569.948358494492,
#    4834.940462848229,
#    10689.98117218481,
#    186,
#    'OK381878|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_BWH1_6'],
#   [676.4303430789469,
#    10689.98117218481,
#    4566.9056573945545,
#    10810.013985875128,
#    187,
#    'KC779515|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_MVa1x_sp'],
#   [688.6680487325223,
#    10810.013985875128,
#    4699.176176738448,
#    10930.046799565445,
#    189,
#    'OK381876|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_BOP1'],
#   [722.0101673104131,
#    10930.046799565445,
#    5177.345781345165,
#    11050.079613255764,
#    194,
#    'OK381881|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_MarVampPPP4'],
#   [720.2401250961802,
#    11050.079613255764,
#    4780.1735293275315,
#    11170.112426946082,
#    195,
#    'OK381880|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_PGC_4'],
#   [741.8847885565252,
#    11170.112426946082,
#    4752.392916562451,
#    11290.1452406364,
#    198,
#    'KC779517|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_V1ld4'],
#   [744.7971925912206,
#    11290.1452406364,
#    4797.6698430760825,
#    11410.178054326718,
#    199,
#    'KC779516|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_En42C'],
#   [737.8902338298102,
#    11410.178054326718,
#    4861.370421779565,
#    11530.210868017037,
#    200,
#    'OK381877|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_BOP4_2'],
#   [715.3556004024765,
#    11530.210868017037,
#    4732.924482154892,
#    11650.243681707354,
#    203,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_TV01'],
#   [717.0365631390125,
#    11650.243681707354,
#    4727.544691144938,
#    11770.276495397673,
#    204,
#    'KC779518|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_V2ld4'],
#   [713.5946310980089,
#    11770.276495397673,
#    4646.434467892552,
#    11890.309309087992,
#    205,
#    'OK381879|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_LBC'],
#   [687.2229816498873,
#    11890.309309087992,
#    5156.680103177619,
#    12010.34212277831,
#    207,
#    'XXXXXXXX|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_MarVamp_KSS'],
#   [687.223806459866,
#    12010.34212277831,
#    4683.610426972813,
#    12130.374936468628,
#    209,
#    'KC779519|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_KibAr'],
#   [687.223806459866,
#    12130.374936468628,
#    4697.731934465792,
#    12250.407750158945,
#    210,
#    'KC779520|Vampyrellida|Arachnulidae|Thalassomyxa|Thalassomyxa_strain_V1ld4'],
#   [699.6586416983449,
#    12250.407750158945,
#    4237.096268689487,
#    12370.440563849264,
#    211,
#    'EU910603|Vampyrellida|Arachnulidae|Arachnulidae_X|Arachnulidae_XX'],
#   [442.03996738945693,
#    12370.440563849264,
#    4155.996438042832,
#    12490.473377539582,
#    214,
#    'AY642743|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [440.462105900255,
#    12490.473377539582,
#    4168.540084046608,
#    12610.5061912299,
#    215,
#    'EU567261|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [440.5553094278452,
#    12610.5061912299,
#    4119.208011348774,
#    12730.539004920218,
#    216,
#    'FJ410735|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [421.1021660808352,
#    12730.539004920218,
#    4149.180144227188,
#    12850.571818610537,
#    217,
#    'EU567260|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [566.6893754164623,
#    12850.571818610537,
#    4315.949614802284,
#    12970.604632300856,
#    220,
#    'DQ409121|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [608.9410913839813,
#    12970.604632300856,
#    4358.201330769803,
#    13090.637445991173,
#    221,
#    'DQ409086|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [410.1132227349701,
#    13090.637445991173,
#    4229.980999585685,
#    13210.670259681492,
#    222,
#    'MF621964|Vampyrellida|Leptophryidae|Planctomyxa|Planctomyxa_polycarya'],
#   [363.19555671809604,
#    13210.670259681492,
#    3964.179967427642,
#    13330.70307337181,
#    224,
#    'MW694332|Vampyrellida|Leptophryidae|Kinopus|Kinopus_chlorellivorous'],
#   [389.79072967043896,
#    13330.70307337181,
#    4110.807954070304,
#    13450.735887062128,
#    225,
#    'KC511080|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [343.50981695710067,
#    13450.735887062128,
#    4071.5877951034545,
#    13570.768700752446,
#    229,
#    'EU567259|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [342.44663689459065,
#    13570.768700752446,
#    4670.688683492535,
#    13690.801514442765,
#    231,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_X_strain_BV01'],
#   [342.4474617045693,
#    13690.801514442765,
#    4070.525439850923,
#    13810.834328133082,
#    233,
#    'AB572112|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [344.1704897500175,
#    13810.834328133082,
#    4072.248467896371,
#    13930.8671418234,
#    235,
#    'AB572110|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [344.1407965907852,
#    13930.8671418234,
#    4072.218774737139,
#    14050.89995551372,
#    236,
#    'AB572111|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [340.61885798184994,
#    14050.89995551372,
#    4520.585075903519,
#    14170.932769204037,
#    237,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_X_strainVm'],
#   [344.42700565338464,
#    14170.932769204037,
#    4065.4442300532487,
#    14290.965582894356,
#    239,
#    'LN586943|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [346.25395975614606,
#    14290.965582894356,
#    4067.27118415601,
#    14410.998396584673,
#    240,
#    'LN587380|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_XX'],
#   [448.8842405924886,
#    14410.998396584673,
#    3668.5879489916124,
#    14531.031210274992,
#    242,
#    'EU567263|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_X'],
#   [494.68098984834563,
#    14531.031210274992,
#    3700.2631907544906,
#    14651.06402396531,
#    244,
#    'AY620292|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_X'],
#   [462.94477629893254,
#    14651.06402396531,
#    4226.326523177732,
#    14771.096837655628,
#    246,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_X_strain_Vd'],
#   [470.8439814646867,
#    14771.096837655628,
#    4523.716631949548,
#    14891.129651345946,
#    249,
#    'HE609036|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_LV01'],
#   [470.93471056234114,
#    14891.129651345946,
#    4523.807361047203,
#    15011.162465036265,
#    251,
#    'HE609039|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_LV04'],
#   [481.7454949528121,
#    15011.162465036265,
#    2508.181820195243,
#    15131.195278726582,
#    252,
#    'Leptophrys_vorax_strain_LV04_seq308_6'],
#   [493.13364632835453,
#    15131.195278726582,
#    2519.5699715707856,
#    15251.2280924169,
#    255,
#    'Leptophrys_vorax_strain_LV02_seq254_8'],
#   [506.53021000196674,
#    15251.2280924169,
#    4559.402860486828,
#    15371.26090610722,
#    259,
#    'HE609038|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_LV03'],
#   [506.53021000196674,
#    15371.26090610722,
#    4559.402860486828,
#    15491.293719797537,
#    260,
#    'HE609037|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_LV02'],
#   [503.4371725819413,
#    15491.293719797537,
#    4754.010927968504,
#    15611.326533487856,
#    261,
#    'KC174719|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_LAK2013'],
#   [494.002996045876,
#    15611.326533487856,
#    4596.300922756162,
#    15731.359347178173,
#    262,
#    'XXXXXXXX|Vampyrellida|Leptophryidae|Leptophrys|Leptophrys_vorax_strain_RV01'],
#   [621.6266688559767,
#    15731.359347178173,
#    2711.6097778168114,
#    15851.392160868492,
#    264,
#    'Leptophrys_vorax_strain_LV02_seq199_18'],
#   [557.5199628835506,
#    15851.392160868492,
#    2647.5030718443854,
#    15971.42497455881,
#    265,
#    'Leptophrys_vorax_strain_LV02_seq173_22'],
#   [324.36350292215656,
#    15971.42497455881,
#    4659.666303266591,
#    16091.457788249128,
#    266,
#    'KC779512|Vampyrellida|Leptophryidae|Leptophryidae_X|Leptophryidae_X_strain_BAra1'],
#   [311.09973365511127,
#    16091.457788249128,
#    4335.729369154015,
#    16211.490601939446,
#    267,
#    'KC779513|Vampyrellida|Leptophryidae|Theratromyxa|Theratromyxa_strain_Wara']],
#  'node_areas': {0: [7.060753746489306,
#    7.060753746489306,
#    5985.878492507021,
#    16211.490601939446],
#   1: [7.060753746489306,
#    7.060753746489306,
#    3987.7186420420153,
#    247.1263811271257],
#   2: [259.63983908568287,
#    7.060753746489306,
#    3624.400587295253,
#    127.0935674368075],
#   3: [259.63983908568287,
#    127.0935674368075,
#    3987.7186420420153,
#    247.1263811271257],
#   4: [7.060753746489306,
#    247.1263811271257,
#    4708.457923808178,
#    607.2248221980803],
#   5: [83.17339376848422,
#    247.1263811271257,
#    4708.457923808178,
#    487.1920085077621],
#   6: [96.04950234555335,
#    247.1263811271257,
