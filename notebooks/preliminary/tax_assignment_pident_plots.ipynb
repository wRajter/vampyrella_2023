# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# ## Global Variables

# %%
project = 'Suthaus_2022'
cell = 'cellCombined'
marker = 'Full18S'
sim = 'sim90'
denoise_method = 'RAD'
raw_data = os.path.join('..', 'raw_data')
tax_assign_results = os.path.join(raw_data, 'tax_assign_results', project, marker, cell, sim, denoise_method)
otu_results = os.path.join(raw_data, 'OTU_results', project)

# %% [markdown]
# # Plotting *'Pident'* values

# %%
final_tax_table_path = os.path.join(otu_results, f'final_tax_table_{marker}_{sim}.csv')

tax_df = pd.read_csv(final_tax_table_path)

# %%
tax_df.head(3)
# Out:
#          OTU  OTU_Num       Reference_ID    Kingdom         Domain  \
# 0  seq106_27        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 1  seq150_65        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 2  seq104_29        6  DQ462456.1.1771_U  Eukaryota      Alveolata
#
#        Phyllum             Class             Order                 Family  \
# 0   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 1   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 2  Apicomplexa  Gregarinomorphea  Neogregarinorida       Actinocephalidae
#
#            Genus                 Species  Pident  Length Sample
# 0    Chrysocapsa  Chrysocapsa_wetherbeei    94.5     683   Th38
# 1    Chrysocapsa  Chrysocapsa_wetherbeei    95.1     884   Th38
# 2  Ascogregarina   Ascogregarina_culicis    84.0    1748   Th38

# %%
# Set style of seaborn plot
sns.set(style="white")

# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(tax_df['Pident'], bins=30, kde=True, color='lightcoral')
plt.title('Distribution of Percentage of Identical Positions (Pident)')
plt.xlabel('Pident')
plt.ylabel('Frequency')

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)

# plt.show()

# save path
save_path = os.path.join(otu_results, f'pident_{marker}_{sim}_histogram.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Set style of seaborn plot
sns.set(style="white")
# darkgrid, whitegrid, dark, white, ticks

# Create a figure and axis
plt.figure(figsize=(6, 12))

# Create a boxplot
sns.boxplot(y=tax_df['Pident'], 
            color='lightcoral', 
            width=0.5, 
            boxprops=dict(alpha=.7, linewidth=2, edgecolor='black'), 
            saturation=1, 
            showfliers=False,
            medianprops = dict(linewidth=2, color='black'),
            whiskerprops = dict(linewidth=2, color='black'),
            capprops = dict(linewidth=2, color='black'))

# Overlay a strip plot on the histogram
sns.stripplot(y=tax_df['Pident'], 
              size=8, 
              color='lightcoral', 
              jitter=0.2, 
              alpha=.5, 
              edgecolor='black', 
              linewidth=0.5)

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(True)


# Add title and labels
plt.title('Distribution of Percentage of Identical Positions (Pident) with Individual OTUs')
plt.ylabel('Pident')


# Show the plot
# plt.show()

# save path
save_path = os.path.join(otu_results, f'pident_{marker}_{sim}_boxplot.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# # Plotting sequence length

# %%
# Set style of seaborn plot
sns.set(style="white")

# Create a histogram
plt.figure(figsize=(10,6))
sns.histplot(tax_df['Length'], bins=30, kde=True, color='#4361EE')
plt.title('Distribution of Sequence Length')
plt.xlabel('Sequence length (number of base pairs)')
plt.ylabel('Frequency')

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)

# plt.show()

# save path
save_path = os.path.join(otu_results, f'length_{marker}_{sim}_histogram.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Set style of seaborn plot
sns.set(style="white")
# darkgrid, whitegrid, dark, white, ticks

# Create a figure and axis
plt.figure(figsize=(6, 12))

# Create a boxplot
sns.boxplot(y=tax_df['Length'], 
            color='#4361EE', 
            width=0.5, 
            boxprops=dict(alpha=.7, linewidth=2, edgecolor='black'), 
            saturation=1, 
            showfliers=False,
            medianprops = dict(linewidth=2, color='black'),
            whiskerprops = dict(linewidth=2, color='black'),
            capprops = dict(linewidth=2, color='black'))

# Overlay a strip plot on the histogram
sns.stripplot(y=tax_df['Length'], 
              size=8, 
              color='#4361EE', 
              jitter=0.2, 
              alpha=.5, 
              edgecolor='black', 
              linewidth=0.5)

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(True)


# Add title and labels
plt.title('Distribution of Length with Individual OTUs')
plt.ylabel('Length')


# Show the plot
# plt.show()

# save path
save_path = os.path.join(otu_results, f'length_{marker}_{sim}_boxplot.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# # Exploring the relationship between sequence length and percentage of identical positions (pident)

# %%
# Set style of seaborn plot
sns.set(style='white')

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Create a scatter plot
sns.scatterplot(x=tax_df['Length'], y=tax_df['Pident'], alpha=0.9)

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)

# Add title and labels
plt.title('Scatter Plot of Sequence Length vs Pident')
plt.xlabel('Sequence Length')
plt.ylabel('Pident')

# Show the plot
plt.show()


# # save path
# save_path = os.path.join(otu_results, f'length_vs_pident_{marker}_{sim}_boxplot.png')
# # Save the figure
# plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# # Taxonomic assignment distribution

# %%
tax_df.head(3)
# Out:
#          OTU  OTU_Num       Reference_ID    Kingdom         Domain  \
# 0  seq106_27        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 1  seq150_65        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 2  seq104_29        6  DQ462456.1.1771_U  Eukaryota      Alveolata
#
#        Phyllum             Class             Order                 Family  \
# 0   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 1   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 2  Apicomplexa  Gregarinomorphea  Neogregarinorida       Actinocephalidae
#
#            Genus                 Species  Pident  Length Sample
# 0    Chrysocapsa  Chrysocapsa_wetherbeei    94.5     683   Th38
# 1    Chrysocapsa  Chrysocapsa_wetherbeei    95.1     884   Th38
# 2  Ascogregarina   Ascogregarina_culicis    84.0    1748   Th38

# %%
tax_df['Species'].unique()
# Out:
# array(['Chrysocapsa_wetherbeei', 'Ascogregarina_culicis',
#        'Leptophryidae_XX', 'Chrysophyceae_CladeE_X_sp.',
#        'DinoGroupIII_XX_sp.', 'Chytridiomycetes_X_sp.',
#        'Cognettia_cognetti', 'Psychodiella_sp.', 'Cephalodella_gibba',
#        'Bryocamptus_pygmaeus', 'Nannochloropsis_sp.', 'Diderma_niveum',
#        'Heterolepidoderma_ocellatum',
#        'SpizellomycetalesandRhizophlyctidales_sp.', 'Uroleptus_pisces',
#        'Limnofilidae_X_sp.', 'Chrysastrella_breviappendiculata',
#        'Dinophyceae_XXX_sp.', 'Plectus_minimus', 'Hemiophrys_procera',
#        'Cryptomycotina_XX_sp.', 'Gregarina_tropica', 'Fungi_XXXX_sp.',
#        'Stenophora_robusta', 'Paramecium_sp.', 'Chromadorea_XX_sp.',
#        'Microthamnion_kuetzingianum', 'Chlamydomonadales_XX_sp.',
#        'Cercomonas_sp.', 'Epipyxis_pulchra', 'Gyratrix_hermaphroditus',
#        'Microspora_sp.', 'Parietochloris_alveolaris',
#        'Tetrahymenida_X_sp.', 'Heterolepidoderma_acidophilum',
#        'Cypria_exsculpta', 'Chrysamoeba_mikrokonta',
#        'Glaciozyma_antarctica', 'Chloromonas_sp.',
#        'Chrysolepidomonas_dendrolepidota', 'Stenostomum_grabbskogense',
#        'Uroleptus_sp.', 'Pinnularia_anglica', 'Vacuolaria_virescens',
#        'Theratromyxa_weberi', 'Acroperus_harpae', 'Ophrydium_versatile',
#        'Bryometopus_pseudochilodon', 'Monocystis_sp.',
#        'Lepidoderma_tigrinum', 'Eupetalomonads_XX_sp.',
#        'Ichthyophonidae_Freshwater_X_sp.', 'Haliphthoros_sp.',
#        'Tetrachaetum_elegans', 'Eurotiomycetes_X_sp.', 'Phoma_herbarum',
#        'Oxytricha_granulifera', 'Chydorus_sphaericus', 'Monodus_guttula',
#        'Aspidisca_sp.', 'Amblyseius_sp.', 'Cryptomonas_pyrenoidifera',
#        'Chironomus_tepperi', 'Vampyrella_lateritia_strain_VL09',
#        'Leptophrys_vorax_strain_LV02', 'Viridiraptor_invadens',
#        'Pseudovampyrella_closterii_strain_VC01',
#        'Placopus_flabellus_HR01', 'Oedogonium_cardiacum',
#        'Diplophrys_sp.', 'Closterium_venus', 'Euglena_deses',
#        'Zygnema_pseudogedeanum', 'Giardia_intestinalis',
#        'Candidatus_Nitrosopumilus_sp.', 'Exobasidiomycetes_X_sp.',
#        'Lamproderma_album', 'Lamproderma_arcyrioides',
#        'Chloromonas_oogama', 'Leptophrys_vorax_strain_LV04',
#        'Closterium_wallichii', 'Colloderma_robustum', 'Closterium_sp.',
#        'Mesotaenium_braunii', 'Monoraphidium_terrestre',
#        'Berwaldia_schaefernai', 'Platyophrya_vorax', 'Peridinium_willei',
#        'Vorticella_fusca', 'Placopus_melkoniani_strain_MAC_1',
#        'Stentor_sp.', 'Ichthyophthirius_multifiliis',
#        'Eustigmatophyceae_XXX_sp.', 'Acricotopus_lucens',
#        'Gyrodinium_sp.', 'Cyphellopsis_anomala', 'Hemidinium_nasutum',
#        'Stenostomum_leucops_aquariorum', 'Nallachius_pulchellus',
#        'Paractinolaimus_macrolaimus', 'Oogamochlamys_zimbabwiensis',
#        'Oligohymenophorea_XXX_sp.', 'Pentapharsodinium_tyrrhenicum',
#        'Sericomyxa_perlucida_strain_BWH1_7', 'Rhabdolaimus_aquaticus',
#        'Tobrilus_gracilis', 'Trisetacus_ehmanni',
#        'Pseudodendromonadales_XX_sp.', 'Chlamydomonas_reinhardtii',
#        'Spirogyra_sp.', 'Nannochloropsis_limnetica', 'Cypridopsis_uenoi',
#        'Caliculium_glossobalani', 'Lagenidium_giganteum',
#        'Mb5Clineage_X_sp.', 'Amoebidium_parasiticum', 'OLIGO4_XX_sp.',
#        'Pleuroxus_aduncus', 'Orciraptor_agilis', 'Pygsuia_biforma',
#        'Mameliella_sp.', 'Chaetonotus_aemilianus',
#        'Brachionus_calyciflorus', 'clade_PurpleVamp_XX',
#        'Cyrtolophosis_mucicola', 'Cyanidioschyzon_sp.',
#        'Katablepharidales_XX_sp.', 'Tetracladium_sp.', 'Cloeon_sp.',
#        'Glissomonadida_XX_sp.', 'Eucyclops_macruroides',
#        'Litostomatea_XXX_sp.', 'Rhynchopus_sp.', 'Group_Te_sp.',
#        'Pentapharsodinium_sp.', 'Slavina_appendiculata', 'MAST12C_XX_sp.',
#        'Euglypha_penardi', 'Clavispora_lusitaniae', 'Aphamonas_sp.',
#        'Chrysophyceae_XXX_sp.', 'Gomphonema_affine',
#        'Culicoides_variipennis', 'Hydrozetes_lacustris',
#        'Bistichella_variabilis', 'Bursariomorphida_X_sp.',
#        'Tracheleuglypha_dentata', 'Mougeotia_scalaris',
#        'Pleuroxus_truncatus', 'Mougeotia_sp.', 'Olkasia_polycarbonata',
#        'Haplogonaria_sp.', 'Orthodonellidae_X_sp.',
#        'Kinetoplastea_KIN1_XX_sp.', 'DinoGroupIClade2_X_sp.',
#        'DinoGroupIClade4_X_sp.', 'Aphanochaete_repens',
#        'Allapsidae_X_sp.', 'Prorocentrum_sp.', 'Filoreta_sp.',
#        'DinoGroupIClade1_X_sp.', 'Planomonas_brevis',
#        'TelonemiaGroup1_X_sp.', 'DinoGroupIIClade10and11_X_sp.',
#        'Troglochaetus_beranecki', 'RADB_X_GroupIVd_X_sp.',
#        'Novocrania_sp.', 'Eupelagonemidae_X_sp.', 'Fabomonas_tropica',
#        'Notosolenus_urceolatus', 'Meriderma_cribrarioides',
#        'Neocallimastix_frontalis', 'Kareniaceae_X_sp.',
#        'Oblongichytrium_sp.', 'DinoGroupIClade3_X_sp.',
#        'Perkinsus_chesapeaki', 'Stramenopiles_XXXXX_sp.',
#        'Vermistella_antarctica', 'Pseudodiophrys_nigricans',
#        'Diplonema_sp.', 'Spumella_sp.', 'DinoGroupIClade8_X_sp.',
#        'DinoGroupIIClade15_X_sp.', 'DinoGroupIIClade1_X_sp.',
#        'Perkinsus_qugwadi', 'Euplotes_sp.', 'Paradinida_XX_sp.',
#        'RADA_Xa_X_sp.', 'Micromonas_commoda', 'Hemimastix_sp.',
#        'Bradya_sp.', 'Labyrinthulomycetes_X_LAB16_X_sp.',
#        'Philasterida_X_sp.', 'Ichthyobodonidae_X_sp.',
#        'Kinetoplastea_XXX_sp.', 'Ctenophora_XXX_sp.', 'Leegaardiella_sp.',
#        'MAST3J_XX_sp.', 'CCW10lineage_X_sp.', 'Diplonema_ambulator',
#        'Protodinium_simplex', 'Prototrachelocerca_sp.',
#        'Polycheira_rufescens', 'Acantharea_4d_X_sp.',
#        'Margolisiella_islandica', 'Cryptocaryon_irritans', 'Apolemia_sp.',
#        'Acantharea_3a_X_sp.', 'Paulinella_sp.',
#        'Helicoprorodontidae_X_sp.', 'Prorocentrum_nanum',
#        'Aspidisca_fusca', 'MAST9C_XX_sp.', 'Hyphochytrium_catenoides',
#        'Clathromonas_butcheri', 'Strombidinopsis_batos',
#        'Lacrimia_lanifica', 'Platydasys_sp.', 'Paraphysomonas_sp.',
#        'RADC_Xa_X_sp.', 'Pirsonia_formosa', 'Metschnikowia_sp.',
#        'Peritromus_kahli', 'Perkinsus_mediterraneus',
#        'Diopisthoporus_longitubus', 'Filoreta_turcica',
#        'Parmales_env_2_X_sp.', 'Oerstedia_dorsalis', 'Eucoleus_dispar',
#        'Nidula_niveotomentosa', 'Coniosporium_sp.',
#        'Sapromyces_elongatus', 'Botryosphaeria_dothidea',
#        'Paracostantinella_sp.', 'Candida_sp.', 'Flectomonas_ekelundi',
#        'Gregarinomorphea_X_GRE7_XX_sp.',
#        'Schizoplasmodium_cavostelioides', 'Scoliciosporum_umbrinum',
#        'Rhysotritia_duplicata', 'Sphaeropleales_XX_sp.',
#        'Xiphocephalus_ellisi', 'Lobosphaera_incisa', 'Spongomonas_minima',
#        'Ceratiomyxella_tahitiensis', 'Paracercomonas_sp.',
#        'Variosea_XXX_sp.', 'Mortierella_alpina',
#        'Catenulostroma_germanicum', 'Chaetothyriomycetidae_sp.',
#        'Cladochytrium_sp.', 'Cypretta_seurati', 'Stereocaulon_vesuvianum',
#        'Sporobolomyces_falcatus', 'Phialocephala_fortinii',
#        'Keratella_quadrata', 'Flammulaster_sp.', 'Operculariidae_X_sp.',
#        'Naiadacarus_arboricola', 'Davidiellaceae_sp.',
#        'Parachloroidium_laureanum', 'Saitoella_complicata',
#        'Urostomides_striatus', 'Thoracosphaeraceae_X_sp.',
#        'Peregrinia_clavideferens', 'Blastocladia_ramosa',
#        'Chaetonotus_sp.', 'Coprinopsis_atramentaria',
#        'Frontonia_paramagna', 'Olisthanella_truncula',
#        'Pinnularia_subcapitata', 'Camptobasidium_hydrophilum',
#        'Lepadella_patella', 'Trachelomonas_oblonga',
#        'Pyramimonas_olivacea', 'Bodomorpha_sp.', 'Lepocinclis_horridus',
#        'Hoplorhynchus_acanthatholius', 'Eucyclops_serrulatus',
#        'Petalomonas_sphagnophila', 'Plagiopylidae_X_sp.',
#        'Stentor_polymorphus', 'Gregarina3_sp.',
#        'Oxytricha_longigranulosa', 'Mattesia_sp.',
#        'Histiobalantium_natans', 'Plumatella_geimermassardi',
#        'Adriamonas_peritocrescens', 'Hydrurus_foetidus',
#        'Spirostomum_minus', 'Basidiomycota_XXX_sp.',
#        'Gregarina1_niphandrodes', 'Euplotes_daidaleos',
#        'Candida_pseudolambica', 'Stenostomum_leucops',
#        'Epalxella_antiquorum', 'Obertrumia_georgiana', 'Prorodon_teres',
#        'Vaginicola_1_sp.', 'Monoraphidium_contortum',
#        'Skrjabinoeces_similis', 'Sandona_campae',
#        'Fusicladium_oleagineum', 'Arachnomyxa_cryptophaga',
#        'Lepocinclis_acus', 'Evaginogenida_X_sp.', 'Nolandellidae_X_sp.',
#        'Loxodes_striatus', 'Perkinsida_XXX_sp.', 'Gregarina1_sp.',
#        'Mollimonas_vickermani', 'Lepocinclis_cyclidiopsis',
#        'Paramecium_chlorelligerum', 'Isohypsibius_granulifer',
#        'Cryptomonas_sp.', 'Novelclade10_XX_sp.', 'Rhyzophidiales_X_sp.',
#        'Meliniomyces_variabilis', 'Castrella_truncata',
#        'Parvilucifera_sinerae', 'Sphaeroeca_volvox',
#        'Glenodiniopsis_uliginosa', 'Trochiliopsis_australis',
#        'NC12Blineage_X_sp.', 'Distigma_sp.', 'Brachonella_spiralis',
#        'Syncystis_mirabilis', 'Diacronema_noctivaga',
#        'Pseudotetraedriella_kamillae', 'Pythium_undulatum',
#        'Gregarina_blattarum', 'Dimastigella_trypaniformis',
#        'Urocentrum_turbo', 'Sessilida_X_sp.', 'Chrysocapsa_sp.',
#        'Metopus_fuscus', 'Spizellomyces_punctatus', 'Eumonhystera_sp.',
#        'Plectidae_sp.', 'Rotifera_XXX_sp.', 'Bensingtonia_yuccicola',
#        'Achlya_bisexualis', 'Umbelopsis_sp.', 'Pyropia_tenera',
#        'Gregarina1_cloptoni', 'Pseudochlorella_pringsheimii',
#        'Trebouxia_jamesii', 'Trebouxiophyceae_XXX_sp.',
#        'Acrochordonoposthia_conica', 'Vampyrella_strain_NV01',
#        'Tetramitus_thorntoni', 'Sporobolomyces_coprosmicola',
#        'Archaeorhizomyces_finlayi', 'Parhypochthonius_aphidinus',
#        'Pseudococcomyxa_sp.', 'Phialocephala_sphaeroides',
#        'Cylindrocystis_brebissonii', 'Casuarina_equisetifolia',
#        'Antonospora_scoticae', 'Netrium_oblongum', 'Nucleophaga_sp.',
#        'DinoGroupIIClade5_X_sp.', 'Chromera_sp.', 'Homo_sapiens',
#        'Comatricha_pseudoalpina', 'Halocafeteria_seosinensis',
#        'Suctoria_XX_sp.', 'Pseudodifflugiidae_X_sp.',
#        'Orthamphisiella_breviseries', 'Hyphochytrydiales_XX_sp.',
#        'Pliciloricus_sp.', 'Actinoposthia_beklemischevi',
#        'Diplonema_aggregatum', 'RADB_X_GroupIVb_X_sp.',
#        'Dryas_octopetala', 'Arcticotantulus_pertzovi', 'Aphamonas_edax',
#        'Prorocentrum_cordatum', 'Thaumatomonadida_XX_sp.',
#        'LC104lineage_X_sp.', 'Itunella_muelleri', 'Polycope_sp.',
#        'Chrysophyceae_CladeH_X_sp.', 'MAST6_XXX_sp.',
#        'Scenedesmus_pupukensis', 'Sulcionema_specki', 'Desmoscolex_sp.',
#        'Endogenida_2_X_sp.', 'Paranerilla_limicola',
#        'Melicertum_octocostatum', 'Abeoformidae_Group_MAIP_2_X_sp.',
#        'Ichthyobodonidae_PRO1_sp.', 'Prismatolaimus_dolichurus',
#        'Ulospora_bilgramii', 'Hypsibius_convergens',
#        'Mycoemilia_scoparia', 'Coenocystis_inconstans',
#        'Zoopagomycotina_XX_sp.', 'PHYLL_2_X_sp.', 'Macrocyclops_albidus',
#        'Chroomonas_mesostigmatica', 'clade_B2_XX', 'Oxytrichidae_X_sp.',
#        'Plasmodiophorida_XX_sp.', 'Coemansia_furcata',
#        'Melampsoridium_sp.', 'Litonotus_pictus', 'Pterocystis_sp.',
#        'Ripella_sp.', 'Mallomonas_annulata', 'Pigoraptor_chileana',
#        'Didymium_squamulosum', 'Rhogostomalineage_X_sp.',
#        'Isotomurus_palustris', 'Bumilleriopsis_sp.', 'WIM80lineage_X_sp.',
#        'Rhizomucor_endophyticus', 'Tintinnidium_sp.', 'Trinema_lineare',
#        'Monodictys_castaneae', 'Anisonema_sp.', 'Thaumatomastix_sp.',
#        'Ancyromonas_howeae', 'Trithigmostoma_cucullulus',
#        'Fibrophrys_sp.', 'Raphidpennate_X_sp.', 'Bodo_sp.',
#        'Amphifilaceae_X_sp.', 'Colpodella_tetrahymenae',
#        'Pseudendocloniopsis_botryoides', 'Reckertia_filosa',
#        'FilosaSarcomonadea_XXX_sp.', 'Vampyrella_X',
#        'Anurofeca_richardsi', 'Dacrymyces_chrysospermus',
#        'Parvamoeba_sp.', 'Flacourtia_jangomas', 'Sinantherina_socialis',
#        'Prionchulus_muscorum', 'Cercomonas_edax', 'Cyclidium_varibonneti',
#        'Leptophryidae_X_strain_VI01', 'Agaricostilbomycetes_X_sp.',
#        'Euchlanis_dilatata', 'Filosa_XXX_sp.', 'Cryptococcus_podzolicus',
#        'Liepara_sp.', 'Helicoon_fuscosporum',
#        'Klebsormidium_subtilissimum', 'Pseudomuriella_cubensis',
#        'Apatococcus_lobatus', 'Glomeromycotina_XX_sp.',
#        'Prasiolales_XX_sp.', 'Turbinellus_floccosus',
#        'Dictyochloropsis_symbiontica', 'Cryptococcus_peneaus',
#        'Phaenocora_sp.', 'Eremobiotus_alicatai', 'Exsertotheca_crispa',
#        'Platygaster_sp.', 'Chlamydomonas_nasuta'], dtype=object)

# %%
def assign_tax_level(species_name):
    if 'XXXXX' in species_name:
        return 'Domain'
    elif 'XXXX' in species_name:
        return 'Phylum'
    elif 'XXX' in species_name:
        return 'Class'
    elif 'XX' in species_name:
        return 'Order'
    elif 'X' in species_name:
        return 'Family'
    elif '_sp.' in species_name:
        return 'Genus'
    else:
        return 'Species'

# %%
# Apply the function to the 'Species' column to create the new 'tax_level' column
tax_df['tax_level'] = tax_df['Species'].apply(assign_tax_level)

# %%
tax_df.head()
# Out:
#          OTU  OTU_Num       Reference_ID    Kingdom         Domain  \
# 0  seq106_27        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 1  seq150_65        1  EF165145.1.1730_U  Eukaryota  Stramenopiles
# 2  seq104_29        6  DQ462456.1.1771_U  Eukaryota      Alveolata
# 3  seq213_14        1           KC511080  Eukaryota       Rhizaria
# 4  seq222_12        1  EF165122.1.1785_U  Eukaryota  Stramenopiles
#
#        Phyllum             Class             Order                 Family  \
# 0   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 1   Ochrophyta     Chrysophyceae   Chrysophyceae_X  Chrysophyceae_CladeB1
# 2  Apicomplexa  Gregarinomorphea  Neogregarinorida       Actinocephalidae
# 3     Cercozoa          Endomyxa      Vampyrellida          Leptophryidae
# 4   Ochrophyta     Chrysophyceae   Chrysophyceae_X   Chrysophyceae_CladeE
#
#                     Genus                     Species  Pident  Length Sample  \
# 0             Chrysocapsa      Chrysocapsa_wetherbeei    94.5     683   Th38
# 1             Chrysocapsa      Chrysocapsa_wetherbeei    95.1     884   Th38
# 2           Ascogregarina       Ascogregarina_culicis    84.0    1748   Th38
# 3         Leptophryidae_X            Leptophryidae_XX    92.2     641   Th38
# 4  Chrysophyceae_CladeE_X  Chrysophyceae_CladeE_X_sp.    91.0     662   Th38
#
#   tax_level
# 0   Species
# 1   Species
# 2   Species
# 3     Order
# 4    Family

# %%
# Set the style of seaborn plot
sns.set(style="whitegrid")

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Create a count plot
sns.countplot(data=tax_df, y='tax_level', order=tax_df['tax_level'].value_counts().index, palette="viridis")

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)

# Add title and labels
plt.title('Distribution of OTUs Across Taxonomic Levels')
plt.xlabel('Count of OTUs')
plt.ylabel('Taxonomic Level')

# Show the plot
# plt.show()


# save path
save_path = os.path.join(otu_results, f'tax_level_dist_{marker}_{sim}.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Set the style of seaborn plot
sns.set(style="white")

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Create a box plot to visualize the distribution of 'pident' at each taxonomic level
sns.boxplot(data=tax_df, 
            x='tax_level', 
            y='Pident', 
            order=tax_df['tax_level'].value_counts().index, 
            palette="viridis", 
            boxprops=dict(alpha=.7, linewidth=1.5, edgecolor='black'), 
            saturation=1, 
            showfliers=False)

# Add title and labels
plt.title('Distribution of Pident Across Taxonomic Levels')
plt.xlabel('Taxonomic Level')
plt.ylabel('Pident')

# Set visibility for spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)


# Show the plot
# plt.show()

# save path
save_path = os.path.join(otu_results, f'pident_across_tax_levels_{marker}_{sim}_boxplots.png')
# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Using ANOVA

# %%
# Group the data by 'tax_level' and select the 'pident' column
grouped_data = [group['Pident'] for name, group in tax_df.groupby('tax_level')]

# Conduct ANOVA
f_statistic, p_value = stats.f_oneway(*grouped_data)

# Print results
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 3.059077287708343
# P-value: 0.005749844199767266

# %% [markdown]
# ## Using Kruskal-Wallis

# %%
# Group the data by 'tax_level' and select the 'pident' column
grouped_data = [group['Pident'] for name, group in tax_df.groupby('tax_level')]

# Conduct Kruskal-Wallis test
h_statistic, p_value = stats.kruskal(*grouped_data)

# Print results
print(f"H-statistic: {h_statistic}")
print(f"P-value: {p_value}")
# Out:
# H-statistic: 23.875343424808513
# P-value: 0.0005505594187219213

# %% [markdown]
# The p-value resulting from either test tells you whether the groups are statistically significantly different from each other.
#
# A small p-value (typically ≤ 0.05) indicates that we can reject the null hypothesis. In the context of these tests, it suggests that **there is a significant difference in 'pident' between at least two of the taxonomic levels**.

# %% [markdown]
# ## Post-Hoc Tests

# %% [markdown]
# ### Tukey HSD

# %%
# Tukey HSD test
posthoc = pairwise_tukeyhsd(tax_df['Pident'], groups=tax_df['tax_level'], alpha=0.05)

# Results
print(posthoc)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1  group2 meandiff p-adj   lower    upper  reject
# ------------------------------------------------------
#  Class  Domain   2.8766    0.9 -14.7644 20.5176  False
#  Class  Family  -0.3989    0.9  -3.4961  2.6983  False
#  Class   Genus  -0.5404    0.9  -3.3966  2.3157  False
#  Class   Order   0.0586    0.9  -3.1647   3.282  False
#  Class  Phylum  -2.0234    0.9  -7.6694  3.6226  False
#  Class Species   1.2692 0.7766  -1.4117  3.9501  False
# Domain  Family  -3.2755    0.9 -20.8206 14.2696  False
# Domain   Genus   -3.417    0.9 -20.9212 14.0872  False
# Domain   Order  -2.8179    0.9 -20.3858 14.7499  False
# Domain  Phylum     -4.9    0.9 -23.0691 13.2691  False
# Domain Species  -1.6074    0.9 -19.0838 15.8691  False
# Family   Genus  -0.1415    0.9  -2.3287  2.0456  False
# Family   Order   0.4576    0.9  -2.1912  3.1064  False
# Family  Phylum  -1.6245    0.9  -6.9633  3.7143  False
# Family Species   1.6681 0.1517  -0.2846  3.6209  False
#  Genus   Order   0.5991    0.9  -1.7633  2.9615  False
#  Genus  Phylum   -1.483    0.9  -6.6856  3.7197  False
#  Genus Species   1.8096 0.0099   0.2676  3.3517   True
#  Order  Phylum  -2.0821    0.9   -7.495  3.3309  False
#  Order Species   1.2106 0.6199  -0.9366  3.3578  False
# Phylum Species   3.2926 0.4787  -1.8159  8.4012  False
# ------------------------------------------------------

# %% [markdown]
# **Explanation:**
# The pairwise_tukeyhsd function conducts the Tukey HSD test, comparing the means of 'pident' for each pair of taxonomic levels.
# The function returns a result object that you can print to see the comparisons between each pair of groups, the difference in means, and whether the difference is statistically significant.

# %% [markdown]
# **Interpretation:**
# The results from the Tukey HSD test reveal that most of the pair-wise comparisons between taxonomic levels are not statistically significantly different in terms of pident values since the p-adj values are greater than 0.05, and reject is False for those comparisons.
# The only exception is the comparison between Genus and Species levels, where reject is True, indicating a statistically significant difference in the means of pident values between these two levels.
# Genus and Species. This positive value suggests that, on average, Species has higher pident values than Genus.
