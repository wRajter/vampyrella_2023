# %%
# imports
from Bio import SeqIO
from Bio import Entrez
from dotenv import load_dotenv
import pandas as pd
import os
import re
import sys
import openpyxl


# Custom functions
python_dir_path = os.path.join('..', 'scripts', 'python')
sys.path.append(python_dir_path)
from low_similarity_otus import extract_data_from_filename, read_and_augment_csv, get_taxonomy_from_genbank, add_taxopath_column

# %%
# variables
project = 'Suthaus_2022'
cell = 'cellCombined'
sim = 'sim90'
marker = 'Full18S'
denoise_method = 'RAD'
raw_data = os.path.join('..', 'raw_data')
otu_results = os.path.join(raw_data, 'OTU_results', project)
load_dotenv(os.path.join('..', 'secrets.env'))
fasta_dir = os.path.join(raw_data, 'OTU_nonchimeric', project, marker, cell, sim, denoise_method)
low_similarity_dir = os.path.join(raw_data, 'low_similarity_OTUs', project, marker, denoise_method, sim)
blast_results_dir = os.path.join(low_similarity_dir, 'BLASTn')

# %% [markdown]
# # Create FASTA file with the low similarity OTUs

# %% [markdown]
# ## Load data into dataframe

# %%
tax_assign_df = pd.read_csv(os.path.join(otu_results, 'final_tax_table_Full18S_sim90.csv'))

# %% [markdown]
# ## Subset the dataframe based on the similarity threshold

# %%
similarity_threshold = 80

low_assign_df = tax_assign_df[tax_assign_df['Pident'] < similarity_threshold]

# %% [markdown]
# ## Create FASTA file for the OTUs in the subset dataframe

# %%
# Create a copy of the dataframe
low_assign_df = low_assign_df.copy()

# Format the OTU ID
low_assign_df['OTU_FASTA_id'] = 'centroid=' + low_assign_df['OTU'] + ';seqs=' + low_assign_df['OTU_Num'].astype(str)

# List of OTUs to extract
otus_to_extract = low_assign_df['OTU_FASTA_id'].tolist()  # replace 'OTU_id_column' with the name of the column with OTU IDs

# Maintain a set of sequence IDs that have been added to the list
added_ids = set()

# Initialize an empty list to store sequences
sequences = []

# Loop through each file in the directory
for fasta_file in os.listdir(fasta_dir):
    # Ensure you only process .fasta files
    if fasta_file.endswith('.fasta') and fasta_file != 'Mock_18S_otu.fasta':
        file_path = os.path.join(fasta_dir, fasta_file)
        
        # Parse the FASTA file and extract sequences as before
        for record in SeqIO.parse(file_path, 'fasta'):
            if record.id in otus_to_extract and record.id not in added_ids:
                sequences.append(record)
                added_ids.add(record.id)

# Writing sequences to a new FASTA file
SeqIO.write(sequences, os.path.join(low_similarity_dir, 
                                    'FASTA', 
                                    f'low_similarity_OTUs_TH{str(similarity_threshold)}.fasta'), 
                                    'fasta')

# %% [markdown]
# # Creating a single table with all the BLASTn search

# %% [markdown]
# Checking the OTUs with the low percentage similarity to the reference sequences. In other words, checking OTUs that are not similar or close to the known sequences in the database used.

# %% [markdown]
# ## Defining variables

# %%
# Files
blast_tables = [blast_table for blast_table in os.listdir(blast_results_dir) if blast_table.endswith('.tsv')]

# List of dataframes
dfs = []

# Regex patterns for extracting data from the CSV table names:
# Sequence ID:
reg_sequence_id = 'seq\d+_\d+'
# Taxon name:
reg_taxon_name = '[^_]+(?:_[^_]+)*'
# Percentage coverage from taxonomical assignement:
reg_score_tax_assign = '\d+\.\d+'
# Sample name:
reg_sample_name = '\w+'
# Final regex pattern

pattern = re.compile(fr'^({reg_sequence_id})_({reg_taxon_name})_({reg_score_tax_assign})_({reg_sample_name})\.tsv$')

# %% [markdown]
# ## Creating the table

# %%
# 2. Iterate over each file
for blast_table in blast_tables:
    # Extracting details from filename
    details = extract_data_from_filename(blast_table, pattern)
    if not details:
        continue
    sequence_id, taxon_name, score_tax_assign, sample_name = details
    
    # Reading and augmenting dataframe
    df = read_and_augment_csv(os.path.join(blast_results_dir, blast_table), *details)
    dfs.append(df)

# Merge all the dataframes together
blastn_df = pd.concat(dfs, ignore_index=True)

# %%
blastn_df
# Out:
#     Sequence_id  Sample           Tax_assignment Score_tax_assign  \
# 0     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 1     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 2     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 3     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 4     seq223_11  X17007    Olkasia_polycarbonata             72.2
# ..          ...     ...                      ...              ...
# 495   seq125_12    Th40  Caliculium_glossobalani             77.4
# 496   seq125_12    Th40  Caliculium_glossobalani             77.4
# 497   seq125_12    Th40  Caliculium_glossobalani             77.4
# 498   seq125_12    Th40  Caliculium_glossobalani             77.4
# 499   seq125_12    Th40  Caliculium_glossobalani             77.4
#
#                    BLASTn Max_Ident     Score        E_value Hit_accession
# 0        Gaulosia striata    89.22%  2675.680   0.000000e+00      OQ331014
# 1            Ploeotid sp.    91.36%  1096.830   0.000000e+00      MK239307
# 2         Diplonemida sp.    73.58%  1075.190   0.000000e+00      KY947150
# 3         Diplonemida sp.    73.56%  1074.290   0.000000e+00      KY947155
# 4       Uncultured marine    73.58%  1066.180   0.000000e+00      KX189158
# ..                    ...       ...       ...            ...           ...
# 495  Uncultured eukaryote    74.74%   384.502  5.959290e-101      AF372801
# 496       Apicomplexa sp.    71.47%   380.895  7.259900e-100      KC890798
# 497  Uncultured Gregarina    74.44%   379.994  7.259900e-100      MG766260
# 498  Uncultured eukaryote    79.29%   375.485   3.086990e-98      AF372709
# 499  Uncultured eukaryote    79.15%   370.075   1.312620e-96      LN575578
#
# [500 rows x 9 columns]

# %% [markdown]
# ## Adding the taxopath for each sequence using Entrez APIs

# %%
Entrez.email = os.getenv('ENTREZ_EMAIL')

# Add the taxopath column (can take some time)
blastn_df = add_taxopath_column(blastn_df)
# Out:
# Processing GenBank ID: OQ331014
# Processing GenBank ID: MK239307
# Processing GenBank ID: KY947150
# Processing GenBank ID: KY947155
# Processing GenBank ID: KX189158
# Processing GenBank ID: KY947157
# Processing GenBank ID: KX189173
# Processing GenBank ID: KJ757308
# Processing GenBank ID: AY665087
# Processing GenBank ID: KX189160
# Processing GenBank ID: KX189167
# Processing GenBank ID: KX189170
# Processing GenBank ID: KJ757736
# Processing GenBank ID: KX189157
# Processing GenBank ID: KJ760279
# Processing GenBank ID: KJ757377
# Processing GenBank ID: KX189137
# Processing GenBank ID: KX189164
# Processing GenBank ID: KJ762734
# Processing GenBank ID: KX189134
# Processing GenBank ID: OQ331014
# Processing GenBank ID: MK239307
# Processing GenBank ID: AY425009
# Processing GenBank ID: KX189125
# Processing GenBank ID: KX189169
# Processing GenBank ID: KX189123
# Processing GenBank ID: KJ757646
# Processing GenBank ID: KX189126
# Processing GenBank ID: AF380996
# Processing GenBank ID: MF422192
# Processing GenBank ID: AY425011
# Processing GenBank ID: KX189171
# Processing GenBank ID: KX189143
# Processing GenBank ID: KX189132
# Processing GenBank ID: KX189167
# Processing GenBank ID: KY947159
# Processing GenBank ID: KX189140
# Processing GenBank ID: KJ757388
# Processing GenBank ID: KX189160
# Processing GenBank ID: KJ757619
# Processing GenBank ID: AY425011
# Processing GenBank ID: AY425009
# Processing GenBank ID: MF422192
# Processing GenBank ID: AF380996
# Processing GenBank ID: MF422194
# Processing GenBank ID: MF422190
# Processing GenBank ID: OY723278
# Processing GenBank ID: OY723268
# Processing GenBank ID: OY723294
# Processing GenBank ID: OY723238
# Processing GenBank ID: OY723305
# Processing GenBank ID: OY723285
# Processing GenBank ID: OY723279
# Processing GenBank ID: OY723237
# Processing GenBank ID: AF380997
# Processing GenBank ID: KX189127
# Processing GenBank ID: KX189123
# Processing GenBank ID: AY490210
# Processing GenBank ID: MF422197
# Processing GenBank ID: KX189124
# Processing GenBank ID: AY425011
# Processing GenBank ID: AY425009
# Processing GenBank ID: MF422192
# Processing GenBank ID: KY947153
# Processing GenBank ID: KY947155
# Processing GenBank ID: KJ762758
# Processing GenBank ID: KY947157
# Processing GenBank ID: KY947150
# Processing GenBank ID: AF380996
# Processing GenBank ID: KX189127
# Processing GenBank ID: KX189128
# Processing GenBank ID: KX189124
# Processing GenBank ID: KX189123
# Processing GenBank ID: KY947159
# Processing GenBank ID: KJ762486
# Processing GenBank ID: KJ762543
# Processing GenBank ID: KX189129
# Processing GenBank ID: KX189173
# Processing GenBank ID: KY947156
# Processing GenBank ID: KJ757388
# Processing GenBank ID: EF024865
# Processing GenBank ID: LC109043
# Processing GenBank ID: AB901898
# Processing GenBank ID: LC109025
# Processing GenBank ID: OX326994
# Processing GenBank ID: OM892761
# Processing GenBank ID: MT238201
# Processing GenBank ID: GQ469513
# Processing GenBank ID: XR_008764473
# Processing GenBank ID: AY165506
# Processing GenBank ID: EF526355
# Processing GenBank ID: XR_004851174
# Processing GenBank ID: U59935
# Processing GenBank ID: DQ786064
# Processing GenBank ID: U33180
# Processing GenBank ID: MT259193
# Processing GenBank ID: EF526310
# Processing GenBank ID: AB072556
# Processing GenBank ID: MT937117
# Processing GenBank ID: FN263265
# Processing GenBank ID: KJ761459
# Processing GenBank ID: KJ758662
# Processing GenBank ID: KJ757270
# Processing GenBank ID: KJ762604
# Processing GenBank ID: KJ757549
# Processing GenBank ID: KJ761609
# Processing GenBank ID: KJ757614
# Processing GenBank ID: KJ757589
# Processing GenBank ID: KJ757567
# Processing GenBank ID: KJ757518
# Processing GenBank ID: KJ757352
# Processing GenBank ID: KJ757159
# Processing GenBank ID: KJ757267
# Processing GenBank ID: KJ757735
# Processing GenBank ID: KJ757505
# Processing GenBank ID: KJ757397
# Processing GenBank ID: KJ757317
# Processing GenBank ID: KJ757116
# Processing GenBank ID: KJ761065
# Processing GenBank ID: KJ760281
# Processing GenBank ID: MK946250
# Processing GenBank ID: OQ331009
# Processing GenBank ID: KP306753
# Processing GenBank ID: KY963138
# Processing GenBank ID: MK239284
# Processing GenBank ID: MK239283
# Processing GenBank ID: MK946022
# Processing GenBank ID: MK564755
# Processing GenBank ID: KY947157
# Processing GenBank ID: KX189145
# Processing GenBank ID: MT007863
# Processing GenBank ID: KX189173
# Processing GenBank ID: KY947156
# Processing GenBank ID: KX189129
# Processing GenBank ID: MK946009
# Processing GenBank ID: EU860484
# Processing GenBank ID: EU860442
# Processing GenBank ID: FJ000076
# Processing GenBank ID: FJ000071
# Processing GenBank ID: KX533083
# Processing GenBank ID: OQ331014
# Processing GenBank ID: MK239307
# Processing GenBank ID: MF422192
# Processing GenBank ID: KX189123
# Processing GenBank ID: AY425009
# Processing GenBank ID: MK239284
# Processing GenBank ID: MK239283
# Processing GenBank ID: KX189125
# Processing GenBank ID: KX189126
# Processing GenBank ID: AF380996
# Processing GenBank ID: MF422190
# Processing GenBank ID: AY425011
# Processing GenBank ID: KJ757646
# Processing GenBank ID: MF422191
# Processing GenBank ID: KX189127
# Processing GenBank ID: KX189167
# Processing GenBank ID: KX189134
# Processing GenBank ID: KX189166
# Processing GenBank ID: KX189128
# Processing GenBank ID: KX189124
# Processing GenBank ID: KJ759798
# Processing GenBank ID: KJ760281
# Processing GenBank ID: AY665046
# Processing GenBank ID: KJ757549
# Processing GenBank ID: KJ760044
# Processing GenBank ID: GU246589
# Processing GenBank ID: KJ761685
# Processing GenBank ID: GU246583
# Processing GenBank ID: GU246590
# Processing GenBank ID: KJ757405
# Processing GenBank ID: KJ762298
# Processing GenBank ID: KJ760124
# Processing GenBank ID: KJ760705
# Processing GenBank ID: KJ760694
# Processing GenBank ID: KJ763449
# Processing GenBank ID: KC583034
# Processing GenBank ID: KJ763698
# Processing GenBank ID: KJ760619
# Processing GenBank ID: KJ757418
# Processing GenBank ID: KC583042
# Processing GenBank ID: MH235264
# Processing GenBank ID: EU567269
# Processing GenBank ID: AB695521
# Processing GenBank ID: AY941200
# Processing GenBank ID: KX771966
# Processing GenBank ID: KX771951
# Processing GenBank ID: KX771964
# Processing GenBank ID: KX771743
# Processing GenBank ID: HE609037
# Processing GenBank ID: KX771978
# Processing GenBank ID: KX771983
# Processing GenBank ID: KX771997
# Processing GenBank ID: KX771732
# Processing GenBank ID: KX771725
# Processing GenBank ID: AY941201
# Processing GenBank ID: KX771996
# Processing GenBank ID: KX771962
# Processing GenBank ID: KX771961
# Processing GenBank ID: GU385680
# Processing GenBank ID: KX771988
# Processing GenBank ID: MT007863
# Processing GenBank ID: KX189173
# Processing GenBank ID: KY947152
# Processing GenBank ID: KX189143
# Processing GenBank ID: KX533083
# Processing GenBank ID: KJ760279
# Processing GenBank ID: KY947157
# Processing GenBank ID: KX189171
# Processing GenBank ID: KJ757619
# Processing GenBank ID: KX189169
# Processing GenBank ID: KX189156
# Processing GenBank ID: KY947153
# Processing GenBank ID: KX189151
# Processing GenBank ID: KX189170
# Processing GenBank ID: KX189149
# Processing GenBank ID: KX189142
# Processing GenBank ID: KX189130
# Processing GenBank ID: KY947154
# Processing GenBank ID: KX189129
# Processing GenBank ID: FJ000076
# Processing GenBank ID: AF372825
# Processing GenBank ID: JQ480022
# Processing GenBank ID: JQ480021
# Processing GenBank ID: KJ736741
# Processing GenBank ID: FJ459740
# Processing GenBank ID: AF372805
# Processing GenBank ID: AF372802
# Processing GenBank ID: AF372800
# Processing GenBank ID: AF372799
# Processing GenBank ID: AF372798
# Processing GenBank ID: AF372797
# Processing GenBank ID: AF372710
# Processing GenBank ID: GQ330638
# Processing GenBank ID: LN575250
# Processing GenBank ID: KP178168
# Processing GenBank ID: AF372801
# Processing GenBank ID: AF372806
# Processing GenBank ID: GU825152
# Processing GenBank ID: AY919803
# Processing GenBank ID: AF372709
# Processing GenBank ID: MK578680
# Processing GenBank ID: AY753947
# Processing GenBank ID: AY753946
# Processing GenBank ID: AY753948
# Processing GenBank ID: KC208028
# Processing GenBank ID: AY255800
# Processing GenBank ID: AY224690
# Processing GenBank ID: GU290080
# Processing GenBank ID: LC669579
# Processing GenBank ID: LC669578
# Processing GenBank ID: JQ613349
# Processing GenBank ID: JQ613336
# Processing GenBank ID: AY224691
# Processing GenBank ID: DQ414519
# Processing GenBank ID: GQ184297
# Processing GenBank ID: GQ184296
# Processing GenBank ID: GQ184295
# Processing GenBank ID: GU290092
# Processing GenBank ID: LC669580
# Processing GenBank ID: AY224692
# Processing GenBank ID: AF274257
# Processing GenBank ID: KC787453
# Processing GenBank ID: KC787375
# Processing GenBank ID: KF378556
# Processing GenBank ID: KC787491
# Processing GenBank ID: FJ222082
# Processing GenBank ID: KJ764339
# Processing GenBank ID: KJ763428
# Processing GenBank ID: KJ763405
# Processing GenBank ID: KJ763293
# Processing GenBank ID: KJ763046
# Processing GenBank ID: KJ762935
# Processing GenBank ID: KJ762860
# Processing GenBank ID: KJ759734
# Processing GenBank ID: KJ568711
# Processing GenBank ID: KC787515
# Processing GenBank ID: KC787457
# Processing GenBank ID: JX841996
# Processing GenBank ID: JX841974
# Processing GenBank ID: JX841849
# Processing GenBank ID: OQ331009
# Processing GenBank ID: OQ331014
# Processing GenBank ID: KP306753
# Processing GenBank ID: KY963138
# Processing GenBank ID: MK239290
# Processing GenBank ID: MK239288
# Processing GenBank ID: AF380996
# Processing GenBank ID: MF422192
# Processing GenBank ID: KX189156
# Processing GenBank ID: KY947154
# Processing GenBank ID: KX189170
# Processing GenBank ID: AY425011
# Processing GenBank ID: KX189145
# Processing GenBank ID: KX189173
# Processing GenBank ID: KX189169
# Processing GenBank ID: KX189143
# Processing GenBank ID: KX189130
# Processing GenBank ID: KX189129
# Processing GenBank ID: KY947156
# Processing GenBank ID: KX189123
# Processing GenBank ID: KX360153
# Processing GenBank ID: KX360146
# Processing GenBank ID: KR704917
# Processing GenBank ID: EF564602
# Processing GenBank ID: AF024655
# Processing GenBank ID: KX360152
# Processing GenBank ID: FJ865222
# Processing GenBank ID: HM002483
# Processing GenBank ID: FJ865221
# Processing GenBank ID: 6ZU5_S60
# Processing GenBank ID: AY376351
# Processing GenBank ID: AY305325
# Processing GenBank ID: LC274958
# Processing GenBank ID: AY305323
# Processing GenBank ID: EU119071
# Processing GenBank ID: AY305324
# Processing GenBank ID: KX360147
# Processing GenBank ID: KX360151
# Processing GenBank ID: XR_008288893
# Processing GenBank ID: XR_001214623
# Processing GenBank ID: JQ226824
# Processing GenBank ID: JQ226686
# Processing GenBank ID: JQ226104
# Processing GenBank ID: JQ223082
# Processing GenBank ID: JQ226025
# Processing GenBank ID: JQ224934
# Processing GenBank ID: JQ223890
# Processing GenBank ID: JQ227255
# Processing GenBank ID: JQ226989
# Processing GenBank ID: JQ226969
# Processing GenBank ID: JQ226921
# Processing GenBank ID: JQ226761
# Processing GenBank ID: JQ226274
# Processing GenBank ID: JQ226210
# Processing GenBank ID: JQ226079
# Processing GenBank ID: JQ226127
# Processing GenBank ID: JQ222657
# Processing GenBank ID: JQ227258
# Processing GenBank ID: JQ222755
# Processing GenBank ID: JQ227333
# Processing GenBank ID: AF372825
# Processing GenBank ID: JQ480022
# Processing GenBank ID: JQ480021
# Processing GenBank ID: KJ736741
# Processing GenBank ID: FJ459740
# Processing GenBank ID: AF372805
# Processing GenBank ID: AF372802
# Processing GenBank ID: AF372800
# Processing GenBank ID: AF372799
# Processing GenBank ID: AF372798
# Processing GenBank ID: AF372797
# Processing GenBank ID: AF372710
# Processing GenBank ID: GQ330638
# Processing GenBank ID: LN575250
# Processing GenBank ID: KP178168
# Processing GenBank ID: AF372801
# Processing GenBank ID: AF372806
# Processing GenBank ID: GU825152
# Processing GenBank ID: AY919803
# Processing GenBank ID: AF372709
# Processing GenBank ID: MK239284
# Processing GenBank ID: MK239283
# Processing GenBank ID: MK239285
# Processing GenBank ID: MK239282
# Processing GenBank ID: MK239281
# Processing GenBank ID: LC683679
# Processing GenBank ID: OQ331014
# Processing GenBank ID: MF422192
# Processing GenBank ID: MK564755
# Processing GenBank ID: AY425011
# Processing GenBank ID: MF422194
# Processing GenBank ID: AY425009
# Processing GenBank ID: AF380996
# Processing GenBank ID: OY723278
# Processing GenBank ID: KJ757619
# Processing GenBank ID: KY947157
# Processing GenBank ID: KY947150
# Processing GenBank ID: KY947153
# Processing GenBank ID: KY947155
# Processing GenBank ID: KX189173
# Processing GenBank ID: MK239285
# Processing GenBank ID: MK239282
# Processing GenBank ID: MF422194
# Processing GenBank ID: MK239284
# Processing GenBank ID: MK239283
# Processing GenBank ID: KC990933
# Processing GenBank ID: MK239292
# Processing GenBank ID: MK239291
# Processing GenBank ID: MF422193
# Processing GenBank ID: MK239296
# Processing GenBank ID: MT007869
# Processing GenBank ID: MT007868
# Processing GenBank ID: KJ757736
# Processing GenBank ID: KX189173
# Processing GenBank ID: OQ331009
# Processing GenBank ID: MK239281
# Processing GenBank ID: KX189143
# Processing GenBank ID: MK564755
# Processing GenBank ID: KX189167
# Processing GenBank ID: KX189171
# Processing GenBank ID: KY922163
# Processing GenBank ID: KY922162
# Processing GenBank ID: KY922164
# Processing GenBank ID: KY922165
# Processing GenBank ID: KY922170
# Processing GenBank ID: OM249669
# Processing GenBank ID: KY922173
# Processing GenBank ID: KY922166
# Processing GenBank ID: KY922171
# Processing GenBank ID: KY922172
# Processing GenBank ID: KY922174
# Processing GenBank ID: KY922168
# Processing GenBank ID: KY922169
# Processing GenBank ID: MK946327
# Processing GenBank ID: KY922161
# Processing GenBank ID: LN575113
# Processing GenBank ID: HM227932
# Processing GenBank ID: JQ000205
# Processing GenBank ID: HM227878
# Processing GenBank ID: HM227801
# Processing GenBank ID: AF372825
# Processing GenBank ID: JQ480022
# Processing GenBank ID: JQ480021
# Processing GenBank ID: AF372710
# Processing GenBank ID: AF372805
# Processing GenBank ID: AF372800
# Processing GenBank ID: AF372799
# Processing GenBank ID: AF372798
# Processing GenBank ID: GQ330638
# Processing GenBank ID: LN575250
# Processing GenBank ID: AF372802
# Processing GenBank ID: AF372797
# Processing GenBank ID: AF372806
# Processing GenBank ID: FJ459740
# Processing GenBank ID: MT126033
# Processing GenBank ID: AF372801
# Processing GenBank ID: KC890798
# Processing GenBank ID: MG766260
# Processing GenBank ID: AF372709
# Processing GenBank ID: LN575578
# Processing GenBank ID: AF372825
# Processing GenBank ID: JQ480022
# Processing GenBank ID: JQ480021
# Processing GenBank ID: AF372710
# Processing GenBank ID: AF372805
# Processing GenBank ID: AF372800
# Processing GenBank ID: AF372799
# Processing GenBank ID: AF372798
# Processing GenBank ID: GQ330638
# Processing GenBank ID: LN575250
# Processing GenBank ID: AF372802
# Processing GenBank ID: AF372797
# Processing GenBank ID: AF372806
# Processing GenBank ID: FJ459740
# Processing GenBank ID: MT126033
# Processing GenBank ID: AF372801
# Processing GenBank ID: KC890798
# Processing GenBank ID: MG766260
# Processing GenBank ID: AF372709
# Processing GenBank ID: LN575578
# Processing GenBank ID: KT346271
# Processing GenBank ID: KT346270
# Processing GenBank ID: LC485280
# Processing GenBank ID: LC485279
# Processing GenBank ID: KJ925427
# Processing GenBank ID: OP094113
# Processing GenBank ID: OP094108
# Processing GenBank ID: MN604303
# Processing GenBank ID: MZ593908
# Processing GenBank ID: MZ593907
# Processing GenBank ID: MZ593906
# Processing GenBank ID: MZ593905
# Processing GenBank ID: DQ336054
# Processing GenBank ID: AY803742
# Processing GenBank ID: AJ841810
# Processing GenBank ID: LC109024
# Processing GenBank ID: EF058253
# Processing GenBank ID: OP256707
# Processing GenBank ID: KJ925426
# Processing GenBank ID: LC272997
# Processing GenBank ID: AF372825
# Processing GenBank ID: JQ480022
# Processing GenBank ID: JQ480021
# Processing GenBank ID: AF372710
# Processing GenBank ID: AF372805
# Processing GenBank ID: AF372800
# Processing GenBank ID: AF372799
# Processing GenBank ID: AF372798
# Processing GenBank ID: GQ330638
# Processing GenBank ID: LN575250
# Processing GenBank ID: AF372802
# Processing GenBank ID: AF372797
# Processing GenBank ID: AF372806
# Processing GenBank ID: FJ459740
# Processing GenBank ID: MT126033
# Processing GenBank ID: AF372801
# Processing GenBank ID: KC890798
# Processing GenBank ID: MG766260
# Processing GenBank ID: AF372709
# Processing GenBank ID: LN575578

# %%
blastn_df
# Out:
#     Sequence_id  Sample           Tax_assignment Score_tax_assign  \
# 0     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 1     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 2     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 3     seq223_11  X17007    Olkasia_polycarbonata             72.2
# 4     seq223_11  X17007    Olkasia_polycarbonata             72.2
# ..          ...     ...                      ...              ...
# 495   seq125_12    Th40  Caliculium_glossobalani             77.4
# 496   seq125_12    Th40  Caliculium_glossobalani             77.4
# 497   seq125_12    Th40  Caliculium_glossobalani             77.4
# 498   seq125_12    Th40  Caliculium_glossobalani             77.4
# 499   seq125_12    Th40  Caliculium_glossobalani             77.4
#
#                    BLASTn Max_Ident     Score        E_value Hit_accession  \
# 0        Gaulosia striata    89.22%  2675.680   0.000000e+00      OQ331014
# 1            Ploeotid sp.    91.36%  1096.830   0.000000e+00      MK239307
# 2         Diplonemida sp.    73.58%  1075.190   0.000000e+00      KY947150
# 3         Diplonemida sp.    73.56%  1074.290   0.000000e+00      KY947155
# 4       Uncultured marine    73.58%  1066.180   0.000000e+00      KX189158
# ..                    ...       ...       ...            ...           ...
# 495  Uncultured eukaryote    74.74%   384.502  5.959290e-101      AF372801
# 496       Apicomplexa sp.    71.47%   380.895  7.259900e-100      KC890798
# 497  Uncultured Gregarina    74.44%   379.994  7.259900e-100      MG766260
# 498  Uncultured eukaryote    79.29%   375.485   3.086990e-98      AF372709
# 499  Uncultured eukaryote    79.15%   370.075   1.312620e-96      LN575578
#
#                                               Taxopath
# 0    Eukaryota; Discoba; Euglenozoa; Euglenida; Eug...
# 1    Eukaryota; Discoba; Euglenozoa; Euglenida; Plo...
# 2           Eukaryota; Discoba; Euglenozoa; Diplonemea
# 3           Eukaryota; Discoba; Euglenozoa; Diplonemea
# 4    Eukaryota; Discoba; Euglenozoa; Diplonemea; en...
# ..                                                 ...
# 495                   Eukaryota; environmental samples
# 496             Eukaryota; Sar; Alveolata; Apicomplexa
# 497  Eukaryota; Sar; Alveolata; Apicomplexa; Conoid...
# 498                   Eukaryota; environmental samples
# 499                   Eukaryota; environmental samples
#
# [500 rows x 10 columns]

# %% [markdown]
# ## Save the table as Excel and TSV files

# %%
# Save to Excel
filename_excel = "blastn_results_table.xlsx"
blastn_df.to_excel(os.path.join(low_similarity_dir, 'tables', filename_excel), index=False)

# %%
# Save to TSV
filename_tsv = "blastn_results_table.tsv"
blastn_df.to_csv(os.path.join(low_similarity_dir, 'tables', filename_tsv), sep='\t', index=False)
