# %% [markdown]
# ## Imports

# %%
import os
import subprocess
from Bio import AlignIO
import sys
import PyQt5
from ete3 import Tree, TreeStyle, TextFace, NodeStyle, AttrFace
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# my functions
sys.path.append(os.path.join('..', 'scripts', 'python'))
from create_phyl_tree import run_mafft, alignment_stats, run_raxmlng_check, run_raxmlng_tree, run_raxmlng_bootstrap, run_raxmlng_support, filter_fasta_file, shorten_sequence_names, num_seqs, run_gblocks_grid_search, move_search_grid_files

# %% [markdown]
# ## Variables

# %%
project = 'Suthaus_2022'
marker = 'Full18S'
sim = 'sim_90'
denoise_method = 'RAD'
raw_data = os.path.join('..', 'raw_data')
results_path = os.path.join('..', 'results')
reference_align_dir = os.path.join(raw_data, 'reference_alignments', 'vamp')
new_seq_dir = os.path.join(results_path, 'tax_assignment_vsearch', project, marker, sim, denoise_method, 'vamp_specific')

# %% [markdown]
# # Preparing input fasta file for the sequence alignment

# %% [markdown]
# ### Create a fasta file with all the new sequences assigned to the vampyrellids

# %%
# Path to the output file
merged_fasta_file = os.path.join(new_seq_dir, 'all_samples.fasta')

# Create a list of fasta files, excluding those starting with 'Mock'
files = [file for file in os.listdir(new_seq_dir) if not file.startswith('Mock')]

# List to store the modified lines
merged_lines = []

for file in files:
    path = os.path.join(new_seq_dir, file)
    sample = file.split('_')[0]
    with open(path, 'r') as infile:
        for line in infile:
            if line.startswith('>'):
                # Replace ';' with '_' in the line as the RAxML-ng does not support the semicolon
                modified_line = line.strip().replace(';', '_')
                # Add the sample name to the line
                merged_lines.append(modified_line + '_' + sample + '\n')
            else:
                merged_lines.append(line)

# Write the contents to the output file: results -> tax_assignment_vsearch -> vamp_specific -> all_samples.fasta
with open(merged_fasta_file, 'w') as outfile:
    outfile.writelines(merged_lines)

# %% [markdown]
# ### Prepare vampyrella reference sequence database

# %%
# We have to exclude the unpublished sequences
# All the unpublished sequences started with 'XXXXXXXX' in the sequence ID

# Vampyrella reference sequences path
vamp_ref_seqs = os.path.join(reference_align_dir, '2023_VAMPYRELLIDA_SSU_annotated_PR2_AM_AS_not_aligned_version.fasta')
# Vampyrella filtered fasta file
output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim)
filtered_fasta_file = os.path.join(output_dir, 'vamp_ref_seqs.fasta')

# Create path to the save directory if not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Filter out sequences with headers starting with "XXXXXXXX", and return the filtered lines.
filtered_lines = filter_fasta_file(file_path = vamp_ref_seqs, exclude_pattern = 'XXXXXXXX')
shorten_seq_names = shorten_sequence_names(filtered_lines)

# Write the contents to the output fasta file file: results -> phyl_trees -> vamp_ref_seqs.fasta
with open(filtered_fasta_file, 'w') as outfile:
    outfile.writelines(shorten_seq_names)

# %% [markdown]
# ### Combine the new sequences with our vampyrella reference sequence database

# %%
# Reference alignment path
vamp_ref_seqs = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'vamp_ref_seqs.fasta')

# Path to the new sequences
# new_vamp_seqs = os.path.join(new_seq_dir, 'all_samples.fasta')

new_vamp_seqs = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', 'extracted_18S_merged.fasta')

# Path to the output directory and name of the output file
# output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim)
output_dir = os.path.join(results_path, 'phyl_trees', 'all_projects_combined')

combined_alignment = os.path.join(output_dir, 'vamp_ref_and_new_seqs_comb.fasta')

# Combine ref. sequences fasta file and new vamp sequences

# Read the contents of the reference sequences file
with open(vamp_ref_seqs, 'r') as file1:
    content1 = file1.read()

# Read the contents of the denoised sequences file
with open(new_vamp_seqs, 'r') as file2:
    content2 = file2.read()

# Write the combined contents to the new file: results -> phyl_trees -> vamp_ref_and_new_seqs_comb.fasta
with open(combined_alignment, 'w') as infile:
    infile.write(content1 + '\n' + content2)

print(f"Combined files {new_vamp_seqs} and {vamp_ref_seqs} into {combined_alignment}")
# Out:
# Combined files ../results/phyl_trees/all_projects_combined/extracted_18S_merged.fasta and ../results/phyl_trees/Suthaus_2022/Full18S/RAD/sim_90/vamp_ref_seqs.fasta into ../results/phyl_trees/all_projects_combined/vamp_ref_and_new_seqs_comb.fasta

# %% [markdown]
# # Create alignment

# %%
# Creating alignment
# input_sequences = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'vamp_ref_and_new_seqs_comb.fasta')
input_sequences = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', 'vamp_ref_and_new_seqs_comb.fasta')

# output_sequences = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
output_sequences = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', 'vamp_mafft.fasta')

# log_file = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.log')
log_file = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', 'vamp_mafft.log')


run_mafft(input_file = input_sequences, 
          output_file = output_sequences, 
          log_file = log_file, 
          method = 'localpair', 
          maxiterate_num = 1000)
# Out:
# Alignment was saved to: ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta
# Log file was saved to: ../results/phyl_trees/all_projects_combined/vamp_mafft.log
# 0

# %%
# Alignment stats
alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')


num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment)

print(f'''
Number of sequences: {num_sequences}
Alignment length: {alignment_length} base pairs
Average number of gaps per sequence: {round(average_gaps, 2)}
Percentage gaps: {round(percentage_gaps, 2)}%
Percentage identity: {round(percentage_identity, 2)}%
''')

# %%
# Alignment stats
# alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')

alignment = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', 'vamp_mafft.fasta')


num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment)

print(f'''
Number of sequences: {num_sequences}
Alignment length: {alignment_length} base pairs
Average number of gaps per sequence: {round(average_gaps, 2)}
Percentage gaps: {round(percentage_gaps, 2)}%
Percentage identity: {round(percentage_identity, 2)}%
''')

# %% [markdown]
# # Check alignment

# %%
# Check the alignment manually to see how does it look like

# %% [markdown]
# # Gblocks: masking poorly aligned positions

# %%
# Define the Parameter Range
Defining the range of values we want to explore for each parameter
mafft_alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')

# Number of sequences and half of the sequences in the alignemnt as a baseline for Gblocks parameters
num_seqs_ = num_seqs(mafft_alignment)
print(f'Total number of sequences in the alignment: {num_seqs_}')
half_num_seqs = math.floor(num_seqs_ / 2) + 1 # half of the sequences, rounded down
print(f'Half of the sequences in the alignment (rounded down): {half_num_seqs}')

# b1
# Description: Minimum Number of Sequences for a Conserved Position
# Minimum is half of the sequences in the alignment.
step_size_b1 = 20
start_b1 = 0
stop_b1 = step_size_b1 * 10
b1_values = [half_num_seqs + i for i in range(start_b1, stop_b1, step_size_b1)]

# b2
# Description: Minimum Number Of Sequences For A Flank Position.
# The lower limit for b2 is the value you set for b1.
step_size_b2 = 20
start_b2 = 0
stop_b2 = step_size_b2 * 10
b2_values = [half_num_seqs + i for i in range(start_b2, stop_b2, step_size_b2)]

# b3:
# Description: Maximum Number Of Contiguous Nonconserved Positions.
# Setting this value too high can include regions of the alignment that are too variable, 
# whereas setting it too low can exclude potentially informative parts of the alignment.
# Default = 8.
step_size_b3 = 5
start_b3 = 8
stop_b3 = (step_size_b3 * 10) + start_b3
b3_values = list(range(start_b3, stop_b3, step_size_b3))

# b4:
# Description: Minimum Length Of A Block.
# Any block that's shorter than the number set will be excluded from the final alignment.
# Default = 10.
step_size_b4 = 5
start_b4 = 10
stop_b4 =  (step_size_b4 * 10) + start_b4
b4_values = list(range(start_b4, stop_b4, step_size_b4))

# v5
# Description: Allowed Gap Positions.
# a: all gaps allowed (the most relaxed setting)
# h: half (a balanced approach)
# n: no gaps allowed (the most strict setting)
b5_values = ['a', 'h', 'n']

print(f'''
b1: {b1_values}
b2: {b2_values}
b3: {b3_values}
b4: {b4_values}
b5: {b5_values}
''')

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
alignment = os.path.join(alignments_path, 'vamp_mafft.fasta')
gblocks_path = os.path.join('..', 'raw_data', 'packages', 'Gblocks_0.91b', 'Gblocks')


run_gblocks_grid_search(mafft_alignment = alignment,
                        b1_values = b1_values,
                        b2_values = b2_values,
                        b3_values = b3_values,
                        b4_values = b4_values,
                        b5_values = b5_values,
                        gblocks_path = gblocks_path)

# Move all the output files to the separate 'grid_search' directory
move_search_grid_files(directory_path = alignments_path, 
                       grid_search_path = os.path.join(alignments_path, 'grid_search'))

# %%
# Checking some basic statistics about our MAFFT alignment
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')

fasta_files = [fasta for fasta in os.listdir(grid_search_path) if '.fasta' in fasta and '_h_' in fasta]

for fasta_file in fasta_files:
    alignment_path = os.path.join(grid_search_path, fasta_file)
    parameters = fasta_file.split('grid_')[1].strip('.fasta')
    print(f'Paramters: {parameters}')
    num_sequences, alignment_length, average_gaps, percentage_gaps, percentage_identity = alignment_stats(alignment_file = alignment_path)
    print(f"Number of sequences: {num_sequences}")
    print(f"Alignment length: {alignment_length}")
    print(f"Average number of gaps per sequence: {average_gaps:.2f}")
    print(f"Percentage of gaps across the sequences: {percentage_gaps:.2f}%")
    print(f"Average percentage identity: {percentage_identity:.2f}%")
    print('\n')

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')
fasta_files = [fasta for fasta in os.listdir(grid_search_path) if '.fasta' in fasta and '_h_' in fasta]
results = []

for fasta_file in fasta_files:
    metrics = alignment_stats(os.path.join(grid_search_path, fasta_file))
    b5_value = fasta_file.split("_grid_")[1].split("_")[0]
    iteration_num = fasta_file.split("_grid_")[1].split("_")[1].strip('.fasta')
    results.append((b5_value, iteration_num) + metrics)

# %%
# Create a dataframe from the grid results
grid_df = pd.DataFrame(results, columns=['b5_value', 
                                         'iteration_num', 
                                         'num_sequences', 
                                         'alignment_length', 
                                         'avg_num_gaps', 
                                         'percentage_gaps', 
                                         'avg_percentage_identity'])
# Sort the dataframe based on the iteration number
grid_df = grid_df.sort_values(by='iteration_num').reset_index(drop=True)

# Add the values from the Gblocks parameters
grid_df['b1_value'] = b1_values
grid_df['b2_value'] = b2_values
grid_df['b3_value'] = b3_values
grid_df['b4_value'] = b4_values

# %%
grid_df

# %%
alignments_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments')
grid_search_path = os.path.join(alignments_path, 'grid_search')

# Visualization

# Set style of seaborn plot
sns.set(style="white")

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Define the metrics and their respective labels
metrics = ['alignment_length', 'avg_num_gaps', 'percentage_gaps', 'avg_percentage_identity']
labels = ['Alignment Length', 'Average Number of Gaps', 'Percentage of Gaps', 'Average Percentage Identity']

# Iterate over each metric and plot it in its subplot
for ax, metric, label in zip(axes.ravel(), metrics, labels):
    sns.lineplot(x='iteration_num', y=metric, data=grid_df, color='lightcoral', ax=ax)
    ax.set_title(label + ' vs Iteration Number', fontweight='bold')
    ax.set_xlabel('')
    ax.set_ylabel(label)
    # Set visibility for spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(True)
    ax.spines['left'].set_visible(True)

# # Adjust layout for better spacing
# plt.tight_layout()
# plt.show()

# save path
save_path = os.path.join(grid_search_path, 'pr2_ref_align_gblocks_grid_search_h.png')
# Save the figure
# plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# # Create Maximum Likelihood tree

# %%
# Variables:
# alignment = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
model = 'GTR+G'

# alignment = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', 'vamp_mafft_cut.fasta')

alignment = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', 'vamp_mafft.fasta')

# %%
# # Run raxml-ng (https://github.com/amkozlov/raxml-ng/wiki/Tutorial) to check the alignment and save the output in the specified directory.
# prefix = 'T1'
# output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, prefix)

prefix = 'T1_data_check'
# output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)
output_dir = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

run_raxmlng_check(alignment = alignment, 
                  output_dir = output_dir, 
                  model = model, 
                  prefix = prefix)
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 11-Dec-2023 11:53:07 as follows:
#
# raxml-ng --check --msa ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta --model GTR+G --prefix T1_data_check
#
# Analysis options:
#   run mode: Alignment validation
#   start tree(s):
#   random seed: 1702291987
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# [00:00:00] Reading alignment from file: ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta
# [00:00:00] Loaded alignment with 183 taxa and 2038 sites
#
# WARNING: Fully undetermined columns found: 7
#
# WARNING: Sequences Thalassomyxa_strain_KibAr_KC779519 and Thalassomyxa_strain_V1ld4_KC779520 are exactly identical!
# WARNING: Sequences 93ec799fa70cc9a684fdbec04fb423d8_Sim17 and 93ec799fa70cc9a684fdbec04fb423d8_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim17 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th38 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th40 are exactly identical!
# WARNING: Sequences fa04010ef186193e6af2567e8e77c9fd_Sim17 and fa04010ef186193e6af2567e8e77c9fd_Sim22 are exactly identical!
# WARNING: Sequences Placopus_X_GU385615 and Placopus_XX_GU385647 are exactly identical!
# WARNING: Duplicate sequences found: 8
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T1_data_check.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 2031 sites
#
# Partition 0: noname
# Model: GTR+FO+G4m
# Alignment sites: 2031
# Gaps: 32.33 %
# Invariant sites: 41.36 %
#
#
#
# Alignment can be successfully read by RAxML-NG.
#
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T1_data_check.raxml.log
#
# Analysis started: 11-Dec-2023 11:53:07 / finished: 11-Dec-2023 11:53:07
#
# Elapsed time: 0.081 seconds
#
#
# Output files were moved to: ../results/phyl_trees/all_projects_combined/T1_data_check
# 0

# %%
# # Run raxml-ng to compute the maximum likelihood tree and save the output in the specified directory
# prefix = 'T2'
# output_dir = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, prefix)


prefix = 'T2_MLtree'
# output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)
output_dir = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

run_raxmlng_tree(alignment = alignment, 
                 output_dir = output_dir, 
                 model = model, 
                 prefix= prefix)
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 11-Dec-2023 11:53:33 as follows:
#
# raxml-ng --msa ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta --model GTR+G --prefix T2_MLtree --threads 3 --seed 2 --tree pars{25},rand{25}
#
# Analysis options:
#   run mode: ML tree search
#   start tree(s): random (25) + parsimony (25)
#   random seed: 2
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (3 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta
# [00:00:00] Loaded alignment with 183 taxa and 2038 sites
#
# WARNING: Fully undetermined columns found: 7
#
# WARNING: Sequences Thalassomyxa_strain_KibAr_KC779519 and Thalassomyxa_strain_V1ld4_KC779520 are exactly identical!
# WARNING: Sequences 93ec799fa70cc9a684fdbec04fb423d8_Sim17 and 93ec799fa70cc9a684fdbec04fb423d8_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim17 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th38 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th40 are exactly identical!
# WARNING: Sequences fa04010ef186193e6af2567e8e77c9fd_Sim17 and fa04010ef186193e6af2567e8e77c9fd_Sim22 are exactly identical!
# WARNING: Sequences Placopus_X_GU385615 and Placopus_XX_GU385647 are exactly identical!
# WARNING: Duplicate sequences found: 8
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 1485 patterns
#
# Partition 0: noname
# Model: GTR+FO+G4m
# Alignment sites / patterns: 2031 / 1485
# Gaps: 32.33 %
# Invariant sites: 41.36 %
#
#
# NOTE: Binary MSA file created: T2_MLtree.raxml.rba
#
# Parallelization scheme autoconfig: 3 worker(s) x 1 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Generating 25 random starting tree(s) with 183 taxa
# [00:00:00] Generating 25 parsimony starting tree(s) with 183 taxa
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 1485 / 23760
# [00:00:00] Data distribution: max. searches per worker: 17
#
# Starting ML tree search with 50 distinct starting trees
#
# [00:02:05] [worker #1] ML tree search #2, logLikelihood: -45602.008558
# [00:02:05] [worker #2] ML tree search #3, logLikelihood: -45607.120366
# [00:02:14] [worker #0] ML tree search #1, logLikelihood: -45598.523880
# [00:04:08] [worker #1] ML tree search #5, logLikelihood: -45597.674720
# [00:04:27] [worker #2] ML tree search #6, logLikelihood: -45600.904169
# [00:04:31] [worker #0] ML tree search #4, logLikelihood: -45597.393653
# [00:06:21] [worker #1] ML tree search #8, logLikelihood: -45597.274465
# [00:06:29] [worker #0] ML tree search #7, logLikelihood: -45598.685906
# [00:06:33] [worker #2] ML tree search #9, logLikelihood: -45597.891970
# [00:08:42] [worker #2] ML tree search #12, logLikelihood: -45601.064268
# [00:08:50] [worker #1] ML tree search #11, logLikelihood: -45597.091811
# [00:08:52] [worker #0] ML tree search #10, logLikelihood: -45596.343909
# [00:10:45] [worker #2] ML tree search #15, logLikelihood: -45599.572047
# [00:11:07] [worker #0] ML tree search #13, logLikelihood: -45604.412971
# [00:11:09] [worker #1] ML tree search #14, logLikelihood: -45600.792540
# [00:13:19] [worker #0] ML tree search #16, logLikelihood: -45600.599463
# [00:13:29] [worker #1] ML tree search #17, logLikelihood: -45597.361195
# [00:13:30] [worker #2] ML tree search #18, logLikelihood: -45599.134496
# [00:15:23] [worker #0] ML tree search #19, logLikelihood: -45603.982796
# [00:15:41] [worker #2] ML tree search #21, logLikelihood: -45598.371858
# [00:15:45] [worker #1] ML tree search #20, logLikelihood: -45597.138792
# [00:17:34] [worker #0] ML tree search #22, logLikelihood: -45596.335449
# [00:17:58] [worker #2] ML tree search #24, logLikelihood: -45597.727585
# [00:18:04] [worker #1] ML tree search #23, logLikelihood: -45606.929572
# [00:19:50] [worker #2] ML tree search #27, logLikelihood: -45596.594805
# [00:19:51] [worker #1] ML tree search #26, logLikelihood: -45597.752833
# [00:19:54] [worker #0] ML tree search #25, logLikelihood: -45598.899516
# [00:21:15] [worker #2] ML tree search #30, logLikelihood: -45597.681192
# [00:21:34] [worker #1] ML tree search #29, logLikelihood: -45600.671089
# [00:21:38] [worker #0] ML tree search #28, logLikelihood: -45597.764798
# [00:22:57] [worker #2] ML tree search #33, logLikelihood: -45597.426304
# [00:23:18] [worker #1] ML tree search #32, logLikelihood: -45603.039861
# [00:23:28] [worker #0] ML tree search #31, logLikelihood: -45601.447998
# [00:24:45] [worker #2] ML tree search #36, logLikelihood: -45597.687269
# [00:25:03] [worker #1] ML tree search #35, logLikelihood: -45597.986655
# [00:25:20] [worker #0] ML tree search #34, logLikelihood: -45596.646024
# [00:26:30] [worker #2] ML tree search #39, logLikelihood: -45599.377414
# [00:27:01] [worker #0] ML tree search #37, logLikelihood: -45598.770785
# [00:27:02] [worker #1] ML tree search #38, logLikelihood: -45597.594252
# [00:28:27] [worker #0] ML tree search #40, logLikelihood: -45599.631098
# [00:28:30] [worker #2] ML tree search #42, logLikelihood: -45596.844256
# [00:29:00] [worker #1] ML tree search #41, logLikelihood: -45603.161321
# [00:29:56] [worker #0] ML tree search #43, logLikelihood: -45597.962794
# [00:30:23] [worker #2] ML tree search #45, logLikelihood: -45597.697977
# [00:30:34] [worker #1] ML tree search #44, logLikelihood: -45596.189598
# [00:31:32] [worker #0] ML tree search #46, logLikelihood: -45596.793565
# [00:31:58] [worker #2] ML tree search #48, logLikelihood: -45598.243831
# [00:32:18] [worker #1] ML tree search #47, logLikelihood: -45596.599657
# [00:33:14] [worker #0] ML tree search #49, logLikelihood: -45600.541127
# [00:33:49] [worker #1] ML tree search #50, logLikelihood: -45599.731702
#
# Optimized model parameters:
#
#    Partition 0: noname
#    Rate heterogeneity: GAMMA (4 cats, mean),  alpha: 0.365375 (ML),  weights&rates: (0.250000,0.012052) (0.250000,0.155459) (0.250000,0.690919) (0.250000,3.141570)
#    Base frequencies (ML): 0.263172 0.189752 0.232549 0.314527
#    Substitution rates (ML): 1.174110 3.455438 1.540679 0.891537 4.835594 1.000000
#
#
# Final LogLikelihood: -45596.189598
#
# AIC score: 91936.379195 / AICc score: 92103.756759 / BIC score: 94025.636680
# Free parameters (model + branch lengths): 372
#
# WARNING: Best ML tree contains 13 near-zero branches!
#
# Best ML tree with collapsed near-zero branches saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.bestTreeCollapsed
# Best ML tree saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.bestTree
# All ML trees saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.mlTrees
# Optimized model saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.bestModel
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T2_MLtree.raxml.log
#
# Analysis started: 11-Dec-2023 11:53:33 / finished: 11-Dec-2023 12:27:23
#
# Elapsed time: 2029.973 seconds
#
#
# Output files were moved to: ../results/phyl_trees/all_projects_combined/T2_MLtree
# 0

# %% [markdown]
# ## Inferring bootstrap trees

# %%
prefix = 'T3_bootstraps'
model = 'GTR+G'
# output_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree', prefix)
output_dir = os.path.join(results_path, 'phyl_trees', 'all_projects_combined', prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)


run_raxmlng_bootstrap(alignment = alignment,
                      output_dir = output_dir, 
                      model = model, 
                      prefix = prefix)
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 11-Dec-2023 12:33:00 as follows:
#
# raxml-ng --bootstrap --msa ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta --model GTR+G --prefix T3_bootstraps --threads 3 --seed 2
#
# Analysis options:
#   run mode: Bootstrapping
#   start tree(s):
#   bootstrap replicates: max: 1000 + bootstopping (autoMRE, cutoff: 0.030000)
#   random seed: 2
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (3 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: ../results/phyl_trees/all_projects_combined/vamp_mafft.fasta
# [00:00:00] Loaded alignment with 183 taxa and 2038 sites
#
# WARNING: Fully undetermined columns found: 7
#
# WARNING: Sequences Thalassomyxa_strain_KibAr_KC779519 and Thalassomyxa_strain_V1ld4_KC779520 are exactly identical!
# WARNING: Sequences 93ec799fa70cc9a684fdbec04fb423d8_Sim17 and 93ec799fa70cc9a684fdbec04fb423d8_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim17 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Sim22 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th38 are exactly identical!
# WARNING: Sequences 91b1f98492eba26f9f791cf7949afb56_NH4 and 91b1f98492eba26f9f791cf7949afb56_Th40 are exactly identical!
# WARNING: Sequences fa04010ef186193e6af2567e8e77c9fd_Sim17 and fa04010ef186193e6af2567e8e77c9fd_Sim22 are exactly identical!
# WARNING: Sequences Placopus_X_GU385615 and Placopus_XX_GU385647 are exactly identical!
# WARNING: Duplicate sequences found: 8
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_bootstraps.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 1485 patterns
#
# Partition 0: noname
# Model: GTR+FO+G4m
# Alignment sites / patterns: 2031 / 1485
# Gaps: 32.33 %
# Invariant sites: 41.36 %
#
#
# NOTE: Binary MSA file created: T3_bootstraps.raxml.rba
#
# Parallelization scheme autoconfig: 3 worker(s) x 1 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 1485 / 23760
# [00:00:00] Data distribution: max. searches per worker: 334
# [00:00:00] Starting bootstrapping analysis with 1000 replicates.
#
# [00:01:21] [worker #1] Bootstrap tree #2, logLikelihood: -44869.031379
# [00:01:57] [worker #0] Bootstrap tree #1, logLikelihood: -44429.424950
# [00:02:03] [worker #2] Bootstrap tree #3, logLikelihood: -41538.998050
# [00:02:46] [worker #1] Bootstrap tree #5, logLikelihood: -44154.887935
# [00:03:25] [worker #0] Bootstrap tree #4, logLikelihood: -46735.432134
# [00:03:36] [worker #2] Bootstrap tree #6, logLikelihood: -44204.626810
# [00:04:18] [worker #1] Bootstrap tree #8, logLikelihood: -45237.013310
# [00:04:53] [worker #0] Bootstrap tree #7, logLikelihood: -45025.108039
# [00:05:04] [worker #2] Bootstrap tree #9, logLikelihood: -44321.401318
# [00:05:55] [worker #1] Bootstrap tree #11, logLikelihood: -44991.322776
# [00:06:28] [worker #0] Bootstrap tree #10, logLikelihood: -46297.575597
# [00:06:42] [worker #2] Bootstrap tree #12, logLikelihood: -45301.455693
# [00:07:24] [worker #1] Bootstrap tree #14, logLikelihood: -44979.176957
# [00:08:09] [worker #0] Bootstrap tree #13, logLikelihood: -45527.835447
# [00:08:44] [worker #1] Bootstrap tree #17, logLikelihood: -44629.531396
# [00:08:47] [worker #2] Bootstrap tree #15, logLikelihood: -44525.196343
# [00:09:33] [worker #0] Bootstrap tree #16, logLikelihood: -44171.314032
# [00:10:03] [worker #1] Bootstrap tree #20, logLikelihood: -45106.576272
# [00:10:16] [worker #2] Bootstrap tree #18, logLikelihood: -45043.556774
# [00:10:53] [worker #0] Bootstrap tree #19, logLikelihood: -46861.191130
# [00:11:30] [worker #1] Bootstrap tree #23, logLikelihood: -45612.785555
# [00:11:43] [worker #2] Bootstrap tree #21, logLikelihood: -44679.631491
# [00:12:23] [worker #0] Bootstrap tree #22, logLikelihood: -43531.625920
# [00:12:53] [worker #1] Bootstrap tree #26, logLikelihood: -45836.364393
# [00:13:18] [worker #2] Bootstrap tree #24, logLikelihood: -45679.234231
# [00:14:28] [worker #1] Bootstrap tree #29, logLikelihood: -46210.583345
# [00:14:40] [worker #0] Bootstrap tree #25, logLikelihood: -45534.833653
# [00:14:50] [worker #2] Bootstrap tree #27, logLikelihood: -44176.573705
# [00:15:53] [worker #1] Bootstrap tree #32, logLikelihood: -44201.235241
# [00:16:11] [worker #0] Bootstrap tree #28, logLikelihood: -45658.176384
# [00:16:14] [worker #2] Bootstrap tree #30, logLikelihood: -43904.940985
# [00:17:23] [worker #1] Bootstrap tree #35, logLikelihood: -44544.794288
# [00:18:01] [worker #0] Bootstrap tree #31, logLikelihood: -45748.649649
# [00:18:15] [worker #2] Bootstrap tree #33, logLikelihood: -44704.875511
# [00:19:14] [worker #1] Bootstrap tree #38, logLikelihood: -46604.386623
# [00:19:41] [worker #2] Bootstrap tree #36, logLikelihood: -44537.568006
# [00:20:49] [worker #0] Bootstrap tree #34, logLikelihood: -44246.756522
# [00:21:05] [worker #1] Bootstrap tree #41, logLikelihood: -46216.407663
# [00:21:16] [worker #2] Bootstrap tree #39, logLikelihood: -44930.794227
# [00:22:15] [worker #0] Bootstrap tree #37, logLikelihood: -47306.143572
# [00:23:36] [worker #2] Bootstrap tree #42, logLikelihood: -45014.811279
# [00:24:08] [worker #1] Bootstrap tree #44, logLikelihood: -47618.101763
# [00:24:48] [worker #0] Bootstrap tree #40, logLikelihood: -46813.909839
# [00:25:24] [worker #2] Bootstrap tree #45, logLikelihood: -47038.344024
# [00:25:38] [worker #1] Bootstrap tree #47, logLikelihood: -45887.572007
# [00:26:18] [worker #0] Bootstrap tree #43, logLikelihood: -47532.942698
# [00:26:59] [worker #2] Bootstrap tree #48, logLikelihood: -46008.736846
# [00:27:03] [worker #1] Bootstrap tree #50, logLikelihood: -47125.038846
# [00:28:06] [worker #0] Bootstrap tree #46, logLikelihood: -45595.041661
# [00:29:28] [worker #0] Bootstrap tree #49, logLikelihood: -45921.936539
# [00:32:04] [worker #1] Bootstrap tree #53, logLikelihood: -45731.780371
# [00:32:06] [worker #0] Bootstrap tree #52, logLikelihood: -44387.628081
# [00:32:36] [worker #2] Bootstrap tree #51, logLikelihood: -47714.321316
# [00:34:05] [worker #1] Bootstrap tree #56, logLikelihood: -44424.284085
# [00:34:26] [worker #0] Bootstrap tree #55, logLikelihood: -45448.171458
# [00:35:29] [worker #2] Bootstrap tree #54, logLikelihood: -48083.665035
# [00:35:32] [worker #1] Bootstrap tree #59, logLikelihood: -44559.826016
# [00:36:16] [worker #0] Bootstrap tree #58, logLikelihood: -47896.193665
# [00:36:57] [worker #1] Bootstrap tree #62, logLikelihood: -43725.376548
# [00:37:23] [worker #2] Bootstrap tree #57, logLikelihood: -45611.242572
# [00:38:09] [worker #0] Bootstrap tree #61, logLikelihood: -45808.721200
# [00:38:31] [worker #1] Bootstrap tree #65, logLikelihood: -46167.646496
# [00:38:59] [worker #2] Bootstrap tree #60, logLikelihood: -43314.818462
# [00:39:39] [worker #0] Bootstrap tree #64, logLikelihood: -43609.478242
# [00:40:21] [worker #2] Bootstrap tree #63, logLikelihood: -46133.117314
# [00:40:27] [worker #1] Bootstrap tree #68, logLikelihood: -46675.947752
# [00:41:06] [worker #0] Bootstrap tree #67, logLikelihood: -46240.577436
# [00:41:45] [worker #2] Bootstrap tree #66, logLikelihood: -46440.108293
# [00:42:32] [worker #0] Bootstrap tree #70, logLikelihood: -43997.420310
# [00:42:40] [worker #1] Bootstrap tree #71, logLikelihood: -43330.590882
# [00:43:09] [worker #2] Bootstrap tree #69, logLikelihood: -45718.229156
# [00:44:08] [worker #1] Bootstrap tree #74, logLikelihood: -44211.336475
# [00:44:49] [worker #0] Bootstrap tree #73, logLikelihood: -44469.484198
# [00:44:53] [worker #2] Bootstrap tree #72, logLikelihood: -47126.196673
# [00:45:48] [worker #1] Bootstrap tree #77, logLikelihood: -45872.251446
# [00:46:33] [worker #2] Bootstrap tree #75, logLikelihood: -43704.957265
# [00:46:53] [worker #0] Bootstrap tree #76, logLikelihood: -44422.746710
# [00:47:18] [worker #1] Bootstrap tree #80, logLikelihood: -46388.293324
# [00:48:03] [worker #2] Bootstrap tree #78, logLikelihood: -44628.717472
# [00:48:25] [worker #0] Bootstrap tree #79, logLikelihood: -45426.545674
# [00:49:01] [worker #1] Bootstrap tree #83, logLikelihood: -45407.401334
# [00:49:38] [worker #2] Bootstrap tree #81, logLikelihood: -44447.944043
# [00:50:17] [worker #0] Bootstrap tree #82, logLikelihood: -43902.060304
# [00:51:01] [worker #1] Bootstrap tree #86, logLikelihood: -43619.057366
# [00:51:10] [worker #2] Bootstrap tree #84, logLikelihood: -45768.258806
# [00:51:39] [worker #0] Bootstrap tree #85, logLikelihood: -45797.572890
# [00:52:23] [worker #1] Bootstrap tree #89, logLikelihood: -45121.799412
# [03:12:06] [worker #1] Bootstrap tree #326, logLikelihood: -43751.883186
# [03:12:29] [worker #2] Bootstrap tree #327, logLikelihood: -43126.794411
# [03:13:06] [worker #0] Bootstrap tree #322, logLikelihood: -44345.482080
# [03:13:48] [worker #1] Bootstrap tree #329, logLikelihood: -46789.709687
# [03:14:07] [worker #2] Bootstrap tree #330, logLikelihood: -45141.989574
# [03:14:53] [worker #0] Bootstrap tree #325, logLikelihood: -44557.051434
# [03:15:25] [worker #1] Bootstrap tree #332, logLikelihood: -45170.997468
# [03:15:35] [worker #2] Bootstrap tree #333, logLikelihood: -44837.828027
# [03:16:47] [worker #0] Bootstrap tree #328, logLikelihood: -45276.636446
# [03:17:08] [worker #2] Bootstrap tree #336, logLikelihood: -44812.870004
# [03:17:11] [worker #1] Bootstrap tree #335, logLikelihood: -44861.071140
# [03:18:16] [worker #0] Bootstrap tree #331, logLikelihood: -45181.686971
# [03:18:43] [worker #1] Bootstrap tree #338, logLikelihood: -45482.847845
# [03:18:52] [worker #2] Bootstrap tree #339, logLikelihood: -44923.849455
# [03:19:56] [worker #0] Bootstrap tree #334, logLikelihood: -45356.025356
# [03:20:33] [worker #2] Bootstrap tree #342, logLikelihood: -44707.189410
# [03:20:40] [worker #1] Bootstrap tree #341, logLikelihood: -46249.822773
# [03:21:22] [worker #0] Bootstrap tree #337, logLikelihood: -45975.642403
# [03:21:54] [worker #2] Bootstrap tree #345, logLikelihood: -45818.834600
# [03:22:00] [worker #1] Bootstrap tree #344, logLikelihood: -45103.901750
# [03:22:54] [worker #0] Bootstrap tree #340, logLikelihood: -48193.986620
# [03:23:41] [worker #2] Bootstrap tree #348, logLikelihood: -45923.782536
# [03:23:54] [worker #1] Bootstrap tree #347, logLikelihood: -45901.074617
# [03:24:23] [worker #0] Bootstrap tree #343, logLikelihood: -46409.302135
# [03:25:22] [worker #1] Bootstrap tree #350, logLikelihood: -44023.855421
# [03:25:45] [worker #0] Bootstrap tree #346, logLikelihood: -45394.117227
# [03:26:59] [worker #0] Bootstrap tree #349, logLikelihood: -46184.381968
# [03:28:39] [worker #2] Bootstrap tree #351, logLikelihood: -45634.639135
# [03:29:01] [worker #1] Bootstrap tree #353, logLikelihood: -45674.811987
# [03:29:01] [worker #0] Bootstrap tree #352, logLikelihood: -42347.560909
# [03:30:12] [worker #2] Bootstrap tree #354, logLikelihood: -46141.502680
# [03:30:28] [worker #1] Bootstrap tree #356, logLikelihood: -43972.301715
# [03:30:33] [worker #0] Bootstrap tree #355, logLikelihood: -45425.533981
# [03:31:46] [worker #2] Bootstrap tree #357, logLikelihood: -48201.454213
# [03:31:55] [worker #1] Bootstrap tree #359, logLikelihood: -42010.887916
# [03:32:06] [worker #0] Bootstrap tree #358, logLikelihood: -46701.920875
# [03:33:12] [worker #2] Bootstrap tree #360, logLikelihood: -46322.245659
# [03:33:16] [worker #1] Bootstrap tree #362, logLikelihood: -45695.529464
# [03:33:55] [worker #0] Bootstrap tree #361, logLikelihood: -46560.728344
# [03:34:45] [worker #1] Bootstrap tree #365, logLikelihood: -45382.925828
# [03:35:03] [worker #2] Bootstrap tree #363, logLikelihood: -42833.179416
# [03:36:13] [worker #0] Bootstrap tree #364, logLikelihood: -46099.299520
# [03:36:14] [worker #1] Bootstrap tree #368, logLikelihood: -45979.593330
# [03:36:33] [worker #2] Bootstrap tree #366, logLikelihood: -45141.285902
# [03:37:39] [worker #0] Bootstrap tree #367, logLikelihood: -46867.533028
# [03:37:49] [worker #1] Bootstrap tree #371, logLikelihood: -46512.199567
# [03:38:03] [worker #2] Bootstrap tree #369, logLikelihood: -45804.578312
# [03:39:22] [worker #0] Bootstrap tree #370, logLikelihood: -44058.935374
# [03:39:36] [worker #1] Bootstrap tree #374, logLikelihood: -46700.773233
# [03:39:52] [worker #2] Bootstrap tree #372, logLikelihood: -43934.127771
# [03:40:55] [worker #0] Bootstrap tree #373, logLikelihood: -46204.093529
# [03:40:55] [worker #1] Bootstrap tree #377, logLikelihood: -47343.414985
# [03:41:38] [worker #2] Bootstrap tree #375, logLikelihood: -46991.033265
# [03:42:20] [worker #1] Bootstrap tree #380, logLikelihood: -44077.060330
# [03:42:45] [worker #0] Bootstrap tree #376, logLikelihood: -44567.536690
# [03:43:03] [worker #2] Bootstrap tree #378, logLikelihood: -43420.702399
# [03:43:55] [worker #1] Bootstrap tree #383, logLikelihood: -46525.666595
# [03:44:24] [worker #0] Bootstrap tree #379, logLikelihood: -45698.319796
# [03:44:27] [worker #2] Bootstrap tree #381, logLikelihood: -43306.135707
# [03:45:22] [worker #1] Bootstrap tree #386, logLikelihood: -45318.943867
# [03:46:08] [worker #0] Bootstrap tree #382, logLikelihood: -44276.520350
# [03:46:14] [worker #2] Bootstrap tree #384, logLikelihood: -46118.567649
# [03:46:42] [worker #1] Bootstrap tree #389, logLikelihood: -45023.374370
# [03:47:31] [worker #2] Bootstrap tree #387, logLikelihood: -44398.148655
# [03:47:32] [worker #0] Bootstrap tree #385, logLikelihood: -45184.943536
# [03:48:05] [worker #1] Bootstrap tree #392, logLikelihood: -45582.531773
# [03:48:54] [worker #2] Bootstrap tree #390, logLikelihood: -44327.638738
# [03:49:02] [worker #0] Bootstrap tree #388, logLikelihood: -45418.903333
# [03:49:28] [worker #1] Bootstrap tree #395, logLikelihood: -45301.680483
# [03:50:27] [worker #2] Bootstrap tree #393, logLikelihood: -45506.517498
# [03:50:38] [worker #0] Bootstrap tree #391, logLikelihood: -43830.297405
# [03:51:23] [worker #1] Bootstrap tree #398, logLikelihood: -45584.310022
# [03:51:57] [worker #0] Bootstrap tree #394, logLikelihood: -42617.294599
# [03:51:58] [worker #2] Bootstrap tree #396, logLikelihood: -44020.720766
# [03:53:18] [worker #2] Bootstrap tree #399, logLikelihood: -43365.933664
# [03:53:21] [worker #0] Bootstrap tree #397, logLikelihood: -44435.880727
# [03:54:45] [worker #0] Bootstrap tree #400, logLikelihood: -43526.364070
# [03:56:13] [worker #0] Bootstrap tree #403, logLikelihood: -45656.602073
# [03:56:16] [worker #1] Bootstrap tree #401, logLikelihood: -43357.752279
# [03:56:41] [worker #2] Bootstrap tree #402, logLikelihood: -46476.002284
# [03:57:34] [worker #1] Bootstrap tree #404, logLikelihood: -46197.177016
# [03:57:45] [worker #0] Bootstrap tree #406, logLikelihood: -46141.104815
# [03:58:04] [worker #2] Bootstrap tree #405, logLikelihood: -44486.688680
# [03:59:07] [worker #1] Bootstrap tree #407, logLikelihood: -45264.043701
# [03:59:16] [worker #0] Bootstrap tree #409, logLikelihood: -45395.559102
# [03:59:31] [worker #2] Bootstrap tree #408, logLikelihood: -45889.253552
# [04:00:36] [worker #1] Bootstrap tree #410, logLikelihood: -45846.465373
# [04:00:42] [worker #0] Bootstrap tree #412, logLikelihood: -46730.742494
# [04:00:57] [worker #2] Bootstrap tree #411, logLikelihood: -44352.817512
# [04:02:10] [worker #1] Bootstrap tree #413, logLikelihood: -50114.487817
# [04:02:25] [worker #2] Bootstrap tree #414, logLikelihood: -46492.944323
# [04:02:37] [worker #0] Bootstrap tree #415, logLikelihood: -43176.847691
# [04:03:39] [worker #1] Bootstrap tree #416, logLikelihood: -46014.258841
# [04:03:49] [worker #2] Bootstrap tree #417, logLikelihood: -45645.229377
# [04:04:02] [worker #0] Bootstrap tree #418, logLikelihood: -43713.521249
# [04:05:07] [worker #1] Bootstrap tree #419, logLikelihood: -44983.673184
# [04:05:12] [worker #2] Bootstrap tree #420, logLikelihood: -41906.431849
# [04:06:12] [worker #0] Bootstrap tree #421, logLikelihood: -43556.286822
# [04:06:30] [worker #1] Bootstrap tree #422, logLikelihood: -42863.739108
# [04:06:38] [worker #2] Bootstrap tree #423, logLikelihood: -45623.255960
# [04:07:39] [worker #0] Bootstrap tree #424, logLikelihood: -44659.584302
# [04:08:09] [worker #2] Bootstrap tree #426, logLikelihood: -44875.359595
# [04:08:29] [worker #1] Bootstrap tree #425, logLikelihood: -43028.335556
# [04:09:11] [worker #0] Bootstrap tree #427, logLikelihood: -45817.752536
# [04:09:52] [worker #1] Bootstrap tree #428, logLikelihood: -43833.289691
# [04:10:46] [worker #2] Bootstrap tree #429, logLikelihood: -45021.752425
# [04:10:58] [worker #0] Bootstrap tree #430, logLikelihood: -45361.835429
# [04:11:12] [worker #1] Bootstrap tree #431, logLikelihood: -43397.222122
# [04:12:08] [worker #2] Bootstrap tree #432, logLikelihood: -44545.711466
# [04:12:35] [worker #1] Bootstrap tree #434, logLikelihood: -45586.851238
# [04:12:44] [worker #0] Bootstrap tree #433, logLikelihood: -43789.801139
# [04:13:43] [worker #2] Bootstrap tree #435, logLikelihood: -46256.488713
# [04:14:10] [worker #0] Bootstrap tree #436, logLikelihood: -46584.482467
# [04:14:22] [worker #1] Bootstrap tree #437, logLikelihood: -44289.545750
# [04:15:28] [worker #2] Bootstrap tree #438, logLikelihood: -44215.559672
# [04:15:37] [worker #0] Bootstrap tree #439, logLikelihood: -44839.132783
# [04:15:56] [worker #1] Bootstrap tree #440, logLikelihood: -47097.021720
# [04:17:06] [worker #0] Bootstrap tree #442, logLikelihood: -45787.566049
# [04:17:23] [worker #1] Bootstrap tree #443, logLikelihood: -43481.632685
# [04:17:26] [worker #2] Bootstrap tree #441, logLikelihood: -46115.791576
# [04:18:30] [worker #0] Bootstrap tree #445, logLikelihood: -45895.384900
# [04:18:54] [worker #2] Bootstrap tree #444, logLikelihood: -45195.343282
# [04:18:55] [worker #1] Bootstrap tree #446, logLikelihood: -44653.910931
# [04:20:41] [worker #0] Bootstrap tree #448, logLikelihood: -45474.356319
# [04:20:54] [worker #2] Bootstrap tree #447, logLikelihood: -47215.416594
# [04:21:06] [worker #1] Bootstrap tree #449, logLikelihood: -46015.451266
# [04:22:15] [worker #2] Bootstrap tree #450, logLikelihood: -45412.614855
# [04:23:45] [worker #0] Bootstrap tree #451, logLikelihood: -45452.613561
# [04:23:46] [worker #1] Bootstrap tree #452, logLikelihood: -43987.932244
# [04:23:55] [worker #2] Bootstrap tree #453, logLikelihood: -46349.043295
# [04:25:16] [worker #1] Bootstrap tree #455, logLikelihood: -45358.474460
# [04:25:20] [worker #0] Bootstrap tree #454, logLikelihood: -45605.603078
# [04:25:34] [worker #2] Bootstrap tree #456, logLikelihood: -46949.432077
# [04:26:59] [worker #1] Bootstrap tree #458, logLikelihood: -44098.996220
# [04:27:05] [worker #2] Bootstrap tree #459, logLikelihood: -41903.460106
# [04:27:11] [worker #0] Bootstrap tree #457, logLikelihood: -46811.401085
# [04:28:47] [worker #0] Bootstrap tree #460, logLikelihood: -45762.383579
# [04:29:11] [worker #1] Bootstrap tree #461, logLikelihood: -46176.189910
# [04:29:23] [worker #2] Bootstrap tree #462, logLikelihood: -46835.098078
# [04:30:34] [worker #1] Bootstrap tree #464, logLikelihood: -43518.768330
# [04:31:04] [worker #0] Bootstrap tree #463, logLikelihood: -47630.958005
# [04:31:20] [worker #2] Bootstrap tree #465, logLikelihood: -45663.607902
# [04:32:10] [worker #1] Bootstrap tree #467, logLikelihood: -45251.979361
# [04:32:50] [worker #2] Bootstrap tree #468, logLikelihood: -44084.932237
# [04:33:50] [worker #1] Bootstrap tree #470, logLikelihood: -46492.233451
# [04:33:59] [worker #0] Bootstrap tree #466, logLikelihood: -45842.683788
# [04:34:23] [worker #2] Bootstrap tree #471, logLikelihood: -45085.239295
# [04:35:30] [worker #1] Bootstrap tree #473, logLikelihood: -45304.034713
# [04:35:36] [worker #0] Bootstrap tree #469, logLikelihood: -45341.701832
# [04:35:50] [worker #2] Bootstrap tree #474, logLikelihood: -45262.038404
# [04:37:01] [worker #1] Bootstrap tree #476, logLikelihood: -45382.297439
# [04:37:15] [worker #0] Bootstrap tree #472, logLikelihood: -43237.725128
# [04:37:35] [worker #2] Bootstrap tree #477, logLikelihood: -45876.888763
# [04:38:41] [worker #1] Bootstrap tree #479, logLikelihood: -44436.291651
# [04:38:52] [worker #0] Bootstrap tree #475, logLikelihood: -45626.263961
# [04:39:03] [worker #2] Bootstrap tree #480, logLikelihood: -44806.071226
# [04:40:08] [worker #1] Bootstrap tree #482, logLikelihood: -45578.041554
# [04:40:33] [worker #0] Bootstrap tree #478, logLikelihood: -43601.503692
# [04:40:42] [worker #2] Bootstrap tree #483, logLikelihood: -47453.823904
# [04:42:00] [worker #0] Bootstrap tree #481, logLikelihood: -45816.550450
# [04:42:18] [worker #1] Bootstrap tree #485, logLikelihood: -46114.171024
# [04:42:19] [worker #2] Bootstrap tree #486, logLikelihood: -43724.341030
# [04:43:47] [worker #0] Bootstrap tree #484, logLikelihood: -47118.521013
# [04:43:53] [worker #1] Bootstrap tree #488, logLikelihood: -45685.412193
# [04:44:10] [worker #2] Bootstrap tree #489, logLikelihood: -45874.450481
# [04:45:26] [worker #1] Bootstrap tree #491, logLikelihood: -42914.644960
# [04:45:33] [worker #0] Bootstrap tree #487, logLikelihood: -45056.511565
# [04:45:39] [worker #2] Bootstrap tree #492, logLikelihood: -43914.476176
# [04:47:05] [worker #1] Bootstrap tree #494, logLikelihood: -44958.768717
# [04:47:08] [worker #0] Bootstrap tree #490, logLikelihood: -43791.336729
# [04:47:19] [worker #2] Bootstrap tree #495, logLikelihood: -45636.585921
# [04:48:35] [worker #0] Bootstrap tree #493, logLikelihood: -45518.972877
# [04:48:40] [worker #1] Bootstrap tree #497, logLikelihood: -45746.856286
# [04:49:00] [worker #2] Bootstrap tree #498, logLikelihood: -45294.939608
# [04:50:02] [worker #0] Bootstrap tree #496, logLikelihood: -46244.276031
# [04:50:15] [worker #1] Bootstrap tree #500, logLikelihood: -45053.533154
# [04:51:35] [worker #0] Bootstrap tree #499, logLikelihood: -45912.320125
# [04:53:05] [worker #2] Bootstrap tree #501, logLikelihood: -46897.993857
# [04:53:15] [worker #0] Bootstrap tree #502, logLikelihood: -44078.347034
# [04:53:18] [worker #1] Bootstrap tree #503, logLikelihood: -45676.934819
# [04:54:41] [worker #2] Bootstrap tree #504, logLikelihood: -45292.110937
# [04:54:50] [worker #0] Bootstrap tree #505, logLikelihood: -43797.474835
# [04:54:54] [worker #1] Bootstrap tree #506, logLikelihood: -43426.130216
# [04:56:20] [worker #0] Bootstrap tree #508, logLikelihood: -46913.862312
# [04:56:36] [worker #1] Bootstrap tree #509, logLikelihood: -43106.465323
# [04:56:38] [worker #2] Bootstrap tree #507, logLikelihood: -45660.944306
# [04:57:54] [worker #0] Bootstrap tree #511, logLikelihood: -44834.137279
# [04:58:16] [worker #1] Bootstrap tree #512, logLikelihood: -45470.629176
# [04:58:30] [worker #2] Bootstrap tree #510, logLikelihood: -45515.779747
# [04:59:33] [worker #0] Bootstrap tree #514, logLikelihood: -45410.317185
# [05:00:03] [worker #2] Bootstrap tree #513, logLikelihood: -45872.484779
# [05:00:11] [worker #1] Bootstrap tree #515, logLikelihood: -43526.542446
# [05:01:11] [worker #0] Bootstrap tree #517, logLikelihood: -45400.229343
# [05:01:49] [worker #1] Bootstrap tree #518, logLikelihood: -44655.982438
# [05:01:56] [worker #2] Bootstrap tree #516, logLikelihood: -44255.046489
# [05:03:02] [worker #0] Bootstrap tree #520, logLikelihood: -45527.101933
# [05:03:15] [worker #1] Bootstrap tree #521, logLikelihood: -43595.442575
# [05:03:36] [worker #2] Bootstrap tree #519, logLikelihood: -44088.123981
# [05:04:27] [worker #0] Bootstrap tree #523, logLikelihood: -43923.082034
# [05:04:46] [worker #1] Bootstrap tree #524, logLikelihood: -46675.658920
# [05:05:23] [worker #2] Bootstrap tree #522, logLikelihood: -47271.070307
# [05:06:15] [worker #0] Bootstrap tree #526, logLikelihood: -43581.116026
# [05:06:20] [worker #1] Bootstrap tree #527, logLikelihood: -46289.653810
# [05:07:11] [worker #2] Bootstrap tree #525, logLikelihood: -46218.219268
# [05:07:50] [worker #1] Bootstrap tree #530, logLikelihood: -44116.796029
# [05:08:11] [worker #0] Bootstrap tree #529, logLikelihood: -45277.363990
# [05:08:35] [worker #2] Bootstrap tree #528, logLikelihood: -45988.332504
# [05:09:40] [worker #1] Bootstrap tree #533, logLikelihood: -44311.541099
# [05:09:51] [worker #0] Bootstrap tree #532, logLikelihood: -47103.413650
# [05:10:23] [worker #2] Bootstrap tree #531, logLikelihood: -47793.289351
# [05:11:23] [worker #0] Bootstrap tree #535, logLikelihood: -44985.446232
# [05:11:53] [worker #1] Bootstrap tree #536, logLikelihood: -44144.862314
# [05:12:15] [worker #2] Bootstrap tree #534, logLikelihood: -46515.774682
# [05:13:01] [worker #0] Bootstrap tree #538, logLikelihood: -46321.454987
# [05:13:23] [worker #1] Bootstrap tree #539, logLikelihood: -43916.602152
# [05:14:04] [worker #2] Bootstrap tree #537, logLikelihood: -47220.268032
# [05:14:46] [worker #0] Bootstrap tree #541, logLikelihood: -45092.606203
# [05:14:48] [worker #1] Bootstrap tree #542, logLikelihood: -43573.814152
# [05:15:22] [worker #2] Bootstrap tree #540, logLikelihood: -44802.982154
# [05:16:19] [worker #1] Bootstrap tree #545, logLikelihood: -42663.785127
# [05:16:41] [worker #0] Bootstrap tree #544, logLikelihood: -48162.545777
# [05:16:53] [worker #2] Bootstrap tree #543, logLikelihood: -47415.569602
# [05:17:47] [worker #1] Bootstrap tree #548, logLikelihood: -45338.054415
# [05:18:17] [worker #0] Bootstrap tree #547, logLikelihood: -45422.503257
# [05:18:27] [worker #2] Bootstrap tree #546, logLikelihood: -43558.135317
# [05:19:48] [worker #2] Bootstrap tree #549, logLikelihood: -44372.310360
# [05:20:01] [worker #0] Bootstrap tree #550, logLikelihood: -45244.973659
# [05:20:03] Bootstrapping converged after 550 replicates.
#
# Bootstrap trees saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_bootstraps.raxml.bootstraps
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T3_bootstraps.raxml.log
#
# Analysis started: 11-Dec-2023 12:33:00 / finished: 11-Dec-2023 17:53:04
#
# Elapsed time: 19204.127 seconds
#
#
# Output files were moved to: ../results/phyl_trees/all_projects_combined/T3_bootstraps
# 0

# %% [markdown]
# ### Computing branch support

# %%
# main_dir = os.path.join(results_path, 'phyl_trees', 'refrence_alignment_tree')

main_dir = os.path.join(results_path, 'phyl_trees', 'all_projects_combined')

bootstraps = os.path.join(main_dir, 'T3_bootstraps', 'T3_bootstraps.raxml.bootstraps')
tree = os.path.join(main_dir, 'T2_MLtree', 'T2_MLtree.raxml.bestTree')
prefix = 'T4_supports'
output_dir = os.path.join(main_dir, prefix)

# Check if the output directory exists, create it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

run_raxmlng_support(tree = tree,
                    output_dir = output_dir, 
                    bootstraps = bootstraps, 
                    num_threads=3, 
                    prefix=prefix)
# Out:
# RAxML-NG v. 1.1.0 released on 29.11.2021 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, 8 cores, 11 GB RAM
#
# RAxML-NG was called at 11-Dec-2023 19:03:02 as follows:
#
# raxml-ng --support --tree ../results/phyl_trees/all_projects_combined/T2_MLtree/T2_MLtree.raxml.bestTree --bs-trees ../results/phyl_trees/all_projects_combined/T3_bootstraps/T3_bootstraps.raxml.bootstraps --prefix T4_supports --threads 3
#
# Analysis options:
#   run mode: Compute bipartition support (Felsenstein Bootstrap)
#   start tree(s): user
#   random seed: 1702317782
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (3 threads), thread pinning: OFF
#
# Reading reference tree from file: ../results/phyl_trees/all_projects_combined/T2_MLtree/T2_MLtree.raxml.bestTree
# Reference tree size: 183
#
# Reading bootstrap trees from file: ../results/phyl_trees/all_projects_combined/T3_bootstraps/T3_bootstraps.raxml.bootstraps
# Loaded 550 trees with 183 taxa.
#
# Best ML tree with Felsenstein bootstrap (FBP) support values saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T4_supports.raxml.support
#
# Execution log saved to: /home/lubo/code/wRajter/vampyrella_2023/notebooks/T4_supports.raxml.log
#
# Analysis started: 11-Dec-2023 19:03:02 / finished: 11-Dec-2023 19:03:02
#
# Elapsed time: 0.228 seconds
#
#
# Output files were moved to: ../results/phyl_trees/all_projects_combined/T4_supports
# 0

# %% [markdown]
# # Tree visualisation

# %%
tree_path

# %%
# Variables
tree_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'T2_gblocks_strong', 'T2.raxml.bestTree')
alignment_path = os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'alignments', 'vamp_mafft.fasta')
os.environ['QT_QPA_PLATFORM'] = 'offscreen'

# %%
# Creating name_mapping dictionary to rename the new sequences in the tree

name_mapping = {}

with open(alignment_path, 'r') as f:
    for line in f:
        # Reference sequences part
        if line.startswith('>') and 'Vampyrellida' in line:
            old_name = line.strip('>').strip()
            new_name = line.split('|')[-1].strip()
            id = line.split('|')[0].strip('>').strip()
            name_mapping[old_name] = new_name + '_' + id
        # New environmental sequences part
        elif line.startswith('>') and 'centroid' in line:
            old_name = line.strip('>').strip()
            seq_name = line.split('=')[1].strip('_seqs')
            sample_name = line.split('_')[-1].strip()
            new_name = 'env_otu_' + seq_name + '_' + sample_name
            name_mapping[old_name] = new_name

# %% [markdown]
# ### Create inner nodes

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()

# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree

# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = "internal_node_{}".format(i)
        i += 1

# for node in tree.traverse():
#     print(node.name)

# # Apply the renaming directly to the leaves of the tree
# for leaf in tree.iter_leaves():
#     if leaf.name in name_mapping:
#         leaf.name = name_mapping[leaf.name]

# Styling
ts.show_leaf_name = True # display leaf names

# Hides the node circles
for node in tree.traverse():
    node.img_style["size"] = 0

# Add node names/IDs
for n in tree.traverse():
    # Create a face to display node name/ID
    name_face = TextFace(n.name, fsize=10, fgcolor='black')
    n.add_face(name_face, column=0, position="branch-top")

tree.render(os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'tree_inner_nodes_gblocks_strong.png'), dpi=300, w=10000, tree_style=ts)
tree.render('%%inline', tree_style=ts)

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()
# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree

# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = 'internal_node_{}'.format(i)
        i += 1


# Find the node you want to use as the new root
node_to_reroot = tree&'internal_node_20'  # Replace 'Node_Name' with the name of your desired node

# Use the assigned name to reroot
tree.set_outgroup(node_to_reroot)

# # Identify the node whose children you want to swap
node_to_swap_1 = tree&'internal_node_0'  
node_to_swap_2 = tree&'internal_node_12'
# node_to_swap_3 = tree&'internal_node_68'
# node_to_swap_4 = tree&'internal_node_64'
# node_to_swap_5 = tree&'internal_node_72'

# # Swap the children of the target node
node_to_swap_1.swap_children()
node_to_swap_2.swap_children()
# node_to_swap_3.swap_children()
# node_to_swap_4.swap_children()
# node_to_swap_5.swap_children()



# Apply the renaming directly to the leaves of the tree
for leaf in tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]


# Add node names/IDs
for n in tree.traverse():
    # Create a face to display node name/ID
    name_face = TextFace(n.name, fsize=10, fgcolor='black')
    n.add_face(name_face, column=0, position="branch-top")


# Hides the node circles
for node in tree.traverse():
    node.img_style['size'] = 0

tree.render('%%inline', tree_style=ts)
# tree.show()
# tree.render(os.path.join(results_path, 'tree_test.png'), tree_style=ts)

# %% [markdown]
# ### Topology

# %%
# Load the tree
tree = Tree(tree_path)

# Create a tree style
ts = TreeStyle()
# Styling
ts.scale = 2000
ts.tree_width = 60000  # Increase this for a wider tree
line_width = 2


# Assign names to inner nodes for easy reference
i = 0
for n in tree.traverse():
    if not n.is_leaf():  # Check if it is an inner node
        n.name = 'internal_node_{}'.format(i)
        i += 1


# Find the node you want to use as the new root
node_to_reroot = tree&'internal_node_6'  # Replace 'Node_Name' with the name of your desired node

# Use the assigned name to reroot
tree.set_outgroup(node_to_reroot)

# Identify the node whose children you want to swap
node_to_swap_1 = tree&'internal_node_0'  
node_to_swap_2 = tree&'internal_node_2'
# node_to_swap_3 = tree&'internal_node_11'
# node_to_swap_4 = tree&'internal_node_64'
# node_to_swap_5 = tree&'internal_node_72'

# Swap the children of the target node
node_to_swap_1.swap_children()
node_to_swap_2.swap_children()
node_to_swap_3.swap_children()
# node_to_swap_4.swap_children()
# node_to_swap_5.swap_children()




# Apply the renaming directly to the leaves of the tree
for leaf in tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]


# # Add node names/IDs
# for n in tree.traverse():
#     # Create a face to display node name/ID
#     name_face = TextFace(n.name, fsize=10, fgcolor='black')
#     n.add_face(name_face, column=0, position="branch-top")


# Hides the node circles
for node in tree.traverse():
    node.img_style['size'] = 0

# Nodestyle
for node in tree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = line_width  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = line_width  # Set the thickness of horizontal lines
    node.set_style(nstyle)

# Find the node you want to collapse
node_to_collapse_1 = tree&'internal_node_6'
node_to_collapse_2 = tree&'internal_node_7'
node_to_collapse_3 = tree&'internal_node_29'
node_to_collapse_4 = tree&'internal_node_28'
node_to_collapse_5 = tree&'internal_node_1'
node_to_collapse_6 = tree&'internal_node_8'
node_to_collapse_7 = tree&'internal_node_19'

# node_to_collapse.img_style['shape'] = 'sphere'
# node_to_collapse.img_style['size'] = 50
node_to_collapse_1.img_style['draw_descendants'] = False
node_to_collapse_2.img_style['draw_descendants'] = False
node_to_collapse_3.img_style['draw_descendants'] = False
node_to_collapse_4.img_style['draw_descendants'] = False
node_to_collapse_5.img_style['draw_descendants'] = False
node_to_collapse_6.img_style['draw_descendants'] = False
node_to_collapse_7.img_style['draw_descendants'] = False

# Rename the node
node_to_collapse_1.name = 'Sericomyxidae'
node_to_collapse_2.name = 'Thalassomyxa & Arachnula'
node_to_collapse_3.name = 'Placopodidae'
node_to_collapse_4.name = 'B4'
node_to_collapse_5.name = 'Vampyrella & Leptophrys'
node_to_collapse_6.name = 'B1'
node_to_collapse_7.name = 'B2'

tree.render('%%inline', tree_style=ts)
# tree.show()
tree.render(os.path.join(results_path, 'phyl_trees', project, marker, denoise_method, sim, 'tree_gblocks_strong.png'), dpi=600, w=1000, tree_style=ts)

# %%
import os
from ete3 import Tree, TreeStyle, NodeStyle, TextFace

os.environ['QT_QPA_PLATFORM'] = 'offscreen'
line_width = 1
tree_width = 200


# Create a Tree object from the Newick file
main_tree = Tree(f'{tree_file}/T2.raxml.bestTree')


# Apply the renaming directly to the leaves of the tree
for leaf in main_tree.iter_leaves():
    if leaf.name in name_mapping:
        leaf.name = name_mapping[leaf.name]
        

# Function to get color based on the label
def get_color(name):
    if 'Leptophrys_vorax_strain_LV02_' in name:
        return 'red'
    elif 'Leptophrys_vorax_strain_LV04_' in name:
        return '#990000'
    elif 'Vampyrella_lateritia_strain_VL09_' in name:
        return 'green'
    elif 'Vampyrella_lateritia_strain_NHR1' in name:
        return '#33CC33'
    elif 'Pseudovampyrella_closterii_strain_VC01_' in name:
        return 'purple'
    elif 'Placopus_flabellus_NHR1_' in name:
        return 'orange'
    elif 'Leptophrys_vorax_strain_LV01_' in name:
        return '#FF6666'
    return 'black'  # Default color if no match

for node in main_tree.traverse():
    # Set the color and thickness for all nodes in the subtree
    nstyle = NodeStyle()
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_width"] = line_width  # Set the thickness of vertical lines
    nstyle["hz_line_width"] = line_width  # Set the thickness of horizontal lines
    node.set_style(nstyle)

for leaf in main_tree.iter_leaves():
    color = get_color(leaf.name)

    # Apply the color to the text (leaf name)
    name_face = TextFace(leaf.name, fgcolor=color)
    leaf.add_face(name_face, column=0, position="branch-right")

    # Apply the color to the branch leading to the leaf
    nstyle = NodeStyle()
    nstyle["fgcolor"] = color
    nstyle["size"] = 0  # Set size to 0 to hide the default circle node
    nstyle["vt_line_color"] = color
    nstyle["hz_line_color"] = color
    nstyle["vt_line_width"] = line_width  # Control the thickness of the vertical lines
    nstyle["hz_line_width"] = line_width  # Control the thickness of the horizontal lines
    leaf.set_style(nstyle)


ts = TreeStyle()
ts.scale = tree_width  # Increase this value to spread out the tree more
ts.show_leaf_name = False
# main_tree.render("%%inline", tree_style=ts)
# main_tree.render(f"{tree_file}/tree_mock.png", dpi=600, w=10000, tree_style=ts)

# save as Newick
# main_tree.write(outfile=f"{tree_file}/tree_mock.newick")

# %%
## Cola

# %%
from ete3 import Tree

def collapse_low_support_nodes(tree_path, threshold=70):
    """
    Collapse nodes in a phylogenetic tree that have bootstrap support values below the given threshold.
    
    Parameters:
    tree_path (str): Path to the Newick tree file.
    threshold (int): Bootstrap support threshold below which nodes will be collapsed. Defaults to 70.
    
    Returns:
    Tree: The tree with nodes collapsed below the bootstrap support threshold.
    """
    
    # Load the tree
    tree = Tree(tree_path)
    
    # Iterate over each node
    for node in tree.traverse():
        # If the node has a bootstrap support value and it's below the threshold
        if node.support < threshold:
            # Collapse the node
            node.delete()
    
    return tree

# Example usage
collapsed_tree = collapse_low_support_nodes('path/to/your/tree.nw', threshold=70)
collapsed_tree.write(outfile='path/to/your/collapsed_tree.nw')

# %% [markdown]
# # Subtrees
